# %% [markdown]
# # First Run of a AutoRegressive-LSTM on the App **MASSA**
#
# **Paramaters**
# The objective of this first run is to do it as simple as possible, to control if the set up is correct and that the code works fine.
# - the config file:  *ARLSTM_v0.yml*
# - basins folder:    *../data/basins.txt* (only massa)
# - dataset file:     *../../../data/Massa/massa.csv*
#
# For now, we only use 2 dynamical forcing variables:
# 1. precipitation at the station Bruchji: prec_bruchji (column CV)
# 2. temperature at the station Binn: temp_binn (column Y)
#
# **NOTE:** no controle of the quality of the dataset has been made for now.

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
import torch

from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run
from neuralhydrology.datasetzoo import register_dataset

# %% [markdown]
# ### Adding our Dataset | Metrics | Models

# %%
from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)  # key used in your YAML
from neuralhydrology.utils.config import Config

# Custom functions plot_training_curves
from custom.functions.Plot import plot_hydrograph, plot_training_curves, plot_validation_metrics
from custom.functions.utils_fla import parse_neuralhydrology_log

# %% [markdown]
# ---

# %%
configPath = Path("24h_v3 - Copy.yml")
runFile = "24h_v3"
cfg = Config(configPath)
TRAIN =  True
Evaluation_TEST = False

# %% [markdown]
# ### Training

# %%
if TRAIN:
    print(" Starting the training  ")
    # by default we assume that you have at least one cuda-capable nvidia gpu or macos with metal support
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        start_run(config_file=Path(configPath))
    # fall back to cpu-only mode
    else:
        print("Using CPU")
        start_run(config_file=Path(configPath), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
# Out:
#  Starting the training
# Using GPU
# 2025-10-17 14:19:40,120: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\ARLSTM_WrongMethod\runs\24h_v3_1710_141940\output.log initialized.
# 2025-10-17 14:19:40,121: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\ARLSTM_WrongMethod\runs\24h_v3_1710_141940
# 2025-10-17 14:19:40,121: ### Run configurations for 24h_v3
# 2025-10-17 14:19:40,122: experiment_name: 24h_v3
# 2025-10-17 14:19:40,122: base_run_dir: runs
# 2025-10-17 14:19:40,123: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\ARLSTM_WrongMethod\runs\24h_v3_1710_141940\train_data
# 2025-10-17 14:19:40,123: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\ARLSTM_WrongMethod\runs\24h_v3_1710_141940\img_log
# 2025-10-17 14:19:40,124: seed: 42
# 2025-10-17 14:19:40,124: device: cuda:0
# 2025-10-17 14:19:40,125: num_workers: 16
# 2025-10-17 14:19:40,125: data_dir: ..\..\data\Massa
# 2025-10-17 14:19:40,125: dataset: swisshourly
# 2025-10-17 14:19:40,126: train_basin_file: ..\data\basins.txt
# 2025-10-17 14:19:40,126: validation_basin_file: ..\data\basins.txt
# 2025-10-17 14:19:40,126: test_basin_file: ..\data\basins.txt
# 2025-10-17 14:19:40,127: train_start_date: 2016-01-03 00:00:00
# 2025-10-17 14:19:40,128: train_end_date: 2023-02-28 00:00:00
# 2025-10-17 14:19:40,128: validation_start_date: 2023-03-01 00:00:00
# 2025-10-17 14:19:40,129: validation_end_date: 2024-03-31 00:00:00
# 2025-10-17 14:19:40,129: test_start_date: 2024-04-01 00:00:00
# 2025-10-17 14:19:40,129: test_end_date: 2025-05-31 00:00:00
# 2025-10-17 14:19:40,130: dynamic_inputs: ['prec_bruchji', 'prec_visp', 'temp_binn', 'temp_visp', 'ray_visp', 'hr', 'daylight', 'temp_binn_6h_mean', 'degree_day_24h', 'is_snow_bruchji', 'prec_bruchji_3h', 'prec_bruchji_24h']
# 2025-10-17 14:19:40,130: SH_addRollingFeatures: True
# 2025-10-17 14:19:40,130: target_variables: ['streamflow']
# 2025-10-17 14:19:40,131: clip_targets_to_zero: ['streamflow']
# 2025-10-17 14:19:40,131: target_normalization: {'streamflow': {'transform': 'log', 'log_offset': 0.01, 'center': 'mean', 'scale': 'std'}}
# 2025-10-17 14:19:40,131: save_transformed_targets: False
# 2025-10-17 14:19:40,132: lagged_features: {'streamflow': [24]}
# 2025-10-17 14:19:40,132: model: arlstm
# 2025-10-17 14:19:40,132: head: regression
# 2025-10-17 14:19:40,132: hidden_size: 128
# 2025-10-17 14:19:40,133: output_activation: linear
# 2025-10-17 14:19:40,133: output_dropout: 0.1
# 2025-10-17 14:19:40,133: initial_forget_bias: 2.5
# 2025-10-17 14:19:40,134: dynamics_embedding: None
# 2025-10-17 14:19:40,134: statics_embedding: None
# 2025-10-17 14:19:40,134: autoregressive_inputs: ['streamflow_shift1']
# 2025-10-17 14:19:40,135: epochs: 100
# 2025-10-17 14:19:40,135: max_updates_per_epoch: 100
# 2025-10-17 14:19:40,135: batch_size: 128
# 2025-10-17 14:19:40,136: optimizer: AdamW
# 2025-10-17 14:19:40,136: loss: MSE
# 2025-10-17 14:19:40,136: learning_rate: {0: 0.001, 6: 0.0008, 10: 0.0005, 15: 0.0003, 20: 0.0001, 25: 5e-05}
# 2025-10-17 14:19:40,137: clip_gradient_norm: 5.0
# 2025-10-17 14:19:40,137: seq_length: 672
# 2025-10-17 14:19:40,137: predict_last_n: 24
# 2025-10-17 14:19:40,138: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-10-17 14:19:40,138: validate_every: 1
# 2025-10-17 14:19:40,138: validate_n_random_basins: 1
# 2025-10-17 14:19:40,139: early_stopping: True
# 2025-10-17 14:19:40,139: patience_early_stopping: 3
# 2025-10-17 14:19:40,139: minimum_epochs_before_early_stopping: 30
# 2025-10-17 14:19:40,140: dynamic_learning_rate: True
# 2025-10-17 14:19:40,140: patience_dynamic_learning_rate: 1
# 2025-10-17 14:19:40,140: factor_dynamic_learning_rate: 0.3
# 2025-10-17 14:19:40,140: log_interval: 10
# 2025-10-17 14:19:40,141: log_n_figures: 1
# 2025-10-17 14:19:40,141: log_tensorboard: True
# 2025-10-17 14:19:40,142: save_train_data: True
# 2025-10-17 14:19:40,142: save_validation_results: True
# 2025-10-17 14:19:40,143: save_all_output: False
# 2025-10-17 14:19:40,144: save_weights_every: 10
# 2025-10-17 14:19:40,145: save_git_diff: False
# 2025-10-17 14:19:40,145: verbose: 1
# 2025-10-17 14:19:40,146: nan_handling_method: masked_mean
# 2025-10-17 14:19:40,146: nan_step_probability: 0.0
# 2025-10-17 14:19:40,146: nan_sequence_probability: 0.0
# 2025-10-17 14:19:40,147: nan_handling_pos_encoding_size: 0
# 2025-10-17 14:19:40,147: number_of_basins: 1
# 2025-10-17 14:19:40,148: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\ARLSTM_WrongMethod\runs\24h_v3_1710_141940
# 2025-10-17 14:19:40,151: ### Device cuda:0 will be used for training
# 2025-10-17 14:19:40,152: Loading basin data into xarray data set.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 6
#       4 if torch.cuda.is_available() or torch.backends.mps.is_available():
#       5     print("Using GPU")
# ----> 6     start_run(config_file=Path(configPath))
#       7 # fall back to cpu-only mode
#       8 else:
#       9     print("Using CPU")
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\nh_run.py:77, in start_run(config_file, gpu)
#      74 if gpu is not None and gpu < 0:
#      75     config.device = "cpu"
# ---> 77 start_training(config)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\train.py:19, in start_training(cfg)
#      17 else:
#      18     raise ValueError(f"Unknown head {cfg.head}.")
# ---> 19 trainer.initialize_training()
#      20 trainer.train_and_validate()
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\basetrainer.py:156, in BaseTrainer.initialize_training(self)
#     153     self._scaler = load_scaler(self.cfg.base_run_dir)
#     155 # Initialize dataset before the model is loaded.
# --> 156 ds = self._get_dataset()
#     157 # print(f"Dataset length: {len(ds)}")
#     158 if len(ds) == 0:
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\basetrainer.py:88, in BaseTrainer._get_dataset(self)
#      87 def _get_dataset(self) -> BaseDataset:
# ---> 88     return get_dataset(cfg=self.cfg, period="train", is_train=True, scaler=self._scaler)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\datasetzoo\__init__.py:71, in get_dataset(cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#      26 """Get data set instance, depending on the run configuration.
#      27
#      28 Currently implemented datasets are 'caravan', 'camels_aus', 'camels_br', 'camels_cl', 'camels_de', 'camels_gb',
#    (...)     67     If no data set class is implemented for the 'dataset' argument in the config.
#      68 """
#      69 global _datasetZooRegistry
# ---> 71 return _datasetZooRegistry.instantiate_dataset(cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\datasetzoo\datasetregistry.py:92, in DatasetRegistry.instantiate_dataset(self, cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#      89 if Dataset is None:
#      90     raise NotImplementedError(f"No dataset class implemented for dataset {cfg.dataset}")
# ---> 92 return Dataset(cfg=cfg,
#      93                is_train=is_train,
#      94                period=period,
#      95                basin=basin,
#      96                additional_features=additional_features,
#      97                id_to_int=id_to_int,
#      98                scaler=scaler)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\custom\dataset\swisshourly.py:39, in SwissHourly.__init__(self, cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#      29 def __init__(
#      30     self,
#      31     cfg: Config,
#    (...)     37     scaler: Dict[str, Union[pd.Series, xr.DataArray]] = None,
#      38 ):
# ---> 39     super().__init__(
#      40         cfg=cfg,
#      41         is_train=is_train,
#      42         period=period,
#      43         basin=basin,
#      44         additional_features=additional_features or [],
#      45         id_to_int=id_to_int or {},
#      46         scaler=scaler or {},
#      47     )
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\datasetzoo\basedataset.py:141, in BaseDataset.__init__(self, cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#     139         self._create_id_to_int()
#     140 # load and preprocess data
# --> 141 self._load_data()
#     142 if self.is_train:
#     143     self._dump_scaler()
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\datasetzoo\basedataset.py:778, in BaseDataset._load_data(self)
#     774 def _load_data(self):
#     775     # load attributes first to sanity-check those features before doing the compute expensive time series loading
#     776     self._load_combined_attributes()
# --> 778     xr = self._load_or_create_xarray_dataset()
#     780     if self.cfg.loss.lower() in ['nse', 'weightednse']:
#     781         # get the std of the discharge for each basin, which is needed for the (weighted) NSE loss.
#     782         self._calculate_per_basin_std(xr)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\datasetzoo\basedataset.py:365, in BaseDataset._load_or_create_xarray_dataset(self)
#     363     LOGGER.info("Loading basin data into xarray data set.")
#     364 for basin in tqdm(self.basins, file=sys.stdout, disable=self._disable_pbar,  leave=False): #file=sys.stdout,
# --> 365     df = self._load_basin_data(basin)
#     366     # print("Basin data loaded !")
#     367     if self.cfg.target_normalization is not None:
#     368         # print("checkpoint 1")
#     369         # print("Applying target normalization")
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\custom\dataset\swisshourly.py:94, in SwissHourly._load_basin_data(self, basin)
#      92 csv_path = Path(self.cfg.data_dir) / f"{basin}.csv"
#      93 if not csv_path.exists():
# ---> 94     raise FileNotFoundError(f"Time series file not found for basin '{basin}' at {csv_path}")
#      96 df = pd.read_csv(csv_path, parse_dates=["date"])
#      97 if "date" not in df.columns:
#
# FileNotFoundError: Time series file not found for basin 'massa' at ..\..\data\Massa\massa.csv

# %%
# Path to your output.log file
log_path = Path(f"{cfg.base_run_dir}/{runFile}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path)

print("Plotting the losses and metrics throughout the training process: ")
plot_training_curves(train_df, val_df)
plot_validation_metrics(val_df)
# Out:
# ✅ Parsed 34 training epochs and 34 validation evaluations.
# Plotting the losses and metrics throughout the training process:

# %% [markdown]
# ---

# %% [markdown]
# ## Evaluation on the TEST Dataset
# The run directory that needs to be specified for evaluation is printed in the output log above. Since the folder name is created dynamically (including the date and time of the start of the run) you will need to change the `run_dir` argument according to your local directory name. By default, it will use the same device as during the training process.

# %%
run_dir = Path(f"{cfg.base_run_dir}/{runFile}")
print(run_dir)
if Evaluation_TEST:
    print(" Starting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test")
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")
# Out:
# runs\24h_v3
#  Testing process skipped !

# %% [markdown]
# ### Load and inspect model predictions
# Next, we load the results file and compare the model predictions with observations. The results file is always a pickled dictionary with one key per basin (even for a single basin). The next-lower dictionary level is the temporal resolution of the predictions. In this case, we trained a model only on daily data ('1D'). Within the temporal resolution, the next-lower dictionary level are `xr`(an xarray Dataset that contains observations and predictions), as well as one key for each metric that was specified in the config file.

# %%
testPath = Path(run_dir / "test" / f"model_epoch030" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)

# results.keys()
results['massa']['1h']
# Out:
# {'xr': <xarray.Dataset> Size: 2MB
#  Dimensions:         (date: 10201, time_step: 24)
#  Coordinates:
#    * date            (date) datetime64[ns] 82kB 2024-04-01T23:00:00 ... 2025-0...
#    * time_step       (time_step) int64 192B -23 -22 -21 -20 -19 ... -4 -3 -2 -1 0
#  Data variables:
#      streamflow_obs  (date, time_step) float32 979kB 1.155 1.146 ... 27.32 26.4
#      streamflow_sim  (date, time_step) float32 979kB 2.194 2.229 ... 32.29 31.74,
#  'MAPE': 8.659356117248535,
#  'NSE': 0.9692349433898926,
#  'MSE': 18.245586395263672,
#  'RMSE': 4.271485268061178}

# %%
from custom.functions.Plot import plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series

xr_ds = results['massa']["1h"]["xr"]
title24 = f"Massa – {cfg.predict_last_n} | MAPE {results['massa']['1h']['MAPE']:.3f}, NSE {results['massa']['1h']['NSE']:.3f}, RMSE {results['massa']['1h']['MSE']:.3f}"

# last forecast of the horizon vs obs
plot_forecast_24h(xr_ds, title=title24).show()
# All spaghetti forecasts
# plot_forecast_24h(xr_ds, mode="spaghetti").show()


# Example: visualize forecast issued on April 10, 2024, at midnight
plot_forecast_horizon_24h(
    xr_ds,
    issue_date="2024-08-10 00:00:00"
).show()
plot_forecast_horizon_24h(
    xr_ds,
    issue_date="2024-08-10 01:00:00"
).show()

# %%
plot_forecast_horizon_24h(
    xr_ds,
    issue_date="2024-07-08 18:00:00"
).show()

# %%
plot_forecast_horizon_series(
    xr_ds,
    issue_date="2024-06-10 00:00:00",
    n_forecasts=5
).show()

# %% [markdown]
# The data variables in the xarray Dataset are named according to the name of the target variables, with suffix `_obs` for the observations and suffix `_sim` for the simulations.

# %%
# results['massa']['1h']['xr']['streamflow_obs'][0]

# %% [markdown]
# Let's plot the model predictions vs. the observations

# %% [markdown]
# Next, we are going to compute all metrics that are implemented in the NeuralHydrology package. You will find additional hydrological signatures implemented in `neuralhydrology.evaluation.signatures`.

# %%
qobs=results['massa']['1h']['xr']['streamflow_obs']
qsim=results['massa']['1h']['xr']['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.969
# MSE: 18.246
# RMSE: 4.271
# KGE: 0.917
# Alpha-NSE: 0.930
# Beta-KGE: 0.957
# Beta-NSE: -0.030
# Pearson-r: 0.987
# FHV: -9.848
# FMS: -1.022
# FLV: 37.899
# Peak-Timing: nan
# Peak-MAPE: 14.530
# MAPE: 8.659
