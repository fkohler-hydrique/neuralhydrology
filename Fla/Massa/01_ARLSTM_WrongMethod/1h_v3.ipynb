# %% [markdown]
# # First Run of a AutoRegressive-LSTM on the App **MASSA**
#
# **Paramaters**
# The objective of this first run is to do it as simple as possible, to control if the set up is correct and that the code works fine.
# - the config file:  *ARLSTM_v0.yml*
# - basins folder:    *../data/basins.txt* (only massa)
# - dataset file:     *../../../data/Massa/massa.csv*
#
# For now, we only use 2 dynamical forcing variables:
# 1. precipitation at the station Bruchji: prec_bruchji (column CV)
# 2. temperature at the station Binn: temp_binn (column Y)
#
# **NOTE:** no controle of the quality of the dataset has been made for now.

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
import torch

from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run
from neuralhydrology.datasetzoo import register_dataset

# %% [markdown]
# ### Adding our Dataset | Metrics | Models

# %%
from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)  # key used in your YAML
from neuralhydrology.utils.config import Config

# Custom functions plot_training_curves
from custom.functions.Plot import plot_hydrograph, plot_training_curves, plot_validation_metrics
from custom.functions.utils_fla import parse_neuralhydrology_log

# %% [markdown]
# ---

# %%
configPath = Path("1h_v3.yml")

runFile = "1h_v3"

cfg = Config(configPath)
TRAIN = True
Evaluation_TEST = False

# %% [markdown]
# ### Training

# %%
if TRAIN:
    print(" Starting the training  ")
    # by default we assume that you have at least one cuda-capable nvidia gpu or macos with metal support
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        start_run(config_file=Path(configPath))
    # fall back to cpu-only mode
    else:
        print("Using CPU")
        start_run(config_file=Path(configPath), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
# Out:
#  Starting the training
# Using GPU
# 2025-10-10 14:22:35,940: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\ARLSM_simple\runs\1h_v3_1010_142235\output.log initialized.
# 2025-10-10 14:22:35,941: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\ARLSM_simple\runs\1h_v3_1010_142235
# 2025-10-10 14:22:35,941: ### Run configurations for 1h_v3
# 2025-10-10 14:22:35,942: experiment_name: 1h_v3
# 2025-10-10 14:22:35,942: base_run_dir: runs
# 2025-10-10 14:22:35,943: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\ARLSM_simple\runs\1h_v3_1010_142235\train_data
# 2025-10-10 14:22:35,943: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\ARLSM_simple\runs\1h_v3_1010_142235\img_log
# 2025-10-10 14:22:35,944: seed: 42
# 2025-10-10 14:22:35,944: device: cuda:0
# 2025-10-10 14:22:35,945: num_workers: 16
# 2025-10-10 14:22:35,945: data_dir: ..\..\..\data\Massa
# 2025-10-10 14:22:35,945: dataset: swisshourly
# 2025-10-10 14:22:35,946: train_basin_file: ..\data\basins.txt
# 2025-10-10 14:22:35,946: validation_basin_file: ..\data\basins.txt
# 2025-10-10 14:22:35,946: test_basin_file: ..\data\basins.txt
# 2025-10-10 14:22:35,947: train_start_date: 2016-01-03 00:00:00
# 2025-10-10 14:22:35,947: train_end_date: 2023-02-28 00:00:00
# 2025-10-10 14:22:35,947: validation_start_date: 2023-03-01 00:00:00
# 2025-10-10 14:22:35,948: validation_end_date: 2024-03-31 00:00:00
# 2025-10-10 14:22:35,948: test_start_date: 2024-04-01 00:00:00
# 2025-10-10 14:22:35,949: test_end_date: 2025-05-31 00:00:00
# 2025-10-10 14:22:35,950: dynamic_inputs: ['prec_bruchji', 'prec_fieschertal', 'temp_binn', 'temp_visp', 'ray_visp', 'pression_vapeur_binn', 'hr', 'daylight', 'temp_binn_6h_mean', 'degree_day_24h', 'is_snow_bruchji', 'prec_bruchji_3h', 'prec_bruchji_24h', 'prec_fieschertal_3h', 'prec_fieschertal_24h']
# 2025-10-10 14:22:35,950: SH_addRollingFeatures: True
# 2025-10-10 14:22:35,950: target_variables: ['streamflow']
# 2025-10-10 14:22:35,951: clip_targets_to_zero: ['streamflow']
# 2025-10-10 14:22:35,951: target_normalization: {'streamflow': {'transform': 'log', 'log_offset': 0.01, 'center': 'mean', 'scale': 'std'}}
# 2025-10-10 14:22:35,952: save_transformed_targets: False
# 2025-10-10 14:22:35,952: lagged_features: {'streamflow': [1]}
# 2025-10-10 14:22:35,952: model: arlstm
# 2025-10-10 14:22:35,953: head: regression
# 2025-10-10 14:22:35,953: hidden_size: 128
# 2025-10-10 14:22:35,953: output_activation: linear
# 2025-10-10 14:22:35,954: output_dropout: 0.1
# 2025-10-10 14:22:35,954: initial_forget_bias: 2.5
# 2025-10-10 14:22:35,955: dynamics_embedding: None
# 2025-10-10 14:22:35,956: statics_embedding: None
# 2025-10-10 14:22:35,956: autoregressive_inputs: ['streamflow_shift1']
# 2025-10-10 14:22:35,957: epochs: 50
# 2025-10-10 14:22:35,957: max_updates_per_epoch: 100
# 2025-10-10 14:22:35,957: batch_size: 128
# 2025-10-10 14:22:35,958: optimizer: AdamW
# 2025-10-10 14:22:35,958: loss: MSE
# 2025-10-10 14:22:35,958: learning_rate: {0: 0.001, 6: 0.0008, 10: 0.0005, 15: 0.0003, 20: 0.0001, 25: 5e-05}
# 2025-10-10 14:22:35,959: clip_gradient_norm: 5.0
# 2025-10-10 14:22:35,959: seq_length: 672
# 2025-10-10 14:22:35,960: predict_last_n: 1
# 2025-10-10 14:22:35,960: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-10-10 14:22:35,961: validate_every: 1
# 2025-10-10 14:22:35,961: validate_n_random_basins: 1
# 2025-10-10 14:22:35,961: early_stopping: True
# 2025-10-10 14:22:35,962: patience_early_stopping: 3
# 2025-10-10 14:22:35,962: minimum_epochs_before_early_stopping: 30
# 2025-10-10 14:22:35,963: dynamic_learning_rate: True
# 2025-10-10 14:22:35,963: patience_dynamic_learning_rate: 1
# 2025-10-10 14:22:35,963: factor_dynamic_learning_rate: 0.3
# 2025-10-10 16:14:46,554: Epoch 26 average validation loss: 0.00091 -- Median validation metrics: avg_loss: 0.00091, MAPE: 4.92580, NSE: 0.98893, MSE: 6.12565, RMSE: 2.47501
# 2025-10-10 16:14:46,555: [Scheduler] - Learning rate changed from 9.0e-05 to 2.7e-05
# 2025-10-10 16:18:08,538: Epoch 27 average loss: avg_loss: 0.00109, avg_total_loss: 0.00109
# 2025-10-10 16:19:04,410: Epoch 27 average validation loss: 0.00084 -- Median validation metrics: avg_loss: 0.00084, MAPE: 4.56976, NSE: 0.98984, MSE: 5.62254, RMSE: 2.37119
# 2025-10-10 16:22:28,027: Epoch 28 average loss: avg_loss: 0.00108, avg_total_loss: 0.00108
# 2025-10-10 16:23:26,120: Epoch 28 average validation loss: 0.00082 -- Median validation metrics: avg_loss: 0.00082, MAPE: 4.59453, NSE: 0.98956, MSE: 5.77470, RMSE: 2.40306
# 2025-10-10 16:26:44,243: Epoch 29 average loss: avg_loss: 0.00105, avg_total_loss: 0.00105
# 2025-10-10 16:27:38,618: Epoch 29 average validation loss: 0.00083 -- Median validation metrics: avg_loss: 0.00083, MAPE: 4.59391, NSE: 0.98957, MSE: 5.77061, RMSE: 2.40221
# 2025-10-10 16:30:53,200: Epoch 30 average loss: avg_loss: 0.00110, avg_total_loss: 0.00110
# 2025-10-10 16:31:49,141: Epoch 30 average validation loss: 0.00083 -- Median validation metrics: avg_loss: 0.00083, MAPE: 4.53683, NSE: 0.98974, MSE: 5.67759, RMSE: 2.38277
# 2025-10-10 16:31:49,143: [Scheduler] - Learning rate changed from 2.7e-05 to 8.1e-06
# 2025-10-10 16:35:21,922: Epoch 31 average loss: avg_loss: 0.00108, avg_total_loss: 0.00108
# 2025-10-10 16:36:19,321: Epoch 31 average validation loss: 0.00082 -- Median validation metrics: avg_loss: 0.00082, MAPE: 4.55181, NSE: 0.98965, MSE: 5.72349, RMSE: 2.39238
# 2025-10-10 16:39:40,409: Epoch 32 average loss: avg_loss: 0.00108, avg_total_loss: 0.00108
# 2025-10-10 16:40:35,399: Epoch 32 average validation loss: 0.00082 -- Median validation metrics: avg_loss: 0.00082, MAPE: 4.57347, NSE: 0.98957, MSE: 5.76878, RMSE: 2.40183
# 2025-10-10 16:44:07,277: Epoch 33 average loss: avg_loss: 0.00107, avg_total_loss: 0.00107
# 2025-10-10 16:45:06,953: Epoch 33 average validation loss: 0.00083 -- Median validation metrics: avg_loss: 0.00083, MAPE: 4.55662, NSE: 0.98970, MSE: 5.69543, RMSE: 2.38651
# 2025-10-10 16:48:28,762: Epoch 34 average loss: avg_loss: 0.00108, avg_total_loss: 0.00108
# 2025-10-10 16:49:26,972: Epoch 34 average validation loss: 0.00083 -- Median validation metrics: avg_loss: 0.00083, MAPE: 4.54084, NSE: 0.98975, MSE: 5.67208, RMSE: 2.38161
# 2025-10-10 16:49:26,973: Early stopping triggered at epoch 34 with validation loss 0.00083. Training stopped.
# ==================================
#   Training ended successfully !
# ==================================

# %%
# Path to your output.log file
log_path = Path(f"{cfg.base_run_dir}/{runFile}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path)

print("Plotting the losses and metrics throughout the training process: ")
plot_training_curves(train_df, val_df)
plot_validation_metrics(val_df)
# Out:
# ✅ Parsed 34 training epochs and 34 validation evaluations.
# Plotting the losses and metrics throughout the training process:

# %% [markdown]
# ---

# %% [markdown]
# ## Evaluation on the TEST Dataset
# The run directory that needs to be specified for evaluation is printed in the output log above. Since the folder name is created dynamically (including the date and time of the start of the run) you will need to change the `run_dir` argument according to your local directory name. By default, it will use the same device as during the training process.

# %%
run_dir = Path(f"{cfg.base_run_dir}/{runFile}")

if Evaluation_TEST:
    print(" Starting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test")
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")
# Out:
#  Testing process skipped !

# %% [markdown]
# ### Load and inspect model predictions
# Next, we load the results file and compare the model predictions with observations. The results file is always a pickled dictionary with one key per basin (even for a single basin). The next-lower dictionary level is the temporal resolution of the predictions. In this case, we trained a model only on daily data ('1D'). Within the temporal resolution, the next-lower dictionary level are `xr`(an xarray Dataset that contains observations and predictions), as well as one key for each metric that was specified in the config file.

# %%
testPath = Path(run_dir / "test" / f"model_epoch030" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)

# results.keys()
results['massa']['1h']
# Out:
# {'xr': <xarray.Dataset> Size: 164kB
#  Dimensions:         (date: 10224, time_step: 1)
#  Coordinates:
#    * date            (date) datetime64[ns] 82kB 2024-04-01 ... 2025-05-31T23:0...
#    * time_step       (time_step) int64 8B 0
#  Data variables:
#      streamflow_obs  (date, time_step) float32 41kB 1.155 1.146 ... 27.32 26.4
#      streamflow_sim  (date, time_step) float32 41kB 1.299 1.274 ... 31.25 30.53,
#  'MAPE': 6.790926933288574,
#  'NSE': 0.9729814529418945,
#  'MSE': 16.003076553344727,
#  'RMSE': 4.000384550683187}

# %% [markdown]
# The data variables in the xarray Dataset are named according to the name of the target variables, with suffix `_obs` for the observations and suffix `_sim` for the simulations.

# %%
# results['massa']['1h']['xr']['streamflow_obs'][0]

# %% [markdown]
# Let's plot the model predictions vs. the observations

# %%
qobs=results['massa']['1h']['xr']['streamflow_obs']
qsim=results['massa']['1h']['xr']['streamflow_sim']
plot_hydrograph(
    qobs=qobs,
    qsim=qsim,
    results=results,
    basin='massa',
    freq='1h',
    plot_peaks=False  # turn on high-flow markers
)

# %% [markdown]
# Next, we are going to compute all metrics that are implemented in the NeuralHydrology package. You will find additional hydrological signatures implemented in `neuralhydrology.evaluation.signatures`.

# %%
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.973
# MSE: 16.003
# RMSE: 4.000
# KGE: 0.931
# Alpha-NSE: 0.941
# Beta-KGE: 0.965
# Beta-NSE: -0.025
# Pearson-r: 0.988
# FHV: -7.939
# FMS: -0.014
# FLV: 30.333
# Peak-Timing: nan
# Peak-MAPE: 12.884
# MAPE: 6.791
