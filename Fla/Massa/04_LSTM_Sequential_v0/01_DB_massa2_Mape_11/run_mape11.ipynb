# %% [markdown]
# ## Imports

# %%
from   pathlib import Path
import matplotlib.pyplot as plt
import pickle
import torch
import pandas as pd
# import mlflow

from neuralhydrology.evaluation     import metrics
from neuralhydrology.nh_run         import start_run, eval_run
from neuralhydrology.datasetzoo     import register_dataset
from neuralhydrology.utils.config   import Config

from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)

# Custom functions plot_training_curves
from custom.functions.Plot import plot_training_curves, plot_validation_metrics
from custom.functions.Plot import plot_mape_horizon, plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series
from custom.functions.utils_fla import parse_neuralhydrology_log
from custom.functions.utils_fla import info_results, mape_array, dict_without_xr_key

# %% [markdown]
# ## Parameters of the run

# %%
# Initialisation of the config file, name of the experiment in the parameter experiment_name
config_file = Path("config_mape11.yml")
cfg = Config(config_file)

# Here write the name of the run if renamed run or if you want to plot the specified run, otherwise will take the run_dir created during training
# example: "expName_TimeStamp" 
runFile = None 

# list of basins, DB -> name of the basin.txt where the name of the csv is indicated
basin = "massa_2"

# Whether you want to run a training, put false to plot your specific run folder for example
TRAIN, Evaluation_TEST = True, True

save_plots_training = True

# %% [markdown]
# ## Run

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        run_dir = start_run(config_file=Path(config_file))
    else:
        print("Using CPU")
        run_dir = start_run(config_file=Path(config_file), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
if runFile is not None:
    run_dir = Path(f"./runs/{runFile}")

if Evaluation_TEST:
    print("\nStarting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test", from_best=cfg.save_best_enabled)
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")

model_str = f"model_from_best"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-11-06 15:48:50: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\04_LSTM_Sequential_v0\01_DB_massa2_Mape_11\runs\mape11_0611_154850\output.log initialized.
# 2025-11-06 15:48:50: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\04_LSTM_Sequential_v0\01_DB_massa2_Mape_11\runs\mape11_0611_154850
# 2025-11-06 15:48:50: ### Run configurations for mape11
# 2025-11-06 15:48:50: experiment_name: mape11
# 2025-11-06 15:48:50: base_run_dir: runs
# 2025-11-06 15:48:50: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\04_LSTM_Sequential_v0\01_DB_massa2_Mape_11\runs\mape11_0611_154850\img_log
# 2025-11-06 15:48:50: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\04_LSTM_Sequential_v0\01_DB_massa2_Mape_11\runs\mape11_0611_154850\train_data
# 2025-11-06 15:48:50: seed: 42
# 2025-11-06 15:48:50: device: cuda:0
# 2025-11-06 15:48:50: num_workers: 16
# 2025-11-06 15:48:50: data_dir: ..\..\data
# 2025-11-06 15:48:50: dataset: swisshourly
# 2025-11-06 15:48:50: train_basin_file: ..\..\data\basins_2.txt
# 2025-11-06 15:48:50: validation_basin_file: ..\..\data\basins_2.txt
# 2025-11-06 15:48:50: test_basin_file: ..\..\data\basins_2.txt
# 2025-11-06 15:48:50: train_start_date: 2020-03-01 00:00:00
# 2025-11-06 15:48:50: train_end_date: 2023-02-28 00:00:00
# 2025-11-06 15:48:50: validation_start_date: 2023-03-01 00:00:00
# 2025-11-06 15:48:50: validation_end_date: 2024-03-31 00:00:00
# 2025-11-06 15:48:50: test_start_date: 2024-04-01 00:00:00
# 2025-11-06 15:48:50: test_end_date: 2025-07-02 00:00:00
# 2025-11-06 15:48:50: dynamic_inputs: ['streamflow_hindcast', 'null_values', 'prec_bruchji', 'fc_prec_bruchji', 'temp_binn', 'fc_temp_binn', 'temp_mean_6h', 'fc_temp_mean_6h', 'ray_visp', 'temp_mean_degree_day', 'fc_temp_mean_degree_day', 'is_Tmean_snow', 'fc_is_Tmean_snow', 'daylight', 'hr']
# 2025-11-06 15:48:50: hindcast_inputs: ['streamflow_hindcast', 'prec_bruchji', 'temp_binn', 'temp_mean_6h', 'ray_visp', 'temp_mean_degree_day', 'is_Tmean_snow', 'daylight', 'hr']
# 2025-11-06 15:48:50: forecast_inputs: ['null_values', 'fc_prec_bruchji', 'fc_temp_binn', 'fc_temp_mean_6h', 'ray_visp', 'fc_temp_mean_degree_day', 'fc_is_Tmean_snow', 'daylight', 'hr']
# 2025-11-06 15:48:50: timestep_counter: True
# 2025-11-06 15:48:50: target_variables: ['streamflow']
# 2025-11-06 15:48:50: clip_targets_to_zero: ['streamflow']
# 2025-11-06 15:48:50: model: sequential_forecast_lstm
# 2025-11-06 15:48:50: head: regression
# 2025-11-06 15:48:50: hidden_size: 256
# 2025-11-06 15:48:50: hindcast_hidden_size: 256
# 2025-11-06 15:48:50: forecast_hidden_size: 256
# 2025-11-06 15:48:50: output_activation: linear
# 2025-11-06 15:48:50: output_dropout: 0.1
# 2025-11-06 15:48:50: lstm_dropout: 0.0
# 2025-11-06 15:48:50: num_layers: 1
# 2025-11-06 15:48:50: initial_forget_bias: 1.5
# 2025-11-06 15:48:50: state_handoff_network: {'hiddens': [128], 'activation': 'gelu', 'dropout': 0.0}
# 2025-11-06 15:48:50: epochs: 10000
# 2025-11-06 15:48:50: learning_rate: 0.001
# 2025-11-06 15:48:50: batch_size: 32
# 2025-11-06 15:48:50: optimizer: AdamW
# 2025-11-06 15:48:50: loss: custom_loss
# 2025-11-06 15:48:50: seq_length: 150
# 2025-11-06 15:48:50: predict_last_n: 24
# 2025-11-06 15:48:50: forecast_seq_length: 24
# 2025-11-06 15:48:50: forecast_overlap: None
# 2025-11-06 15:48:50: custom_loss: {'losses': ['smape', 'nse', 'mse'], 'weights': [0.7, 0.3, 0.0]}
# 2025-11-06 15:48:50: clip_gradient_norm: 5.0
# 2025-11-06 15:48:50: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-11-06 15:48:50: validate_every: 1
# 2025-11-06 15:48:50: validate_n_random_basins: 1
# 2025-11-06 15:48:50: early_stopping: True
# 2025-11-06 15:48:50: patience_early_stopping: 20
# 2025-11-06 15:48:50: minimum_epochs_before_early_stopping: 20
# 2025-11-06 15:48:50: min_delta_early_stopping: 1e-07
# 2025-11-06 15:48:50: dynamic_learning_rate: True
# 2025-11-06 15:48:50: patience_dynamic_learning_rate: 5
# 2025-11-06 15:48:50: factor_dynamic_learning_rate: 0.4
# 2025-11-06 15:48:50: log_interval: 10
# 2025-11-06 15:48:50: log_n_figures: 1
# 2025-11-06 15:48:50: log_tensorboard: True
# 2025-11-06 15:48:50: save_train_data: False
# 2025-11-06 15:48:50: save_validation_results: False
# 2025-11-06 15:48:50: save_all_output: False
# 2025-11-06 15:48:50: save_weights_every: 10
# 2025-11-06 15:48:50: verbose: 1
# 2025-11-06 15:48:50: save_best_enabled: True
# 2025-11-06 15:48:50: save_best_criterion: MAPE
# 2025-11-06 15:48:50: save_in_csv: True
# 2025-11-06 15:48:50: csv_metrics_name: Metrics_over_Experiments
# 2025-11-06 15:48:50: nan_handling_method: masked_mean
# 2025-11-06 15:48:50: nan_step_probability: 0.0
# 2025-11-06 15:48:50: nan_sequence_probability: 0.0
# 2025-11-06 15:48:50: nan_handling_pos_encoding_size: 0
# 2025-11-06 15:48:50: number_of_basins: 1
# 2025-11-06 15:48:50: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\04_LSTM_Sequential_v0\01_DB_massa2_Mape_11\runs\mape11_0611_154850
# 2025-11-06 15:48:50: ### Device cuda:0 will be used for training
# 2025-11-06 15:48:50: Loading basin data into xarray data set.
# 2025-11-06 15:48:50: Calculating target variable stds per basin
# 2025-11-06 15:48:50: Create lookup table and convert to pytorch tensor
# 2025-11-06 15:49:41: Epoch 1 average loss: avg_loss: 14.53213, avg_total_loss: 14.53213
# 2025-11-06 15:49:44: Epoch 1 average validation loss: 12.17705 -- Median validation metrics: avg_loss: 12.17705, MAPE: 44.78729, NSE: 0.93635, MSE: 35.25286, RMSE: 5.93741
# 2025-11-06 15:49:44: [saveBest] New best model found at epoch 1: 44.787289 (prev inf)
# 2025-11-06 15:50:00: Epoch 2 average loss: avg_loss: 9.35262, avg_total_loss: 9.35262
# 2025-11-06 15:50:04: Epoch 2 average validation loss: 9.41001 -- Median validation metrics: avg_loss: 9.41001, MAPE: 23.90079, NSE: 0.94981, MSE: 27.79716, RMSE: 5.27230
# 2025-11-06 15:50:04: [saveBest] New best model found at epoch 2: 23.900785 (prev 44.787289)
# 2025-11-06 16:08:16: Epoch 38 average loss: avg_loss: 2.42657, avg_total_loss: 2.42657
# 2025-11-06 16:08:21: Epoch 38 average validation loss: 7.84289 -- Median validation metrics: avg_loss: 7.84289, MAPE: 11.09217, NSE: 0.96895, MSE: 17.19439, RMSE: 4.14661
# 2025-11-06 16:08:46: Epoch 39 average loss: avg_loss: 2.41100, avg_total_loss: 2.41100
# 2025-11-06 16:08:51: Epoch 39 average validation loss: 7.88486 -- Median validation metrics: avg_loss: 7.88486, MAPE: 11.07850, NSE: 0.96873, MSE: 17.31676, RMSE: 4.16134
# 2025-11-06 16:09:16: Epoch 40 average loss: avg_loss: 2.40601, avg_total_loss: 2.40601
# 2025-11-06 16:09:21: Epoch 40 average validation loss: 7.82679 -- Median validation metrics: avg_loss: 7.82679, MAPE: 10.70007, NSE: 0.96899, MSE: 17.17667, RMSE: 4.14447
# 2025-11-06 16:09:21: [saveBest] New best model found at epoch 40: 10.700067 (prev 10.936830)
# 2025-11-06 16:09:21: [Scheduler] - Learning rate changed from 6.4e-05 to 2.6e-05
# 2025-11-06 16:09:46: Epoch 41 average loss: avg_loss: 2.36651, avg_total_loss: 2.36651
# 2025-11-06 16:09:49: Epoch 41 average validation loss: 7.87172 -- Median validation metrics: avg_loss: 7.87172, MAPE: 10.92750, NSE: 0.96877, MSE: 17.29661, RMSE: 4.15892
# 2025-11-06 16:10:03: Epoch 42 average loss: avg_loss: 2.35727, avg_total_loss: 2.35727
# 2025-11-06 16:10:06: Epoch 42 average validation loss: 7.87291 -- Median validation metrics: avg_loss: 7.87291, MAPE: 10.86951, NSE: 0.96854, MSE: 17.42403, RMSE: 4.17421
# 2025-11-06 16:10:06: Early stopping triggered at epoch 42 with validation loss 7.87291. Training stopped.
# ==================================
#   Training ended successfully !
# ==================================
#
# Starting the EVALUATION on the test period:
# 2025-11-06 16:10:08: Using the model weights from c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\04_LSTM_Sequential_v0\01_DB_massa2_Mape_11\runs\mape11_0611_154850\best_model.pt
# ==================================
#   TEST ended successfully !
# ==================================

# %%
Metrics = dict_without_xr_key(results[basin]['1h'])
Metrics_ = Metrics.copy()

if cfg.save_in_csv and Evaluation_TEST:
    if Metrics_ is not None:
        summary_file =  Path(f"./{cfg.csv_metrics_name}.csv")
        Metrics_['experiment'] = run_dir.name

        summary_df = pd.DataFrame([Metrics_])
        
        # Append to summary file, creating it with a header if it doesn't exist
        summary_df.to_csv(f"{cfg.csv_metrics_name}.csv", mode='a', header=not summary_file.exists(), index=False)

# %% [markdown]
# ---

# %%
print("Metrics on the cuncatenated last predictions, on the Evaluation period:")
print(Metrics)
# Out:
# Metrics on the cuncatenated last predictions, on the Evaluation period:
# {'MAPE': 12.55449104309082, 'NSE': 0.951233983039856, 'MSE': 30.7420711517334, 'RMSE': 5.544553286941465}

# %%
# Path to your output.log file
log_path = Path(f"{run_dir}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path, verbose=False)


plot_training_curves(train_df, val_df, save_fig = save_plots_training, run_dir=run_dir)
plot_validation_metrics(val_df, save_fig = save_plots_training, run_dir=run_dir)

# %% [markdown]
# ---

# %% [markdown]
# ### Extract results from Test period

# %%
results_ = results[basin]["1h"]["xr"]
scores = dict_without_xr_key(results[basin]['1h'])

# store only the values in numpy arrays from xarray DataArrays
y_true = results_['streamflow_obs']
y_pred = results_['streamflow_sim']

verb = False
if verb: 
    print("\n-- Calculating MAPE values for each horizon: --\n")
    mapes = mape_array(y_true, y_pred, verbose=verb)
    print("\n-- MAPE calculation per horizon completed. --\n")
else:
    mapes = mape_array(y_true, y_pred, verbose=verb)

# %%
plot_mape_horizon(
    mapes,
    color="#e76f51",
    title=f"MAPE vs Forecast Horizon for basin {basin}"
)

# %%
scores_str = str.join(', ', [f"{key} : {scores[key]:.2f}" for key in scores])
title24 = f"Massa – {cfg.predict_last_n}h | " + scores_str

# plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[1, 6, cfg.predict_last_n])
plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[cfg.predict_last_n])

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 00:00:00",
#     xr_ds=results_
# ).show()
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 01:00:00",
#     xr_ds=results_
# ).show()

# %%
# Example to plot the forecast issued at the given time stamp and the n_forecast next predictions
# plot_forecast_horizon_series(
#     issue_date="2024-06-10 00:00:00",
#     xr_ds=results_,
#     n_forecasts=10
# ).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores - TEST period

# %% [markdown]
# ### Prediction at $t+24h$

# %%
qobs=results_['streamflow_obs']
qsim=results_['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.951
# MSE: 30.742
# RMSE: 5.545
# KGE: 0.910
# Alpha-NSE: 0.930
# Beta-KGE: 0.949
# Beta-NSE: -0.039
# Pearson-r: 0.977
# FHV: -8.032
# FMS: -0.586
# FLV: -1778.036
# Peak-Timing: nan
# Peak-MAPE: 17.739
# MAPE: 12.555

# %% [markdown]
# ### Prediction at $t+7h$

# %%
values = metrics.calculate_all_metrics(qobs.isel(time_step=6), qsim.isel(time_step=6))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.975
# MSE: 15.480
# RMSE: 3.934
# KGE: 0.960
# Alpha-NSE: 0.967
# Beta-KGE: 0.980
# Beta-NSE: -0.016
# Pearson-r: 0.988
# FHV: -3.087
# FMS: -0.935
# FLV: -27.021
# Peak-Timing: nan
# Peak-MAPE: 13.377
# MAPE: 8.460
