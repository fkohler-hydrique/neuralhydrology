# %% [markdown]
# #  Run of Model **$X$** on the App **MASSA**
#
# **Paramaters**
# The parameters of all models should be available in the parent folder, in an EXCEL file.

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
import torch

from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run
from neuralhydrology.datasetzoo import register_dataset

# %% [markdown]
# ### Adding our Dataset | Metrics | Models

# %%
from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)
from neuralhydrology.utils.config import Config

# Custom functions plot_training_curves
from custom.functions.Plot import plot_hydrograph, plot_training_curves, plot_validation_metrics
from custom.functions.utils_fla import parse_neuralhydrology_log

# %% [markdown]
# ---

# %% [markdown]
# ### Run parameters

# %%
configPath = Path("M0.yml")

runFile = "M4_10"

cfg = Config(configPath)
TRAIN = True
Evaluation_TEST =  False

# %% [markdown]
# ---
# ## **Training**

# %%
import pandas as pd
csv_path = r"..\..\data\massa.csv"
data = pd.read_csv(csv_path)
# print("Columns of the csv:  ", data.columns)
# print(data.dtypes)
# data['date'] = pd.to_datetime(data['date'])


# print some information about the dataset

# print(data.head())
# print(data.describe())

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    # by default we assume that you have at least one cuda-capable nvidia gpu or macos with metal support
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        start_run(config_file=Path(configPath))
    # fall back to cpu-only mode
    else:
        print("Using CPU")
        start_run(config_file=Path(configPath), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-10-20 12:24:25,647: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\M_0\runs\M0_2010_122425\output.log initialized.
# 2025-10-20 12:24:25,648: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\M_0\runs\M0_2010_122425
# 2025-10-20 12:24:25,648: ### Run configurations for M0
# 2025-10-20 12:24:25,649: experiment_name: M0
# 2025-10-20 12:24:25,649: base_run_dir: runs
# 2025-10-20 12:24:25,650: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\M_0\runs\M0_2010_122425\train_data
# 2025-10-20 12:24:25,650: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\M_0\runs\M0_2010_122425\img_log
# 2025-10-20 12:24:25,651: seed: 42
# 2025-10-20 12:24:25,652: device: cuda:0
# 2025-10-20 12:24:25,652: num_workers: 16
# 2025-10-20 12:24:25,653: data_dir: ..\..\data
# 2025-10-20 12:24:25,653: dataset: swisshourly
# 2025-10-20 12:24:25,653: train_basin_file: ..\..\data\basins.txt
# 2025-10-20 12:24:25,654: validation_basin_file: ..\..\data\basins.txt
# 2025-10-20 12:24:25,654: test_basin_file: ..\..\data\basins.txt
# 2025-10-20 12:24:25,654: train_start_date: 2020-01-03 00:00:00
# 2025-10-20 12:24:25,655: train_end_date: 2023-02-28 00:00:00
# 2025-10-20 12:24:25,655: validation_start_date: 2023-03-01 00:00:00
# 2025-10-20 12:24:25,655: validation_end_date: 2024-03-31 00:00:00
# 2025-10-20 12:24:25,656: test_start_date: 2024-04-01 00:00:00
# 2025-10-20 12:24:25,656: test_end_date: 2025-05-31 00:00:00
# 2025-10-20 12:24:25,656: dynamic_inputs: ['prec_bruchji', 'degree_day', 'is_snow', 'forecast_prec_bruchji', 'forecast_temp_binn', 'temp_binn', 'ray_visp', 'daylight', 'hr', 'null_values', 'streamflow_hindcast']
# 2025-10-20 12:24:25,657: hindcast_inputs: ['degree_day', 'is_snow', 'ray_visp', 'prec_bruchji', 'temp_binn', 'streamflow_hindcast', 'daylight', 'hr']
# 2025-10-20 12:24:25,657: forecast_inputs: ['forecast_prec_bruchji', 'forecast_temp_binn', 'degree_day', 'is_snow', 'ray_visp', 'null_values', 'daylight', 'hr']
# 2025-10-20 12:24:25,657: forecast_seq_length: 24
# 2025-10-20 12:24:25,659: forecast_overlap: None
# 2025-10-20 12:24:25,659: timestep_counter: True
# 2025-10-20 12:24:25,659: SH_addRollingFeatures: False
# 2025-10-20 12:24:25,660: target_variables: ['streamflow']
# 2025-10-20 12:24:25,660: clip_targets_to_zero: ['streamflow']
# 2025-10-20 12:24:25,660: model: sequential_forecast_lstm
# 2025-10-20 12:24:25,661: head: regression
# 2025-10-20 12:24:25,661: hidden_size: 128
# 2025-10-20 12:24:25,662: output_activation: linear
# 2025-10-20 12:24:25,662: output_dropout: 0.1
# 2025-10-20 12:24:25,662: initial_forget_bias: 2
# 2025-10-20 12:24:25,663: epochs: 1000
# 2025-10-20 12:24:25,663: max_updates_per_epoch: None
# 2025-10-20 12:24:25,663: batch_size: 32
# 2025-10-20 12:24:25,664: optimizer: AdamW
# 2025-10-20 12:24:25,664: loss: SMAPE
# 2025-10-20 12:24:25,665: learning_rate: 0.001
# 2025-10-20 12:24:25,665: clip_gradient_norm: 3.0
# 2025-10-20 12:24:25,665: seq_length: 90
# 2025-10-20 12:24:25,666: predict_last_n: 24
# 2025-10-20 12:24:25,666: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-10-20 12:24:25,667: validate_every: 1
# 2025-10-20 12:24:25,667: validate_n_random_basins: 1
# 2025-10-20 12:24:25,667: early_stopping: True
# 2025-10-20 12:24:25,668: patience_early_stopping: 10
# 2025-10-20 12:24:25,668: minimum_epochs_before_early_stopping: 20
# 2025-10-20 12:24:25,669: min_delta_early_stopping: 5e-07
# 2025-10-20 12:24:25,669: dynamic_learning_rate: True
# 2025-10-20 12:24:25,669: patience_dynamic_learning_rate: 5
# 2025-10-20 12:24:25,670: factor_dynamic_learning_rate: 0.6
# 2025-10-20 12:24:25,670: log_interval: 10
# 2025-10-20 12:24:25,671: log_n_figures: 1
# 2025-10-20 12:24:25,671: log_tensorboard: True
# 2025-10-20 12:24:25,672: save_train_data: False
# 2025-10-20 12:24:25,672: save_validation_results: False
# 2025-10-20 12:24:25,672: save_all_output: False
# 2025-10-20 12:24:25,673: save_weights_every: 10
# 2025-10-20 12:24:25,673: save_git_diff: False
# 2025-10-20 12:24:25,674: verbose: 1
# 2025-10-20 12:24:25,674: nan_handling_method: masked_mean
# 2025-10-20 12:24:25,675: nan_step_probability: 0.0
# 2025-10-20 12:24:25,675: nan_sequence_probability: 0.0
# 2025-10-20 12:24:25,676: nan_handling_pos_encoding_size: 0
# 2025-10-20 12:24:25,676: number_of_basins: 1
# 2025-10-20 12:24:25,676: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\M_0\runs\M0_2010_122425
# 2025-10-20 12:24:25,681: ### Device cuda:0 will be used for training
# 2025-10-20 12:24:25,682: Loading basin data into xarray data set.
# 2025-10-20 12:24:25,875: Create lookup table and convert to pytorch tensor
# 2025-10-20 12:25:09,349: Epoch 1 average loss: avg_loss: 18.92656, avg_total_loss: 18.92656
# 2025-10-20 12:25:12,215: Epoch 1 average validation loss: 15.67200 -- Median validation metrics: avg_loss: 15.67200, MAPE: 25.31148, NSE: 0.94066, MSE: 32.86459, RMSE: 5.73276
# 2025-10-20 12:25:19,865: Epoch 2 average loss: avg_loss: 12.73320, avg_total_loss: 12.73320
# 2025-10-20 12:25:22,124: Epoch 2 average validation loss: 13.86404 -- Median validation metrics: avg_loss: 13.86404, MAPE: 24.23117, NSE: 0.93587, MSE: 35.51400, RMSE: 5.95936
# 2025-10-20 12:25:29,420: Epoch 3 average loss: avg_loss: 11.53908, avg_total_loss: 11.53908
# 2025-10-20 12:25:31,394: Epoch 3 average validation loss: 12.76011 -- Median validation metrics: avg_loss: 12.76011, MAPE: 20.12816, NSE: 0.94837, MSE: 28.59200, RMSE: 5.34715
# 2025-10-20 12:25:38,593: Epoch 4 average loss: avg_loss: 10.68619, avg_total_loss: 10.68619
# 2025-10-20 12:25:40,796: Epoch 4 average validation loss: 13.39009 -- Median validation metrics: avg_loss: 13.39009, MAPE: 36.39430, NSE: 0.95690, MSE: 23.87040, RMSE: 4.88573
# 2025-10-20 12:25:48,053: Epoch 5 average loss: avg_loss: 10.00130, avg_total_loss: 10.00130
# 2025-10-20 12:25:50,001: Epoch 5 average validation loss: 12.05698 -- Median validation metrics: avg_loss: 12.05698, MAPE: 16.60655, NSE: 0.95944, MSE: 22.46407, RMSE: 4.73963
# 2025-10-20 12:25:56,980: Epoch 6 average loss: avg_loss: 9.55311, avg_total_loss: 9.55311
# 2025-10-20 12:25:58,883: Epoch 6 average validation loss: 11.51021 -- Median validation metrics: avg_loss: 11.51021, MAPE: 15.41731, NSE: 0.95150, MSE: 26.85888, RMSE: 5.18255
# 2025-10-20 12:26:06,488: Epoch 7 average loss: avg_loss: 9.22387, avg_total_loss: 9.22387
# 2025-10-20 12:26:08,372: Epoch 7 average validation loss: 12.34220 -- Median validation metrics: avg_loss: 12.34220, MAPE: 30.72393, NSE: 0.95568, MSE: 24.54570, RMSE: 4.95436
# 2025-10-20 12:26:16,052: Epoch 8 average loss: avg_loss: 8.79355, avg_total_loss: 8.79355
# 2025-10-20 12:26:18,134: Epoch 8 average validation loss: 10.75824 -- Median validation metrics: avg_loss: 10.75824, MAPE: 14.57850, NSE: 0.96641, MSE: 18.60078, RMSE: 4.31286
# 2025-10-20 12:29:52,105: Epoch 29 average validation loss: 10.75771 -- Median validation metrics: avg_loss: 10.75771, MAPE: 12.40536, NSE: 0.96741, MSE: 18.04868, RMSE: 4.24837
# 2025-10-20 12:30:00,102: Epoch 30 average loss: avg_loss: 5.04316, avg_total_loss: 5.04316
# 2025-10-20 12:30:02,506: Epoch 30 average validation loss: 10.86164 -- Median validation metrics: avg_loss: 10.86164, MAPE: 12.68282, NSE: 0.96552, MSE: 19.09721, RMSE: 4.37004
# 2025-10-20 12:30:10,403: Epoch 31 average loss: avg_loss: 5.02327, avg_total_loss: 5.02327
# 2025-10-20 12:30:12,863: Epoch 31 average validation loss: 11.09308 -- Median validation metrics: avg_loss: 11.09308, MAPE: 13.64826, NSE: 0.96561, MSE: 19.04514, RMSE: 4.36407
# 2025-10-20 12:30:20,851: Epoch 32 average loss: avg_loss: 5.00599, avg_total_loss: 5.00599
# 2025-10-20 12:30:23,089: Epoch 32 average validation loss: 10.92007 -- Median validation metrics: avg_loss: 10.92007, MAPE: 12.17696, NSE: 0.96612, MSE: 18.76480, RMSE: 4.33184
# 2025-10-20 12:30:31,461: Epoch 33 average loss: avg_loss: 4.97427, avg_total_loss: 4.97427
# 2025-10-20 12:30:33,885: Epoch 33 average validation loss: 10.97654 -- Median validation metrics: avg_loss: 10.97654, MAPE: 13.72371, NSE: 0.96581, MSE: 18.93601, RMSE: 4.35155
# 2025-10-20 12:30:41,649: Epoch 34 average loss: avg_loss: 4.93846, avg_total_loss: 4.93846
# 2025-10-20 12:30:43,974: Epoch 34 average validation loss: 11.52466 -- Median validation metrics: avg_loss: 11.52466, MAPE: 19.80369, NSE: 0.96563, MSE: 19.03268, RMSE: 4.36265
# 2025-10-20 12:30:43,975: Early stopping triggered at epoch 34 with validation loss 11.52466. Training stopped.
# ==================================
#   Training ended successfully !
# ==================================

# %% [markdown]
# ### Plot of the Loss and Metrics

# %%
# Path to your output.log file
log_path = Path(f"{cfg.base_run_dir}/{runFile}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path)

print("Plotting the losses and metrics throughout the training process: ")
plot_training_curves(train_df, val_df)
plot_validation_metrics(val_df)
# Out:
# ✅ Parsed 38 training epochs and 38 validation evaluations.
# Plotting the losses and metrics throughout the training process:

# %% [markdown]
# ---

# %% [markdown]
# ## Evaluation on the **TEST** Dataset
# The run directory that needs to be specified for evaluation is printed in the output log above. Since the folder name is created dynamically (including the date and time of the start of the run) you will need to change the `run_dir` argument according to your local directory name. By default, it will use the same device as during the training process.

# %%
run_dir = Path(f"{cfg.base_run_dir}/{runFile}")

if Evaluation_TEST:
    print(" Starting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test")
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")
# Out:
#  Testing process skipped !

# %% [markdown]
# ---

# %% [markdown]
# ### Load and inspect model predictions
# Next, we load the results file and compare the model predictions with observations. The results file is always a pickled dictionary with one key per basin (even for a single basin). The next-lower dictionary level is the temporal resolution of the predictions.
#
# In this case, we trained a model only on daily data ('1D'). Within the temporal resolution, the next-lower dictionary level are `xr`(an xarray Dataset that contains observations and predictions), as well as one key for each metric that was specified in the config file.
#
# NOTE: The data variables in the xarray Dataset are named according to the name of the target variables, with suffix `_obs` for the observations and suffix `_sim` for the simulations.

# %%
# model_str = f"model_epoch{str(cfg.epochs).zfill(3)}"
model_str = f"model_epoch030"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
basin = "massa"
# results.keys()
results[basin]['1h']
# Out:
# {'xr': <xarray.Dataset> Size: 2MB
#  Dimensions:         (date: 10201, time_step: 24)
#  Coordinates:
#    * date            (date) datetime64[ns] 82kB 2024-04-01T23:00:00 ... 2025-0...
#    * time_step       (time_step) int64 192B -23 -22 -21 -20 -19 ... -4 -3 -2 -1 0
#  Data variables:
#      streamflow_obs  (date, time_step) float32 979kB 1.155 1.146 ... 27.32 26.4
#      streamflow_sim  (date, time_step) float32 979kB 1.415 1.368 ... 29.96 29.47,
#  'MAPE': 14.445847511291504,
#  'NSE': 0.9508161544799805,
#  'MSE': 29.1690673828125,
#  'RMSE': 5.400839507225937}

# %% [markdown]
# ### Plotting model predictions vs observations

# %% [markdown]
# Code for 1h prediction:

# %%
# qobs=results['massa']['1h']['xr']['streamflow_obs']
# qsim=results['massa']['1h']['xr']['streamflow_sim']
# plot_hydrograph(
#     qobs=qobs,
#     qsim=qsim,
#     results=results,
#     basin='massa',
#     freq='1h',
#     plot_peaks=False  # turn on high-flow markers
# )

# %% [markdown]
# Code for 24h predictions:

# %%
from custom.functions.Plot import plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series

xr_ds = results[basin]["1h"]["xr"]
title24 = f"Massa – {cfg.predict_last_n}h | MAPE {results[basin]['1h']['MAPE']:.3f}, NSE {results[basin]['1h']['NSE']:.3f}, RMSE {results[basin]['1h']['MSE']:.3f}"

# last forecast of the horizon vs obs
plot_forecast_24h(xr_ds, title=title24).show()
# All spaghetti forecasts
# plot_forecast_24h(xr_ds, mode="spaghetti").show()

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
plot_forecast_horizon_24h(
    xr_ds,
    issue_date="2024-08-10 00:00:00"
).show()
plot_forecast_horizon_24h(
    xr_ds,
    issue_date="2024-08-10 01:00:00"
).show()

# %%
plot_forecast_horizon_series(
    xr_ds,
    issue_date="2024-06-10 00:00:00",
    n_forecasts=5
).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores
# Next, we are going to compute all metrics that are implemented in the NeuralHydrology package. You will find additional hydrological signatures implemented in `neuralhydrology.evaluation.signatures`.

# %%
qobs=results[basin]['1h']['xr']['streamflow_obs']
qsim=results[basin]['1h']['xr']['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.951
# MSE: 29.169
# RMSE: 5.401
# KGE: 0.898
# Alpha-NSE: 0.919
# Beta-KGE: 0.942
# Beta-NSE: -0.041
# Pearson-r: 0.978
# FHV: -8.906
# FMS: -0.063
# FLV: -1872.925
# Peak-Timing: nan
# Peak-MAPE: 21.589
# MAPE: 14.447
