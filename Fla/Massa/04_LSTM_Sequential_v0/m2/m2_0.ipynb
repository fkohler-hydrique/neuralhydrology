# %% [markdown]
# #  Run of Model **$X$** on the App **MASSA**
#
# **Paramaters**
# The parameters of all models should be available in the parent folder, in an EXCEL file.

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
import torch

from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run
from neuralhydrology.datasetzoo import register_dataset

# %% [markdown]
# ### Adding our Dataset | Metrics | Models

# %%
from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)
from neuralhydrology.utils.config import Config

# Custom functions plot_training_curves
from custom.functions.Plot import plot_hydrograph, plot_training_curves, plot_validation_metrics
from custom.functions.utils_fla import parse_neuralhydrology_log

# %% [markdown]
# ---

# %% [markdown]
# ### Run parameters

# %%
configPath = Path("m2_0.yml")

runFile = "m2_base"

cfg = Config(configPath)
TRAIN = True
Evaluation_TEST =  False

# %% [markdown]
# ---
# ## **Training**

# %%
import pandas as pd
csv_path = r"..\..\data\massa_2.csv"
data = pd.read_csv(csv_path)
# print("Columns of the csv:  ", data.columns)
# print(data.dtypes)
# data['date'] = pd.to_datetime(data['date'])


# print some information about the dataset

# print(data.head())
# print(data.describe())

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    # by default we assume that you have at least one cuda-capable nvidia gpu or macos with metal support
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        start_run(config_file=Path(configPath))
    # fall back to cpu-only mode
    else:
        print("Using CPU")
        start_run(config_file=Path(configPath), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-10-23 10:58:43,411: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m2_2310_105843\output.log initialized.
# 2025-10-23 10:58:43,413: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m2_2310_105843
# 2025-10-23 10:58:43,413: ### Run configurations for m2
# 2025-10-23 10:58:43,414: experiment_name: m2
# 2025-10-23 10:58:43,414: base_run_dir: runs
# 2025-10-23 10:58:43,415: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m2_2310_105843\train_data
# 2025-10-23 10:58:43,415: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m2_2310_105843\img_log
# 2025-10-23 10:58:43,416: seed: 42
# 2025-10-23 10:58:43,416: device: cuda:0
# 2025-10-23 10:58:43,417: num_workers: 16
# 2025-10-23 10:58:43,417: data_dir: ..\..\data
# 2025-10-23 10:58:43,418: dataset: swisshourly
# 2025-10-23 10:58:43,418: train_basin_file: ..\..\data\basins_2.txt
# 2025-10-23 10:58:43,419: validation_basin_file: ..\..\data\basins_2.txt
# 2025-10-23 10:58:43,420: test_basin_file: ..\..\data\basins_2.txt
# 2025-10-23 10:58:43,420: train_start_date: 2020-03-01 00:00:00
# 2025-10-23 10:58:43,421: train_end_date: 2023-02-28 00:00:00
# 2025-10-23 10:58:43,421: validation_start_date: 2023-03-01 00:00:00
# 2025-10-23 10:58:43,422: validation_end_date: 2024-03-31 00:00:00
# 2025-10-23 10:58:43,422: test_start_date: 2024-04-01 00:00:00
# 2025-10-23 10:58:43,423: test_end_date: 2025-08-10 00:00:00
# 2025-10-23 10:58:43,424: dynamic_inputs: ['streamflow_hindcast', 'null_values', 'prec_bruchji', 'pv_eggishorn', 'fc_prec_eggishorn', 'temp_binn', 'temp_eggishorn', 'temp_mean_6h', 'fc_temp_mean_6h', 'fc_prec_bruchji', 'fc_temp_binn', 'fc_temp_eggishorn', 'ray_visp', 'ray_eggishorn', 'temp_mean_degree_day', 'fc_temp_mean_degree_day', 'is_Tmean_snow', 'fc_is_Tmean_snow', 'daylight', 'hr']
# 2025-10-23 10:58:43,424: hindcast_inputs: ['streamflow_hindcast', 'prec_bruchji', 'temp_binn', 'temp_eggishorn', 'temp_mean_6h', 'ray_visp', 'ray_eggishorn', 'temp_mean_degree_day', 'is_Tmean_snow', 'daylight', 'hr']
# 2025-10-23 10:58:43,425: forecast_inputs: ['null_values', 'fc_prec_bruchji', 'fc_temp_binn', 'fc_temp_eggishorn', 'fc_temp_mean_6h', 'ray_visp', 'ray_eggishorn', 'fc_temp_mean_degree_day', 'fc_is_Tmean_snow', 'daylight', 'hr']
# 2025-10-23 10:58:43,425: forecast_seq_length: 24
# 2025-10-23 10:58:43,426: forecast_overlap: None
# 2025-10-23 10:58:43,427: timestep_counter: True
# 2025-10-23 10:58:43,427: target_variables: ['streamflow']
# 2025-10-23 10:58:43,428: clip_targets_to_zero: ['streamflow']
# 2025-10-23 10:58:43,428: model: sequential_forecast_lstm
# 2025-10-23 10:58:43,429: head: regression
# 2025-10-23 10:58:43,429: hidden_size: 128
# 2025-10-23 10:58:43,430: num_layers: 1
# 2025-10-23 10:58:43,430: seq_length: 150
# 2025-10-23 10:58:43,430: predict_last_n: 24
# 2025-10-23 10:58:43,431: output_activation: linear
# 2025-10-23 10:58:43,432: output_dropout: 0.07
# 2025-10-23 10:58:43,432: initial_forget_bias: 2.6
# 2025-10-23 10:58:43,432: epochs: 1000
# 2025-10-23 10:58:43,433: learning_rate: 0.001
# 2025-10-23 10:58:43,433: batch_size: 32
# 2025-10-23 10:58:43,433: optimizer: AdamW
# 2025-10-23 10:58:43,434: loss: custom_loss
# 2025-10-23 10:58:43,434: clip_gradient_norm: 5.0
# 2025-10-23 10:58:43,434: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-10-23 10:58:43,435: validate_every: 1
# 2025-10-23 10:58:43,435: validate_n_random_basins: 1
# 2025-10-23 10:58:43,435: early_stopping: True
# 2025-10-23 10:58:43,435: patience_early_stopping: 15
# 2025-10-23 10:58:43,437: minimum_epochs_before_early_stopping: 20
# 2025-10-23 10:58:43,437: min_delta_early_stopping: 5e-07
# 2025-10-23 10:58:43,437: dynamic_learning_rate: True
# 2025-10-23 10:58:43,438: patience_dynamic_learning_rate: 6
# 2025-10-23 10:58:43,438: factor_dynamic_learning_rate: 0.4
# 2025-10-23 10:58:43,439: log_interval: 10
# 2025-10-23 10:58:43,439: log_n_figures: 1
# 2025-10-23 10:58:43,439: log_tensorboard: True
# 2025-10-23 10:58:43,440: save_train_data: False
# 2025-10-23 10:58:43,441: save_validation_results: False
# 2025-10-23 10:58:43,441: save_all_output: False
# 2025-10-23 10:58:43,441: save_weights_every: 5
# 2025-10-23 10:58:43,442: verbose: 1
# 2025-10-23 10:58:43,442: nan_handling_method: masked_mean
# 2025-10-23 10:58:43,442: nan_step_probability: 0.0
# 2025-10-23 10:58:43,443: nan_sequence_probability: 0.0
# 2025-10-23 10:58:43,443: nan_handling_pos_encoding_size: 0
# 2025-10-23 10:58:43,444: number_of_basins: 1
# 2025-10-23 10:58:43,444: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m2_2310_105843
# 2025-10-23 10:58:43,449: ### Device cuda:0 will be used for training
# 2025-10-23 10:58:43,450: Loading basin data into xarray data set.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 6
#       4 if torch.cuda.is_available() or torch.backends.mps.is_available():
#       5     print("Using GPU")
# ----> 6     start_run(config_file=Path(configPath))
#       7 # fall back to cpu-only mode
#       8 else:
#       9     print("Using CPU")
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\nh_run.py:77, in start_run(config_file, gpu)
#      74 if gpu is not None and gpu < 0:
#      75     config.device = "cpu"
# ---> 77 start_training(config)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\train.py:19, in start_training(cfg)
#      17 else:
#      18     raise ValueError(f"Unknown head {cfg.head}.")
# ---> 19 trainer.initialize_training()
#      20 trainer.train_and_validate()
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\basetrainer.py:156, in BaseTrainer.initialize_training(self)
#     153     self._scaler = load_scaler(self.cfg.base_run_dir)
#     155 # Initialize dataset before the model is loaded.
# --> 156 ds = self._get_dataset()
#     157 # print(f"Dataset length: {len(ds)}")
#     158 if len(ds) == 0:
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\basetrainer.py:88, in BaseTrainer._get_dataset(self)
#      87 def _get_dataset(self) -> BaseDataset:
# ---> 88     return get_dataset(cfg=self.cfg, period="train", is_train=True, scaler=self._scaler)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\datasetzoo\__init__.py:71, in get_dataset(cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#      26 """Get data set instance, depending on the run configuration.
#      27
#      28 Currently implemented datasets are 'caravan', 'camels_aus', 'camels_br', 'camels_cl', 'camels_de', 'camels_gb',
#    (...)     67     If no data set class is implemented for the 'dataset' argument in the config.
#      68 """
#      69 global _datasetZooRegistry
# ---> 71 return _datasetZooRegistry.instantiate_dataset(cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\datasetzoo\datasetregistry.py:92, in DatasetRegistry.instantiate_dataset(self, cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#      89 if Dataset is None:
#      90     raise NotImplementedError(f"No dataset class implemented for dataset {cfg.dataset}")
# ---> 92 return Dataset(cfg=cfg,
#      93                is_train=is_train,
#      94                period=period,
#      95                basin=basin,
#      96                additional_features=additional_features,
#      97                id_to_int=id_to_int,
#      98                scaler=scaler)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\custom\dataset\swisshourly.py:39, in SwissHourly.__init__(self, cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#      29 def __init__(
#      30     self,
#      31     cfg: Config,
#    (...)     37     scaler: Dict[str, Union[pd.Series, xr.DataArray]] = None,
#      38 ):
# ---> 39     super().__init__(
#      40         cfg=cfg,
#      41         is_train=is_train,
#      42         period=period,
#      43         basin=basin,
#      44         additional_features=additional_features or [],
#      45         id_to_int=id_to_int or {},
#      46         scaler=scaler or {},
#      47     )
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\datasetzoo\basedataset.py:141, in BaseDataset.__init__(self, cfg, is_train, period, basin, additional_features, id_to_int, scaler)
#     139         self._create_id_to_int()
#     140 # load and preprocess data
# --> 141 self._load_data()
#     142 if self.is_train:
#     143     self._dump_scaler()
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\datasetzoo\basedataset.py:778, in BaseDataset._load_data(self)
#     774 def _load_data(self):
#     775     # load attributes first to sanity-check those features before doing the compute expensive time series loading
#     776     self._load_combined_attributes()
# --> 778     xr = self._load_or_create_xarray_dataset()
#     780     # if self.cfg.loss.lower() in ['nse', 'weightednse', 'custom_loss']:
#     781         # get the std of the discharge for each basin, which is needed for the (weighted) NSE loss.
#     782     self._calculate_per_basin_std(xr)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\datasetzoo\basedataset.py:365, in BaseDataset._load_or_create_xarray_dataset(self)
#     363     LOGGER.info("Loading basin data into xarray data set.")
#     364 for basin in tqdm(self.basins, file=sys.stdout, disable=self._disable_pbar,  leave=False): #file=sys.stdout,
# --> 365     df = self._load_basin_data(basin)
#     366     # print("Basin data loaded !")
#     367     if self.cfg.target_normalization is not None:
#     368         # print("checkpoint 1")
#     369         # print("Applying target normalization")
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\custom\dataset\swisshourly.py:138, in SwissHourly._load_basin_data(self, basin)
#     136 missing = [c for c in required_dyn if c not in df.columns and c not in rolling_derived]
#     137 if missing:
# --> 138     raise KeyError(f"Missing required dynamic input(s) for basin {basin}: {missing}")
#     139 # print("No missing")
#     140 # Now compute the keep_cols as BaseDataset will expect (mirrors BaseDataset logic)
#     141 if isinstance(self.cfg.dynamic_inputs, list):
#     142     # print("ouais alors Jacqueline...")
#
# KeyError: "Missing required dynamic input(s) for basin massa_2: ['pv_eggishorn', 'fc_prec_eggishorn', 'hr']"

# %% [markdown]
# ### Plot of the Loss and Metrics

# %%
# Path to your output.log file
log_path = Path(f"{cfg.base_run_dir}/{runFile}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path)

print("Plotting the losses and metrics throughout the training process: ")
plot_training_curves(train_df, val_df)
plot_validation_metrics(val_df)
# Out:
# ✅ Parsed 40 training epochs and 40 validation evaluations.
# Plotting the losses and metrics throughout the training process:

# %% [markdown]
# ---

# %% [markdown]
# ## Evaluation on the **TEST** Dataset
# The run directory that needs to be specified for evaluation is printed in the output log above. Since the folder name is created dynamically (including the date and time of the start of the run) you will need to change the `run_dir` argument according to your local directory name. By default, it will use the same device as during the training process.

# %%
run_dir = Path(f"{cfg.base_run_dir}/{runFile}")

if Evaluation_TEST:
    print(" Starting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test")
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")
# Out:
#  Testing process skipped !

# %% [markdown]
# ---

# %% [markdown]
# ### Load and inspect model predictions
# Next, we load the results file and compare the model predictions with observations. The results file is always a pickled dictionary with one key per basin (even for a single basin). The next-lower dictionary level is the temporal resolution of the predictions.
#
# In this case, we trained a model only on daily data ('1D'). Within the temporal resolution, the next-lower dictionary level are `xr`(an xarray Dataset that contains observations and predictions), as well as one key for each metric that was specified in the config file.
#
# NOTE: The data variables in the xarray Dataset are named according to the name of the target variables, with suffix `_obs` for the observations and suffix `_sim` for the simulations.

# %%
# model_str = f"model_epoch{str(cfg.epochs).zfill(3)}"
model_str = f"model_epoch040"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
basin = "massa_2"
# results.keys()
results[basin]['1h']
# Out:
# {'xr': <xarray.Dataset> Size: 2MB
#  Dimensions:         (date: 11905, time_step: 24)
#  Coordinates:
#    * date            (date) datetime64[ns] 95kB 2024-04-01T23:00:00 ... 2025-0...
#    * time_step       (time_step) int64 192B -23 -22 -21 -20 -19 ... -4 -3 -2 -1 0
#  Data variables:
#      streamflow_obs  (date, time_step) float32 1MB 1.155 1.146 ... 71.21 70.97
#      streamflow_sim  (date, time_step) float32 1MB 1.407 1.229 ... 65.8 63.94,
#  'MAPE': 13.204061508178711,
#  'NSE': 0.9433053731918335,
#  'MSE': 35.90907669067383,
#  'RMSE': 5.992418267333633}

# %% [markdown]
# ### Plotting model predictions vs observations

# %% [markdown]
# Code for 1h prediction:

# %%
# qobs=results['massa']['1h']['xr']['streamflow_obs']
# qsim=results['massa']['1h']['xr']['streamflow_sim']
# plot_hydrograph(
#     qobs=qobs,
#     qsim=qsim,
#     results=results,
#     basin='massa',
#     freq='1h',
#     plot_peaks=False  # turn on high-flow markers
# )

# %% [markdown]
# Code for 24h predictions:

# %%
from custom.functions.Plot import plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series

xr_ds = results[basin]["1h"]["xr"]
title24 = f"Massa – {cfg.predict_last_n}h | MAPE {results[basin]['1h']['MAPE']:.3f}, NSE {results[basin]['1h']['NSE']:.3f}, RMSE {results[basin]['1h']['MSE']:.3f}"

# last forecast of the horizon vs obs
plot_forecast_24h(xr_ds, title=title24).show()
# All spaghetti forecasts
# plot_forecast_24h(xr_ds, mode="spaghetti").show()

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
plot_forecast_horizon_24h(
    xr_ds,
    issue_date="2024-08-10 00:00:00"
).show()
plot_forecast_horizon_24h(
    xr_ds,
    issue_date="2024-08-10 01:00:00"
).show()

# %%
plot_forecast_horizon_series(
    xr_ds,
    issue_date="2024-06-10 00:00:00",
    n_forecasts=10
).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores
# Next, we are going to compute all metrics that are implemented in the NeuralHydrology package. You will find additional hydrological signatures implemented in `neuralhydrology.evaluation.signatures`.

# %%
qobs=results[basin]['1h']['xr']['streamflow_obs']
qsim=results[basin]['1h']['xr']['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.943
# MSE: 35.909
# RMSE: 5.992
# KGE: 0.902
# Alpha-NSE: 0.929
# Beta-KGE: 0.938
# Beta-NSE: -0.052
# Pearson-r: 0.974
# FHV: -8.644
# FMS: -0.569
# FLV: -185.222
# Peak-Timing: nan
# Peak-MAPE: 22.359
# MAPE: 13.204
