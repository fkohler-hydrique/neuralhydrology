# %% [markdown]
# #  Run of Model **$X$** on the App **MASSA**
#
# **Paramaters**
# The parameters of all models should be available in the parent folder, in an EXCEL file.

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
import torch

from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run
from neuralhydrology.datasetzoo import register_dataset

# %% [markdown]
# ### Adding our Dataset | Metrics | Models

# %%
from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)
from neuralhydrology.utils.config import Config

# Custom functions plot_training_curves
from custom.functions.Plot import plot_hydrograph, plot_training_curves, plot_validation_metrics
from custom.functions.utils_fla import parse_neuralhydrology_log

# %% [markdown]
# ---

# %% [markdown]
# ### Run parameters

# %%
configPath = Path("explo.yml")

runFile = "explo"

cfg = Config(configPath)
TRAIN = True
Evaluation_TEST =  False

# %% [markdown]
# ---
# ## **Training**

# %%
import pandas as pd
csv_path = r"..\..\data\massa_2.csv"
data = pd.read_csv(csv_path)

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    # by default we assume that you have at least one cuda-capable nvidia gpu or macos with metal support
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        start_run(config_file=Path(configPath))
    # fall back to cpu-only mode
    else:
        print("Using CPU")
        start_run(config_file=Path(configPath), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-10-29 13:41:49,027: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\explo_2910_134149\output.log initialized.
# 2025-10-29 13:41:49,027: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\explo_2910_134149
# 2025-10-29 13:41:49,028: ### Run configurations for explo
# 2025-10-29 13:41:49,028: experiment_name: explo
# 2025-10-29 13:41:49,029: base_run_dir: runs
# 2025-10-29 13:41:49,030: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\explo_2910_134149\train_data
# 2025-10-29 13:41:49,030: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\explo_2910_134149\img_log
# 2025-10-29 13:41:49,031: seed: 42
# 2025-10-29 13:41:49,031: device: cuda:0
# 2025-10-29 13:41:49,032: num_workers: 16
# 2025-10-29 13:41:49,033: data_dir: ..\..\data
# 2025-10-29 13:41:49,033: dataset: swisshourly
# 2025-10-29 13:41:49,034: train_basin_file: ..\..\data\basins_2_with_rollings.txt
# 2025-10-29 13:41:49,034: validation_basin_file: ..\..\data\basins_2_with_rollings.txt
# 2025-10-29 13:41:49,035: test_basin_file: ..\..\data\basins_2_with_rollings.txt
# 2025-10-29 13:41:49,036: train_start_date: 2020-03-01 00:00:00
# 2025-10-29 13:41:49,036: train_end_date: 2023-02-28 00:00:00
# 2025-10-29 13:41:49,036: validation_start_date: 2023-03-01 00:00:00
# 2025-10-29 13:41:49,037: validation_end_date: 2024-03-31 00:00:00
# 2025-10-29 13:41:49,037: test_start_date: 2024-04-01 00:00:00
# 2025-10-29 13:41:49,037: test_end_date: 2025-07-02 00:00:00
# 2025-10-29 13:41:49,038: dynamic_inputs: ['streamflow_hindcast', 'null_values', 'prec_bruchji', 'fc_prec_bruchji', 'temp_binn', 'temp_binn_roll_sum_24', 'fc_temp_binn', 'fc_temp_binn_roll_sum_24', 'temp_mean_6h', 'fc_temp_mean_6h', 'ray_visp', 'temp_mean_degree_day', 'fc_temp_mean_degree_day', 'is_Tmean_snow', 'fc_is_Tmean_snow', 'daylight', 'hr', 'prec_bruchji_roll_sum_6', 'fc_prec_bruchji_roll_sum_6', 'prec_bruchji_roll_mean_24', 'fc_prec_bruchji_roll_mean_24']
# 2025-10-29 13:41:49,039: hindcast_inputs: ['streamflow_hindcast', 'prec_bruchji', 'temp_binn', 'temp_mean_6h', 'ray_visp', 'temp_mean_degree_day', 'is_Tmean_snow', 'daylight', 'hr', 'temp_binn_roll_sum_24', 'prec_bruchji_roll_sum_6', 'prec_bruchji_roll_mean_24']
# 2025-10-29 13:41:49,039: forecast_inputs: ['null_values', 'fc_prec_bruchji', 'fc_temp_binn', 'fc_temp_mean_6h', 'ray_visp', 'fc_temp_mean_degree_day', 'fc_is_Tmean_snow', 'daylight', 'hr', 'fc_temp_binn_roll_sum_24', 'fc_prec_bruchji_roll_sum_6', 'fc_prec_bruchji_roll_mean_24']
# 2025-10-29 13:41:49,039: forecast_seq_length: 24
# 2025-10-29 13:41:49,040: forecast_overlap: None
# 2025-10-29 13:41:49,040: timestep_counter: True
# 2025-10-29 13:41:49,040: target_variables: ['streamflow']
# 2025-10-29 13:41:49,041: clip_targets_to_zero: ['streamflow']
# 2025-10-29 13:41:49,042: model: sequential_forecast_lstm
# 2025-10-29 13:41:49,042: head: regression
# 2025-10-29 13:41:49,042: hidden_size: 128
# 2025-10-29 13:41:49,043: num_layers: 2
# 2025-10-29 13:41:49,043: seq_length: 200
# 2025-10-29 13:41:49,043: predict_last_n: 24
# 2025-10-29 13:41:49,044: output_activation: linear
# 2025-10-29 13:41:49,044: output_dropout: 0.1
# 2025-10-29 13:41:49,044: initial_forget_bias: 1.5
# 2025-10-29 13:41:49,045: epochs: 1000
# 2025-10-29 13:41:49,045: learning_rate: 0.001
# 2025-10-29 13:41:49,046: batch_size: 64
# 2025-10-29 13:41:49,047: optimizer: AdamW
# 2025-10-29 13:41:49,047: custom_loss: {'losses': ['smape', 'mse', 'nse'], 'weights': [0.7, 0.2, 0.1]}
# 2025-10-29 13:41:49,048: loss: custom_loss
# 2025-10-29 13:41:49,048: clip_gradient_norm: 3.0
# 2025-10-29 13:41:49,049: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-10-29 13:41:49,050: validate_every: 1
# 2025-10-29 13:41:49,051: validate_n_random_basins: 1
# 2025-10-29 13:41:49,051: early_stopping: True
# 2025-10-29 13:41:49,051: patience_early_stopping: 20
# 2025-10-29 13:41:49,052: minimum_epochs_before_early_stopping: 20
# 2025-10-29 13:41:49,052: min_delta_early_stopping: 5e-07
# 2025-10-29 13:41:49,052: dynamic_learning_rate: True
# 2025-10-29 13:41:49,053: patience_dynamic_learning_rate: 5
# 2025-10-29 13:41:49,053: factor_dynamic_learning_rate: 0.2
# 2025-10-29 13:41:49,054: log_interval: 10
# 2025-10-29 13:41:49,054: log_n_figures: 1
# 2025-10-29 13:41:49,055: log_tensorboard: True
# 2025-10-29 13:41:49,055: save_train_data: False
# 2025-10-29 13:41:49,055: save_validation_results: False
# 2025-10-29 13:41:49,056: save_all_output: False
# 2025-10-29 13:41:49,056: save_weights_every: 5
# 2025-10-29 13:41:49,057: verbose: 1
# 2025-10-29 13:41:49,058: nan_handling_method: masked_mean
# 2025-10-29 13:41:49,058: nan_step_probability: 0.0
# 2025-10-29 13:41:49,059: nan_sequence_probability: 0.0
# 2025-10-29 13:41:49,059: nan_handling_pos_encoding_size: 0
# 2025-10-29 13:41:49,059: number_of_basins: 1
# 2025-10-29 13:41:49,060: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\explo_2910_134149
# 2025-10-29 13:41:49,063: ### Device cuda:0 will be used for training
# 2025-10-29 13:41:49,064: Loading basin data into xarray data set.
# 2025-10-29 13:41:49,998: Calculating target variable stds per basin
# 2025-10-29 13:41:50,018: Create lookup table and convert to pytorch tensor
# 2025-10-29 13:42:44,682: Epoch 1 average loss: avg_loss: 14.95330, avg_total_loss: 14.95330
# 2025-10-29 13:42:49,329: Epoch 1 average validation loss: 10.50082 -- Median validation metrics: avg_loss: 10.50082, MAPE: 24.00639, NSE: 0.96081, MSE: 21.70389, RMSE: 4.65874
# 2025-10-29 13:43:01,067: Epoch 2 average loss: avg_loss: 9.23490, avg_total_loss: 9.23490
# 2025-10-29 13:43:04,771: Epoch 2 average validation loss: 11.10881 -- Median validation metrics: avg_loss: 11.10881, MAPE: 25.51219, NSE: 0.95077, MSE: 27.26521, RMSE: 5.22161
# 2025-10-29 13:43:17,651: Epoch 3 average loss: avg_loss: 8.26483, avg_total_loss: 8.26483
# 2025-10-29 13:43:21,448: Epoch 3 average validation loss: 9.67851 -- Median validation metrics: avg_loss: 9.67851, MAPE: 37.63979, NSE: 0.96321, MSE: 20.37379, RMSE: 4.51373
# 2025-10-29 13:43:33,836: Epoch 4 average loss: avg_loss: 7.59645, avg_total_loss: 7.59645
# 2025-10-29 13:43:37,545: Epoch 4 average validation loss: 9.15613 -- Median validation metrics: avg_loss: 9.15613, MAPE: 20.31087, NSE: 0.95722, MSE: 23.69175, RMSE: 4.86742
# 2025-10-29 13:43:50,001: Epoch 5 average loss: avg_loss: 7.11738, avg_total_loss: 7.11738
# 2025-10-29 13:43:54,018: Epoch 5 average validation loss: 9.54483 -- Median validation metrics: avg_loss: 9.54483, MAPE: 19.80550, NSE: 0.95114, MSE: 27.06082, RMSE: 5.20200
# 2025-10-29 13:44:06,781: Epoch 6 average loss: avg_loss: 6.64980, avg_total_loss: 6.64980
# 2025-10-29 13:44:10,851: Epoch 6 average validation loss: 8.66996 -- Median validation metrics: avg_loss: 8.66996, MAPE: 20.01908, NSE: 0.95935, MSE: 22.51160, RMSE: 4.74464
# 2025-10-29 13:44:23,756: Epoch 7 average loss: avg_loss: 6.32320, avg_total_loss: 6.32320
# 2025-10-29 13:44:27,670: Epoch 7 average validation loss: 8.75203 -- Median validation metrics: avg_loss: 8.75203, MAPE: 19.05541, NSE: 0.96500, MSE: 19.38266, RMSE: 4.40257
# 2025-10-29 13:44:40,488: Epoch 8 average loss: avg_loss: 5.95173, avg_total_loss: 5.95173
# 2025-10-29 13:44:44,463: Epoch 8 average validation loss: 8.76861 -- Median validation metrics: avg_loss: 8.76861, MAPE: 20.09746, NSE: 0.96471, MSE: 19.54439, RMSE: 4.42090
# 2025-10-29 13:44:56,586: Epoch 9 average loss: avg_loss: 5.59564, avg_total_loss: 5.59564
# 2025-10-29 13:45:00,283: Epoch 9 average validation loss: 8.99958 -- Median validation metrics: avg_loss: 8.99958, MAPE: 20.48314, NSE: 0.95765, MSE: 23.45256, RMSE: 4.84278
# 2025-10-29 13:45:12,654: Epoch 10 average loss: avg_loss: 5.41961, avg_total_loss: 5.41961
# 2025-10-29 13:45:16,366: Epoch 10 average validation loss: 8.81534 -- Median validation metrics: avg_loss: 8.81534, MAPE: 17.87263, NSE: 0.96768, MSE: 17.89865, RMSE: 4.23068
# 2025-10-29 13:45:28,837: Epoch 11 average loss: avg_loss: 5.08923, avg_total_loss: 5.08923
# 2025-10-29 13:45:32,533: Epoch 11 average validation loss: 8.63479 -- Median validation metrics: avg_loss: 8.63479, MAPE: 18.70021, NSE: 0.96019, MSE: 22.05036, RMSE: 4.69578
# 2025-10-29 13:45:44,193: Epoch 12 average loss: avg_loss: 4.86675, avg_total_loss: 4.86675
# 2025-10-29 13:45:47,764: Epoch 12 average validation loss: 8.77881 -- Median validation metrics: avg_loss: 8.77881, MAPE: 16.66035, NSE: 0.95757, MSE: 23.49640, RMSE: 4.84731
# 2025-10-29 13:45:47,766: [Scheduler] - Learning rate changed from 1.0e-03 to 2.0e-04
# 2025-10-29 13:45:59,833: Epoch 13 average loss: avg_loss: 3.82045, avg_total_loss: 3.82045
# 2025-10-29 13:46:03,925: Epoch 13 average validation loss: 8.37664 -- Median validation metrics: avg_loss: 8.37664, MAPE: 17.70425, NSE: 0.96252, MSE: 20.75859, RMSE: 4.55616
# 2025-10-29 13:46:16,794: Epoch 14 average loss: avg_loss: 3.63105, avg_total_loss: 3.63105
# 2025-10-29 13:46:20,629: Epoch 14 average validation loss: 8.55404 -- Median validation metrics: avg_loss: 8.55404, MAPE: 15.51671, NSE: 0.96123, MSE: 21.47183, RMSE: 4.63377
# 2025-10-29 13:46:32,914: Epoch 15 average loss: avg_loss: 3.53786, avg_total_loss: 3.53786
# 2025-10-29 13:46:36,480: Epoch 15 average validation loss: 8.51845 -- Median validation metrics: avg_loss: 8.51845, MAPE: 16.10862, NSE: 0.95966, MSE: 22.34277, RMSE: 4.72681
# 2025-10-29 13:46:48,055: Epoch 16 average loss: avg_loss: 3.46670, avg_total_loss: 3.46670
# 2025-10-29 13:46:51,534: Epoch 16 average validation loss: 8.53870 -- Median validation metrics: avg_loss: 8.53870, MAPE: 18.36188, NSE: 0.96135, MSE: 21.40459, RMSE: 4.62651
# 2025-10-29 13:47:04,035: Epoch 17 average loss: avg_loss: 3.38942, avg_total_loss: 3.38942
# 2025-10-29 13:47:08,091: Epoch 17 average validation loss: 8.67792 -- Median validation metrics: avg_loss: 8.67792, MAPE: 15.43055, NSE: 0.95912, MSE: 22.64096, RMSE: 4.75825
# 2025-10-29 13:47:21,383: Epoch 18 average loss: avg_loss: 3.33087, avg_total_loss: 3.33087
# 2025-10-29 13:47:26,375: Epoch 18 average validation loss: 8.61937 -- Median validation metrics: avg_loss: 8.61937, MAPE: 15.44038, NSE: 0.96013, MSE: 22.08113, RMSE: 4.69906
# 2025-10-29 13:47:40,329: Epoch 19 average loss: avg_loss: 3.25768, avg_total_loss: 3.25768
# 2025-10-29 13:47:44,251: Epoch 19 average validation loss: 8.81742 -- Median validation metrics: avg_loss: 8.81742, MAPE: 17.44055, NSE: 0.96112, MSE: 21.52996, RMSE: 4.64004
# 2025-10-29 13:47:57,620: Epoch 20 average loss: avg_loss: 3.23513, avg_total_loss: 3.23513
# 2025-10-29 13:48:04,329: Epoch 20 average validation loss: 8.82989 -- Median validation metrics: avg_loss: 8.82989, MAPE: 19.73670, NSE: 0.95962, MSE: 22.36482, RMSE: 4.72915
# 2025-10-29 13:48:16,314: Epoch 21 average loss: avg_loss: 3.18745, avg_total_loss: 3.18745
# 2025-10-29 13:48:19,956: Epoch 21 average validation loss: 8.75530 -- Median validation metrics: avg_loss: 8.75530, MAPE: 15.53374, NSE: 0.95909, MSE: 22.65512, RMSE: 4.75974
# 2025-10-29 13:48:19,957: [Scheduler] - Learning rate changed from 2.0e-04 to 4.0e-05
# 2025-10-29 13:48:31,901: Epoch 22 average loss: avg_loss: 2.97600, avg_total_loss: 2.97600
# 2025-10-29 13:48:36,224: Epoch 22 average validation loss: 8.65739 -- Median validation metrics: avg_loss: 8.65739, MAPE: 16.02600, NSE: 0.95992, MSE: 22.19459, RMSE: 4.71111
# 2025-10-29 13:48:49,363: Epoch 23 average loss: avg_loss: 2.93602, avg_total_loss: 2.93602
# 2025-10-29 13:48:53,232: Epoch 23 average validation loss: 8.66619 -- Median validation metrics: avg_loss: 8.66619, MAPE: 16.75036, NSE: 0.95992, MSE: 22.19553, RMSE: 4.71121
# 2025-10-29 13:49:06,238: Epoch 24 average loss: avg_loss: 2.92192, avg_total_loss: 2.92192
# 2025-10-29 13:49:11,320: Epoch 24 average validation loss: 8.61748 -- Median validation metrics: avg_loss: 8.61748, MAPE: 15.34421, NSE: 0.96004, MSE: 22.13059, RMSE: 4.70432
# 2025-10-29 13:49:26,837: Epoch 25 average loss: avg_loss: 2.90496, avg_total_loss: 2.90496
# 2025-10-29 13:49:31,494: Epoch 25 average validation loss: 8.61896 -- Median validation metrics: avg_loss: 8.61896, MAPE: 15.55463, NSE: 0.95979, MSE: 22.26657, RMSE: 4.71875
# 2025-10-29 13:49:44,658: Epoch 26 average loss: avg_loss: 2.89651, avg_total_loss: 2.89651
# 2025-10-29 13:49:48,947: Epoch 26 average validation loss: 8.64410 -- Median validation metrics: avg_loss: 8.64410, MAPE: 15.41303, NSE: 0.95917, MSE: 22.61472, RMSE: 4.75549
# 2025-10-29 13:50:02,454: Epoch 27 average loss: avg_loss: 2.88316, avg_total_loss: 2.88316
# 2025-10-29 13:50:07,059: Epoch 27 average validation loss: 8.64654 -- Median validation metrics: avg_loss: 8.64654, MAPE: 15.35043, NSE: 0.95907, MSE: 22.66668, RMSE: 4.76095
# 2025-10-29 13:50:21,112: Epoch 28 average loss: avg_loss: 2.87476, avg_total_loss: 2.87476
# 2025-10-29 13:50:25,826: Epoch 28 average validation loss: 8.67328 -- Median validation metrics: avg_loss: 8.67328, MAPE: 15.73738, NSE: 0.95933, MSE: 22.52145, RMSE: 4.74568
# 2025-10-29 13:50:39,560: Epoch 29 average loss: avg_loss: 2.85826, avg_total_loss: 2.85826
# 2025-10-29 13:50:44,286: Epoch 29 average validation loss: 8.66067 -- Median validation metrics: avg_loss: 8.66067, MAPE: 16.75095, NSE: 0.95927, MSE: 22.55945, RMSE: 4.74968
# 2025-10-29 13:50:58,292: Epoch 30 average loss: avg_loss: 2.84374, avg_total_loss: 2.84374
# 2025-10-29 13:51:02,758: Epoch 30 average validation loss: 8.66499 -- Median validation metrics: avg_loss: 8.66499, MAPE: 16.00032, NSE: 0.95945, MSE: 22.45720, RMSE: 4.73890
# 2025-10-29 13:51:02,760: [Scheduler] - Learning rate changed from 4.0e-05 to 8.0e-06
# 2025-10-29 13:51:15,850: Epoch 31 average loss: avg_loss: 2.81045, avg_total_loss: 2.81045
# 2025-10-29 13:51:19,937: Epoch 31 average validation loss: 8.66810 -- Median validation metrics: avg_loss: 8.66810, MAPE: 15.37578, NSE: 0.95932, MSE: 22.53135, RMSE: 4.74672
# 2025-10-29 13:51:32,955: Epoch 32 average loss: avg_loss: 2.79905, avg_total_loss: 2.79905
# 2025-10-29 13:51:37,770: Epoch 32 average validation loss: 8.66811 -- Median validation metrics: avg_loss: 8.66811, MAPE: 15.52793, NSE: 0.95914, MSE: 22.63143, RMSE: 4.75725
# 2025-10-29 13:51:51,685: Epoch 33 average loss: avg_loss: 2.79425, avg_total_loss: 2.79425
# 2025-10-29 13:51:56,471: Epoch 33 average validation loss: 8.65921 -- Median validation metrics: avg_loss: 8.65921, MAPE: 15.29108, NSE: 0.95904, MSE: 22.68415, RMSE: 4.76279
# 2025-10-29 13:52:09,962: Epoch 34 average loss: avg_loss: 2.80351, avg_total_loss: 2.80351
# 2025-10-29 13:52:15,556: Epoch 34 average validation loss: 8.68008 -- Median validation metrics: avg_loss: 8.68008, MAPE: 15.25863, NSE: 0.95919, MSE: 22.60349, RMSE: 4.75431
# 2025-10-29 13:52:29,072: Epoch 35 average loss: avg_loss: 2.80050, avg_total_loss: 2.80050
# 2025-10-29 13:52:33,471: Epoch 35 average validation loss: 8.66792 -- Median validation metrics: avg_loss: 8.66792, MAPE: 15.26046, NSE: 0.95909, MSE: 22.65463, RMSE: 4.75969
# 2025-10-29 13:52:46,948: Epoch 36 average loss: avg_loss: 2.79063, avg_total_loss: 2.79063
# 2025-10-29 13:52:52,570: Epoch 36 average validation loss: 8.68593 -- Median validation metrics: avg_loss: 8.68593, MAPE: 15.51173, NSE: 0.95925, MSE: 22.56694, RMSE: 4.75047
# 2025-10-29 13:53:06,317: Epoch 37 average loss: avg_loss: 2.79292, avg_total_loss: 2.79292
# 2025-10-29 13:53:10,763: Epoch 37 average validation loss: 8.68568 -- Median validation metrics: avg_loss: 8.68568, MAPE: 15.18630, NSE: 0.95887, MSE: 22.77628, RMSE: 4.77245
# 2025-10-29 13:53:24,170: Epoch 38 average loss: avg_loss: 2.79351, avg_total_loss: 2.79351
# 2025-10-29 13:53:28,129: Epoch 38 average validation loss: 8.67047 -- Median validation metrics: avg_loss: 8.67047, MAPE: 15.31974, NSE: 0.95901, MSE: 22.70370, RMSE: 4.76484
# 2025-10-29 13:53:41,029: Epoch 39 average loss: avg_loss: 2.78834, avg_total_loss: 2.78834
# 2025-10-29 13:53:45,112: Epoch 39 average validation loss: 8.67013 -- Median validation metrics: avg_loss: 8.67013, MAPE: 15.36476, NSE: 0.95899, MSE: 22.71242, RMSE: 4.76576
# 2025-10-29 13:53:45,113: [Scheduler] - Learning rate changed from 8.0e-06 to 1.6e-06
# 2025-10-29 13:53:58,766: Epoch 40 average loss: avg_loss: 2.77413, avg_total_loss: 2.77413
# 2025-10-29 13:54:05,119: Epoch 40 average validation loss: 8.67086 -- Median validation metrics: avg_loss: 8.67086, MAPE: 15.57830, NSE: 0.95893, MSE: 22.74378, RMSE: 4.76904
# 2025-10-29 13:54:17,809: Epoch 41 average loss: avg_loss: 2.77651, avg_total_loss: 2.77651
# 2025-10-29 13:54:22,028: Epoch 41 average validation loss: 8.67837 -- Median validation metrics: avg_loss: 8.67837, MAPE: 15.46002, NSE: 0.95884, MSE: 22.79696, RMSE: 4.77462
# 2025-10-29 13:54:34,912: Epoch 42 average loss: avg_loss: 2.77590, avg_total_loss: 2.77590
# 2025-10-29 13:54:40,652: Epoch 42 average validation loss: 8.67600 -- Median validation metrics: avg_loss: 8.67600, MAPE: 15.34884, NSE: 0.95883, MSE: 22.80212, RMSE: 4.77516
# 2025-10-29 13:54:54,597: Epoch 43 average loss: avg_loss: 2.77161, avg_total_loss: 2.77161
# 2025-10-29 13:54:59,352: Epoch 43 average validation loss: 8.68379 -- Median validation metrics: avg_loss: 8.68379, MAPE: 15.41159, NSE: 0.95893, MSE: 22.74823, RMSE: 4.76951
# 2025-10-29 13:55:12,588: Epoch 44 average loss: avg_loss: 2.77597, avg_total_loss: 2.77597
# 2025-10-29 13:55:16,800: Epoch 44 average validation loss: 8.67184 -- Median validation metrics: avg_loss: 8.67184, MAPE: 15.30149, NSE: 0.95895, MSE: 22.73645, RMSE: 4.76828
# 2025-10-29 13:55:16,801: Early stopping triggered at epoch 44 with validation loss 8.67184. Training stopped.
# ==================================
#   Training ended successfully !
# ==================================

# %%
# python
# Create dataset as you do in the notebook environment and inspect a single sample.
# Assumes `cfg` is your Config instance and dataset registered as 'swisshourly'.
# from neuralhydrology.datasetzoo import get_dataset
# from neuralhydrology.training.basetrainer import BaseTrainer
# basetrainer = BaseTrainer(cfg)
# ds = basetrainer._get_dataset()
# print("cfg.hindcast_inputs_flattened:", cfg.hindcast_inputs_flattened)
# print("cfg.forecast_inputs_flattened:", cfg.forecast_inputs_flattened)
# print("First lookup entries:", ds.lookup_table.info())
# sample = ds[0]
# # sample keys for dynamic groups (names may be 'x_d_hindcast' / 'x_d_forecast' depending on cfg)
# print("sample keys:", list(sample.keys()))
# print("hindcast feature order in sample:", list(sample.get('x_d_hindcast', {}).keys()))
# print("forecast feature order in sample:", list(sample.get('x_d_forecast', {}).keys()))

# %% [markdown]
# ### Plot of the Loss and Metrics

# %%
# Path to your output.log file
log_path = Path(f"{cfg.base_run_dir}/{runFile}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path)

print("Plotting the losses and metrics throughout the training process: ")
plot_training_curves(train_df, val_df)
plot_validation_metrics(val_df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Path to your output.log file
#       2 log_path = Path(f"{cfg.base_run_dir}/{runFile}/output.log")
# ----> 3 train_df, val_df = parse_neuralhydrology_log(log_path)
#       5 print("Plotting the losses and metrics throughout the training process: ")
#       6 plot_training_curves(train_df, val_df)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\custom\functions\utils_fla.py:9, in parse_neuralhydrology_log(log_path)
#       7 """Parse output.log from NeuralHydrology training run."""
#       8 log_path = Path(log_path)
# ----> 9 text = log_path.read_text(encoding="utf-8")
#      11 # Regex patterns
#      12 train_pattern = r"Epoch (\d+) average loss: avg_loss: ([\d\.]+), avg_total_loss: ([\d\.]+)"
#
# File C:\Python313\Lib\pathlib\_local.py:546, in Path.read_text(self, encoding, errors, newline)
#     543 # Call io.text_encoding() here to ensure any warning is raised at an
#     544 # appropriate stack level.
#     545 encoding = io.text_encoding(encoding)
# --> 546 return PathBase.read_text(self, encoding, errors, newline)
#
# File C:\Python313\Lib\pathlib\_abc.py:632, in PathBase.read_text(self, encoding, errors, newline)
#     628 def read_text(self, encoding=None, errors=None, newline=None):
#     629     """
#     630     Open the file in text mode, read it, and close the file.
#     631     """
# --> 632     with self.open(mode='r', encoding=encoding, errors=errors, newline=newline) as f:
#     633         return f.read()
#
# File C:\Python313\Lib\pathlib\_local.py:537, in Path.open(self, mode, buffering, encoding, errors, newline)
#     535 if "b" not in mode:
#     536     encoding = io.text_encoding(encoding)
# --> 537 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'runs\\explo\\output.log'

# %% [markdown]
# ---

# %% [markdown]
# ## Evaluation on the **TEST** Dataset
# The run directory that needs to be specified for evaluation is printed in the output log above. Since the folder name is created dynamically (including the date and time of the start of the run) you will need to change the `run_dir` argument according to your local directory name. By default, it will use the same device as during the training process.

# %%
run_dir = Path(f"{cfg.base_run_dir}/{runFile}")

if Evaluation_TEST:
    print(" Starting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test")
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")
# Out:
#  Testing process skipped !

# %% [markdown]
# ---

# %% [markdown]
# ### Load and inspect model predictions
# Next, we load the results file and compare the model predictions with observations. The results file is always a pickled dictionary with one key per basin (even for a single basin). The next-lower dictionary level is the temporal resolution of the predictions.
#
# In this case, we trained a model only on daily data ('1D'). Within the temporal resolution, the next-lower dictionary level are `xr`(an xarray Dataset that contains observations and predictions), as well as one key for each metric that was specified in the config file.
#
# NOTE: The data variables in the xarray Dataset are named according to the name of the target variables, with suffix `_obs` for the observations and suffix `_sim` for the simulations.

# %%
# model_str = f"model_epoch{str(cfg.epochs).zfill(3)}"
model_str = f"model_epoch015"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
basin = "massa_2"
# results.keys()
results[basin]['1h']
# Out:
# {'xr': <xarray.Dataset> Size: 2MB
#  Dimensions:         (date: 10969, time_step: 24)
#  Coordinates:
#    * date            (date) datetime64[ns] 88kB 2024-04-01T23:00:00 ... 2025-0...
#    * time_step       (time_step) int64 192B -23 -22 -21 -20 -19 ... -4 -3 -2 -1 0
#  Data variables:
#      streamflow_obs  (date, time_step) float32 1MB 1.155 1.146 ... 81.34 77.88
#      streamflow_sim  (date, time_step) float32 1MB 2.377 2.31 ... 86.74 81.75,
#  'MAPE': 16.354454040527344,
#  'NSE': 0.9553975462913513,
#  'MSE': 28.117355346679688,
#  'RMSE': 5.30258006508904}

# %% [markdown]
# ### Plotting model predictions vs observations

# %% [markdown]
# Code for 1h prediction:

# %%
# qobs=results['massa']['1h']['xr']['streamflow_obs']
# qsim=results['massa']['1h']['xr']['streamflow_sim']
# plot_hydrograph(
#     qobs=qobs,
#     qsim=qsim,
#     results=results,
#     basin='massa',
#     freq='1h',
#     plot_peaks=False  # turn on high-flow markers
# )

# %% [markdown]
# Code for 24h predictions:

# %%
from custom.functions.Plot import plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series
from custom.functions.utils_fla import info_results, mape_array, dict_without_xr_key
from custom.functions.Plot import plot_mape_horizon

results_ = results[basin]["1h"]["xr"]
scores = dict_without_xr_key(results[basin]['1h'])

# store only the values in numpy arrays from xarray DataArrays
y_true = results_['streamflow_obs']#.values
y_pred = results_['streamflow_sim']#.values

verb = False
if verb: 
    print("\n-- Calculating MAPE values for each horizon: --\n")
    mapes = mape_array(y_true, y_pred, verbose=verb)
    print("\n-- MAPE calculation per horizon completed. --\n")
else:
    mapes = mape_array(y_true, y_pred, verbose=verb)

# %%
# Example usage (variables `mapes`, `horizons`, and `basin` exist in the notebook):
plot_mape_horizon(
    mapes,
    color="#e76f51",
    title=f"MAPE vs Forecast Horizon for basin {basin}"
)

# %%
from custom.functions.Plot import plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series

scores_str = str.join(', ', [f"{key} : {scores[key]:.2f}" for key in scores])
title24 = f"Massa – {cfg.predict_last_n}h | " + scores_str
plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[1, 6, cfg.predict_last_n])
plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[cfg.predict_last_n])

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
plot_forecast_horizon_24h(
    issue_date="2024-08-10 00:00:00",
    xr_ds=results_
).show()
plot_forecast_horizon_24h(
    issue_date="2024-08-10 01:00:00",
    xr_ds=results_
).show()

# %%
plot_forecast_horizon_series(
    issue_date="2024-06-10 00:00:00",
    xr_ds=results_,
    n_forecasts=10
).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores
# Next, we are going to compute all metrics that are implemented in the NeuralHydrology package. You will find additional hydrological signatures implemented in `neuralhydrology.evaluation.signatures`.

# %%
qobs=results_['streamflow_obs']
qsim=results_['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.955
# MSE: 28.117
# RMSE: 5.303
# KGE: 0.885
# Alpha-NSE: 0.919
# Beta-KGE: 0.921
# Beta-NSE: -0.061
# Pearson-r: 0.981
# FHV: -10.008
# FMS: 1.196
# FLV: 59.255
# Peak-Timing: nan
# Peak-MAPE: 20.880
# MAPE: 16.354

# %%
values = metrics.calculate_all_metrics(qobs.isel(time_step=6), qsim.isel(time_step=6))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.968
# MSE: 19.783
# RMSE: 4.448
# KGE: 0.914
# Alpha-NSE: 0.937
# Beta-KGE: 0.943
# Beta-NSE: -0.044
# Pearson-r: 0.986
# FHV: -7.229
# FMS: 0.140
# FLV: 55.227
# Peak-Timing: nan
# Peak-MAPE: 16.128
# MAPE: 14.979
