# %% [markdown]
# #  Run of Model **$X$** on the App **MASSA**
#
# **Paramaters**
# The parameters of all models should be available in the parent folder, in an EXCEL file.

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
import torch

from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run
from neuralhydrology.datasetzoo import register_dataset

# %% [markdown]
# ### Adding our Dataset | Metrics | Models

# %%
from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)
from neuralhydrology.utils.config import Config

# Custom functions plot_training_curves
from custom.functions.Plot import plot_hydrograph, plot_training_curves, plot_validation_metrics
from custom.functions.utils_fla import parse_neuralhydrology_log

# %% [markdown]
# ---

# %% [markdown]
# ### Run parameters

# %%
configPath = Path("m3.yml")

runFile = "m2_mape_11"

cfg = Config(configPath)
TRAIN = True
Evaluation_TEST =  False

# %% [markdown]
# ---
# ## **Training**

# %%
import pandas as pd
csv_path = r"..\..\data\massa_2.csv"
data = pd.read_csv(csv_path)
# print("Columns of the csv:  ", data.columns)
# print(data.dtypes)
# data['date'] = pd.to_datetime(data['date'])


# print some information about the dataset

# print(data.head())
# print(data.describe())

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    # by default we assume that you have at least one cuda-capable nvidia gpu or macos with metal support
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        start_run(config_file=Path(configPath))
    # fall back to cpu-only mode
    else:
        print("Using CPU")
        start_run(config_file=Path(configPath), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-10-23 15:45:35,926: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m3_2310_154535\output.log initialized.
# 2025-10-23 15:45:35,926: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m3_2310_154535
# 2025-10-23 15:45:35,927: ### Run configurations for m3
# 2025-10-23 15:45:35,927: experiment_name: m3
# 2025-10-23 15:45:35,928: base_run_dir: runs
# 2025-10-23 15:45:35,928: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m3_2310_154535\train_data
# 2025-10-23 15:45:35,929: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m3_2310_154535\img_log
# 2025-10-23 15:45:35,931: seed: 42
# 2025-10-23 15:45:35,931: device: cuda:0
# 2025-10-23 15:45:35,931: num_workers: 16
# 2025-10-23 15:45:35,932: data_dir: ..\..\data
# 2025-10-23 15:45:35,932: dataset: swisshourly
# 2025-10-23 15:45:35,932: train_basin_file: ..\..\data\basins_2.txt
# 2025-10-23 15:45:35,933: validation_basin_file: ..\..\data\basins_2.txt
# 2025-10-23 15:45:35,934: test_basin_file: ..\..\data\basins_2.txt
# 2025-10-23 15:45:35,934: train_start_date: 2020-03-01 00:00:00
# 2025-10-23 15:45:35,934: train_end_date: 2023-02-28 00:00:00
# 2025-10-23 15:45:35,935: validation_start_date: 2023-03-01 00:00:00
# 2025-10-23 15:45:35,935: validation_end_date: 2024-03-31 00:00:00
# 2025-10-23 15:45:35,936: test_start_date: 2024-04-01 00:00:00
# 2025-10-23 15:45:35,937: test_end_date: 2025-08-10 00:00:00
# 2025-10-23 15:45:35,938: dynamic_inputs: ['streamflow_hindcast', 'null_values', 'prec_bruchji', 'temp_binn', 'fc_prec_bruchji', 'fc_temp_binn', 'ray_mean', 'temp_mean_degree_day', 'fc_temp_mean_degree_day', 'is_Tmean_snow', 'fc_is_Tmean_snow', 'hr_sin', 'doy_sin']
# 2025-10-23 15:45:35,938: hindcast_inputs: ['streamflow_hindcast', 'prec_bruchji', 'temp_binn', 'ray_mean', 'temp_mean_degree_day', 'is_Tmean_snow', 'hr_sin', 'doy_sin']
# 2025-10-23 15:45:35,939: forecast_inputs: ['null_values', 'fc_prec_bruchji', 'fc_temp_binn', 'ray_mean', 'fc_temp_mean_degree_day', 'fc_is_Tmean_snow', 'hr_sin', 'doy_sin']
# 2025-10-23 15:45:35,939: forecast_seq_length: 24
# 2025-10-23 15:45:35,940: forecast_overlap: None
# 2025-10-23 15:45:35,940: timestep_counter: True
# 2025-10-23 15:45:35,941: target_variables: ['streamflow']
# 2025-10-23 15:45:35,941: clip_targets_to_zero: ['streamflow']
# 2025-10-23 15:45:35,942: model: sequential_forecast_lstm
# 2025-10-23 15:45:35,943: head: regression
# 2025-10-23 15:45:35,943: hidden_size: 256
# 2025-10-23 15:45:35,943: num_layers: 1
# 2025-10-23 15:45:35,944: seq_length: 1320
# 2025-10-23 15:45:35,944: predict_last_n: 24
# 2025-10-23 15:45:35,944: output_activation: linear
# 2025-10-23 15:45:35,945: output_dropout: 0.01
# 2025-10-23 15:45:35,945: initial_forget_bias: 4
# 2025-10-23 15:45:35,945: epochs: 1000
# 2025-10-23 15:45:35,946: learning_rate: 0.001
# 2025-10-23 15:45:35,946: batch_size: 128
# 2025-10-23 15:45:35,946: optimizer: AdamW
# 2025-10-23 15:45:35,947: custom_loss: {'losses': ['smape', 'nse'], 'weights': [0.7, 0.3]}
# 2025-10-23 15:45:35,947: loss: custom_loss
# 2025-10-23 15:45:35,947: clip_gradient_norm: 3.0
# 2025-10-23 15:45:35,948: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-10-23 15:45:35,949: validate_every: 1
# 2025-10-23 15:45:35,949: validate_n_random_basins: 1
# 2025-10-23 15:45:35,949: early_stopping: True
# 2025-10-23 15:45:35,950: patience_early_stopping: 15
# 2025-10-23 15:45:35,950: minimum_epochs_before_early_stopping: 20
# 2025-10-23 15:45:35,950: min_delta_early_stopping: 5e-07
# 2025-10-23 15:45:35,950: dynamic_learning_rate: True
# 2025-10-23 15:45:35,951: patience_dynamic_learning_rate: 5
# 2025-10-23 15:45:35,951: factor_dynamic_learning_rate: 0.6
# 2025-10-23 15:45:35,951: log_interval: 10
# 2025-10-23 15:45:35,951: log_n_figures: 1
# 2025-10-23 15:45:35,952: log_tensorboard: True
# 2025-10-23 15:45:35,953: save_train_data: False
# 2025-10-23 15:45:35,953: save_validation_results: False
# 2025-10-23 15:45:35,954: save_all_output: False
# 2025-10-23 15:45:35,954: save_weights_every: 5
# 2025-10-23 15:45:35,955: verbose: 1
# 2025-10-23 15:45:35,955: nan_handling_method: masked_mean
# 2025-10-23 15:45:35,956: nan_step_probability: 0.0
# 2025-10-23 15:45:35,956: nan_sequence_probability: 0.0
# 2025-10-23 15:45:35,956: nan_handling_pos_encoding_size: 0
# 2025-10-23 15:45:35,957: number_of_basins: 1
# 2025-10-23 15:45:35,957: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m3_2310_154535
# 2025-10-23 15:45:35,961: ### Device cuda:0 will be used for training
# 2025-10-23 15:45:35,962: Loading basin data into xarray data set.
# 2025-10-23 15:45:36,114: Calculating target variable stds per basin
# 2025-10-23 15:45:36,125: Create lookup table and convert to pytorch tensor
# 2025-10-23 15:46:39,869: Epoch 1 average loss: avg_loss: 50.70044, avg_total_loss: 50.70044
# 2025-10-23 15:46:44,489: Epoch 1 average validation loss: 16.57095 -- Median validation metrics: avg_loss: 16.57095, MAPE: 43.75607, NSE: 0.88627, MSE: 62.98664, RMSE: 7.93641
# 2025-10-23 15:47:10,763: Epoch 2 average loss: avg_loss: 15.91655, avg_total_loss: 15.91655
# 2025-10-23 15:47:15,271: Epoch 2 average validation loss: 19.96357 -- Median validation metrics: avg_loss: 19.96357, MAPE: 50.57740, NSE: 0.84936, MSE: 83.43021, RMSE: 9.13401
# 2025-10-23 15:47:42,116: Epoch 3 average loss: avg_loss: 13.05819, avg_total_loss: 13.05819
# 2025-10-23 15:47:46,504: Epoch 3 average validation loss: 13.49099 -- Median validation metrics: avg_loss: 13.49099, MAPE: 64.41431, NSE: 0.93591, MSE: 35.49472, RMSE: 5.95774
# 2025-10-23 15:48:13,185: Epoch 4 average loss: avg_loss: 11.61662, avg_total_loss: 11.61662
# 2025-10-23 15:48:17,587: Epoch 4 average validation loss: 12.23000 -- Median validation metrics: avg_loss: 12.23000, MAPE: 40.84041, NSE: 0.93441, MSE: 36.32639, RMSE: 6.02714
# 2025-10-23 15:48:43,973: Epoch 5 average loss: avg_loss: 10.97964, avg_total_loss: 10.97964
# 2025-10-23 15:48:48,331: Epoch 5 average validation loss: 12.64078 -- Median validation metrics: avg_loss: 12.64078, MAPE: 79.81499, NSE: 0.94981, MSE: 27.79427, RMSE: 5.27203
# 2025-10-23 15:49:15,621: Epoch 6 average loss: avg_loss: 10.22725, avg_total_loss: 10.22725
# 2025-10-23 15:49:19,980: Epoch 6 average validation loss: 12.57966 -- Median validation metrics: avg_loss: 12.57966, MAPE: 47.86303, NSE: 0.95019, MSE: 27.58627, RMSE: 5.25226
# 2025-10-23 16:04:44,169: Epoch 36 average validation loss: 8.70160 -- Median validation metrics: avg_loss: 8.70160, MAPE: 25.45058, NSE: 0.95685, MSE: 23.89597, RMSE: 4.88835
# 2025-10-23 16:05:13,227: Epoch 37 average loss: avg_loss: 3.63632, avg_total_loss: 3.63632
# 2025-10-23 16:05:18,129: Epoch 37 average validation loss: 8.79671 -- Median validation metrics: avg_loss: 8.79671, MAPE: 22.86569, NSE: 0.95608, MSE: 24.32546, RMSE: 4.93208
# 2025-10-23 16:05:45,186: Epoch 38 average loss: avg_loss: 3.61112, avg_total_loss: 3.61112
# 2025-10-23 16:05:50,021: Epoch 38 average validation loss: 8.39014 -- Median validation metrics: avg_loss: 8.39014, MAPE: 19.26571, NSE: 0.95691, MSE: 23.86696, RMSE: 4.88538
# 2025-10-23 16:06:18,002: Epoch 39 average loss: avg_loss: 3.66673, avg_total_loss: 3.66673
# 2025-10-23 16:06:22,175: Epoch 39 average validation loss: 8.48081 -- Median validation metrics: avg_loss: 8.48081, MAPE: 20.33255, NSE: 0.95650, MSE: 24.09068, RMSE: 4.90823
# 2025-10-23 16:06:49,222: Epoch 40 average loss: avg_loss: 3.59958, avg_total_loss: 3.59958
# 2025-10-23 16:06:53,713: Epoch 40 average validation loss: 8.43025 -- Median validation metrics: avg_loss: 8.43025, MAPE: 17.84851, NSE: 0.95582, MSE: 24.47013, RMSE: 4.94673
# 2025-10-23 16:06:53,714: Early stopping triggered at epoch 40 with validation loss 8.43025. Training stopped.
# ==================================
#   Training ended successfully !
# ==================================

# %% [markdown]
# ### Plot of the Loss and Metrics

# %%
# Path to your output.log file
log_path = Path(f"{cfg.base_run_dir}/{runFile}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path)

print("Plotting the losses and metrics throughout the training process: ")
plot_training_curves(train_df, val_df)
plot_validation_metrics(val_df)
# Out:
# ✅ Parsed 42 training epochs and 42 validation evaluations.
# Plotting the losses and metrics throughout the training process:

# %% [markdown]
# ---

# %% [markdown]
# ## Evaluation on the **TEST** Dataset
# The run directory that needs to be specified for evaluation is printed in the output log above. Since the folder name is created dynamically (including the date and time of the start of the run) you will need to change the `run_dir` argument according to your local directory name. By default, it will use the same device as during the training process.

# %%
run_dir = Path(f"{cfg.base_run_dir}/{runFile}")

if Evaluation_TEST:
    print(" Starting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test")
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")
# Out:
#  Testing process skipped !

# %% [markdown]
# ---

# %% [markdown]
# ### Load and inspect model predictions
# Next, we load the results file and compare the model predictions with observations. The results file is always a pickled dictionary with one key per basin (even for a single basin). The next-lower dictionary level is the temporal resolution of the predictions.
#
# In this case, we trained a model only on daily data ('1D'). Within the temporal resolution, the next-lower dictionary level are `xr`(an xarray Dataset that contains observations and predictions), as well as one key for each metric that was specified in the config file.
#
# NOTE: The data variables in the xarray Dataset are named according to the name of the target variables, with suffix `_obs` for the observations and suffix `_sim` for the simulations.

# %%
# model_str = f"model_epoch{str(cfg.epochs).zfill(3)}"
model_str = f"model_epoch040"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
basin = "massa_2"
# results.keys()
results[basin]['1h']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 4
#       2 model_str = f"model_epoch040"
#       3 testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
# ----> 4 with open(testPath, "rb") as fp:
#       5     results = pickle.load(fp)
#       6 basin = "massa_2"
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'runs\\m2_mape_11\\test\\model_epoch040\\test_results.p'

# %% [markdown]
# ### Plotting model predictions vs observations

# %% [markdown]
# Code for 1h prediction:

# %%
# qobs=results['massa']['1h']['xr']['streamflow_obs']
# qsim=results['massa']['1h']['xr']['streamflow_sim']
# plot_hydrograph(
#     qobs=qobs,
#     qsim=qsim,
#     results=results,
#     basin='massa',
#     freq='1h',
#     plot_peaks=False  # turn on high-flow markers
# )

# %% [markdown]
# Code for 24h predictions:

# %%
from custom.functions.Plot import plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series

xr_ds = results[basin]["1h"]["xr"]
title24 = f"Massa – {cfg.predict_last_n}h | MAPE {results[basin]['1h']['MAPE']:.3f}, NSE {results[basin]['1h']['NSE']:.3f}, RMSE {results[basin]['1h']['MSE']:.3f}"

# last forecast of the horizon vs obs
plot_forecast_24h(xr_ds, title=title24).show()
# All spaghetti forecasts
# plot_forecast_24h(xr_ds, mode="spaghetti").show()

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
plot_forecast_horizon_24h(
    xr_ds,
    issue_date="2024-08-10 00:00:00"
).show()
plot_forecast_horizon_24h(
    xr_ds,
    issue_date="2024-08-10 01:00:00"
).show()

# %%
plot_forecast_horizon_series(
    xr_ds,
    issue_date="2024-06-10 00:00:00",
    n_forecasts=10
).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores
# Next, we are going to compute all metrics that are implemented in the NeuralHydrology package. You will find additional hydrological signatures implemented in `neuralhydrology.evaluation.signatures`.

# %%
qobs=results[basin]['1h']['xr']['streamflow_obs']
qsim=results[basin]['1h']['xr']['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.943
# MSE: 35.909
# RMSE: 5.992
# KGE: 0.902
# Alpha-NSE: 0.929
# Beta-KGE: 0.938
# Beta-NSE: -0.052
# Pearson-r: 0.974
# FHV: -8.644
# FMS: -0.569
# FLV: -185.222
# Peak-Timing: nan
# Peak-MAPE: 22.359
# MAPE: 13.204
