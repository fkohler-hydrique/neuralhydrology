# %% [markdown]
# #  Run of Model **$X$** on the App **MASSA**
#
# **Paramaters**
# The parameters of all models should be available in the parent folder, in an EXCEL file.

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
import torch

from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run
from neuralhydrology.datasetzoo import register_dataset

# %% [markdown]
# ### Adding our Dataset | Metrics | Models

# %%
from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)
from neuralhydrology.utils.config import Config

# Custom functions plot_training_curves
from custom.functions.Plot import plot_hydrograph, plot_training_curves, plot_validation_metrics
from custom.functions.utils_fla import parse_neuralhydrology_log

# %% [markdown]
# ---

# %% [markdown]
# ### Run parameters

# %%
configPath = Path("m2_base.yml")

runFile = "m2_base"

cfg = Config(configPath)
TRAIN = True
Evaluation_TEST =  False # False

# %% [markdown]
# ---
# ## **Training**

# %%
import pandas as pd
csv_path = r"..\..\data\massa_2.csv"
data = pd.read_csv(csv_path)
# print("Columns of the csv:  ", data.columns)
# print(data.dtypes)
# data['date'] = pd.to_datetime(data['date'])


# print some information about the dataset

# print(data.head())
# print(data.describe())

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    # by default we assume that you have at least one cuda-capable nvidia gpu or macos with metal support
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        start_run(config_file=Path(configPath))
    # fall back to cpu-only mode
    else:
        print("Using CPU")
        start_run(config_file=Path(configPath), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-10-28 15:42:14,762: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m2_base_2810_154214\output.log initialized.
# 2025-10-28 15:42:14,763: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m2_base_2810_154214
# 2025-10-28 15:42:14,764: ### Run configurations for m2_base
# 2025-10-28 15:42:14,765: experiment_name: m2_base
# 2025-10-28 15:42:14,765: base_run_dir: runs
# 2025-10-28 15:42:14,766: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m2_base_2810_154214\train_data
# 2025-10-28 15:42:14,766: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m2_base_2810_154214\img_log
# 2025-10-28 15:42:14,767: seed: 42
# 2025-10-28 15:42:14,767: device: cuda:0
# 2025-10-28 15:42:14,768: num_workers: 16
# 2025-10-28 15:42:14,768: data_dir: ..\..\data
# 2025-10-28 15:42:14,768: dataset: swisshourly
# 2025-10-28 15:42:14,769: train_basin_file: ..\..\data\basins_2.txt
# 2025-10-28 15:42:14,769: validation_basin_file: ..\..\data\basins_2.txt
# 2025-10-28 15:42:14,769: test_basin_file: ..\..\data\basins_2.txt
# 2025-10-28 15:42:14,769: train_start_date: 2020-03-01 00:00:00
# 2025-10-28 15:42:14,770: train_end_date: 2023-02-28 00:00:00
# 2025-10-28 15:42:14,771: validation_start_date: 2023-03-01 00:00:00
# 2025-10-28 15:42:14,771: validation_end_date: 2024-03-31 00:00:00
# 2025-10-28 15:42:14,771: test_start_date: 2024-04-01 00:00:00
# 2025-10-28 15:42:14,772: test_end_date: 2025-08-10 00:00:00
# 2025-10-28 15:42:14,772: dynamic_inputs: ['streamflow_hindcast', 'null_values', 'prec_bruchji', 'temp_binn', 'fc_prec_bruchji', 'fc_temp_binn', 'ray_visp', 'temp_mean_degree_day', 'fc_temp_mean_degree_day', 'is_Tmean_snow', 'fc_is_Tmean_snow', 'daylight', 'hr']
# 2025-10-28 15:42:14,773: hindcast_inputs: ['streamflow_hindcast', 'prec_bruchji', 'temp_binn', 'ray_visp', 'temp_mean_degree_day', 'is_Tmean_snow', 'daylight', 'hr']
# 2025-10-28 15:42:14,773: forecast_inputs: ['null_values', 'fc_prec_bruchji', 'fc_temp_binn', 'ray_visp', 'fc_temp_mean_degree_day', 'fc_is_Tmean_snow', 'daylight', 'hr']
# 2025-10-28 15:42:14,773: forecast_seq_length: 24
# 2025-10-28 15:42:14,774: forecast_overlap: None
# 2025-10-28 15:42:14,774: timestep_counter: True
# 2025-10-28 15:42:14,774: target_variables: ['streamflow']
# 2025-10-28 15:42:14,775: clip_targets_to_zero: ['streamflow']
# 2025-10-28 15:42:14,775: model: sequential_forecast_lstm
# 2025-10-28 15:42:14,775: head: regression
# 2025-10-28 15:42:14,776: hidden_size: 128
# 2025-10-28 15:42:14,776: num_layers: 2
# 2025-10-28 15:42:14,776: seq_length: 150
# 2025-10-28 15:42:14,777: predict_last_n: 24
# 2025-10-28 15:42:14,777: output_activation: linear
# 2025-10-28 15:42:14,777: output_dropout: 0.2
# 2025-10-28 15:42:14,778: initial_forget_bias: 2
# 2025-10-28 15:42:14,778: epochs: 1000
# 2025-10-28 15:42:14,778: learning_rate: 0.0001
# 2025-10-28 15:42:14,779: batch_size: 16
# 2025-10-28 15:42:14,779: optimizer: Adam
# 2025-10-28 15:42:14,779: custom_loss: {'losses': ['smape', 'mse', 'nse'], 'weights': [0.6, 0.2, 0.2]}
# 2025-10-28 15:42:14,780: loss: custom_loss
# 2025-10-28 15:42:14,780: clip_gradient_norm: 3.0
# 2025-10-28 15:42:14,781: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-10-28 15:42:14,781: validate_every: 1
# 2025-10-28 15:42:14,782: validate_n_random_basins: 1
# 2025-10-28 15:42:14,782: early_stopping: True
# 2025-10-28 15:42:14,782: patience_early_stopping: 20
# 2025-10-28 15:42:14,783: minimum_epochs_before_early_stopping: 20
# 2025-10-28 15:42:14,783: min_delta_early_stopping: 5e-07
# 2025-10-28 15:42:14,784: dynamic_learning_rate: True
# 2025-10-28 15:42:14,784: patience_dynamic_learning_rate: 5
# 2025-10-28 15:42:14,784: factor_dynamic_learning_rate: 0.4
# 2025-10-28 15:42:14,785: log_interval: 10
# 2025-10-28 15:42:14,785: log_n_figures: 1
# 2025-10-28 15:42:14,786: log_tensorboard: True
# 2025-10-28 15:42:14,786: save_train_data: False
# 2025-10-28 15:42:14,786: save_validation_results: False
# 2025-10-28 15:42:14,787: save_all_output: False
# 2025-10-28 15:42:14,787: save_weights_every: 5
# 2025-10-28 15:42:14,788: verbose: 1
# 2025-10-28 15:42:14,788: nan_handling_method: masked_mean
# 2025-10-28 15:42:14,788: nan_step_probability: 0.0
# 2025-10-28 15:42:14,789: nan_sequence_probability: 0.0
# 2025-10-28 15:42:14,789: nan_handling_pos_encoding_size: 0
# 2025-10-28 15:42:14,790: number_of_basins: 1
# 2025-10-28 15:42:14,790: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs
# 2025-10-28 16:01:33,213: Epoch 47 average loss: avg_loss: 3.30763, avg_total_loss: 3.30763
# 2025-10-28 16:01:36,751: Epoch 47 average validation loss: 8.36384 -- Median validation metrics: avg_loss: 8.36384, MAPE: 15.71006, NSE: 0.94845, MSE: 28.55215, RMSE: 5.34342
# 2025-10-28 16:01:54,204: Epoch 48 average loss: avg_loss: 3.31227, avg_total_loss: 3.31227
# 2025-10-28 16:01:59,282: Epoch 48 average validation loss: 8.35293 -- Median validation metrics: avg_loss: 8.35293, MAPE: 15.72055, NSE: 0.94798, MSE: 28.80954, RMSE: 5.36745
# 2025-10-28 16:02:19,552: Epoch 49 average loss: avg_loss: 3.30892, avg_total_loss: 3.30892
# 2025-10-28 16:02:23,517: Epoch 49 average validation loss: 8.36804 -- Median validation metrics: avg_loss: 8.36804, MAPE: 16.11798, NSE: 0.94839, MSE: 28.58302, RMSE: 5.34631
# 2025-10-28 16:02:40,957: Epoch 50 average loss: avg_loss: 3.29773, avg_total_loss: 3.29773
# 2025-10-28 16:02:44,577: Epoch 50 average validation loss: 8.34472 -- Median validation metrics: avg_loss: 8.34472, MAPE: 16.08706, NSE: 0.94871, MSE: 28.40436, RMSE: 5.32957
# 2025-10-28 16:03:02,887: Epoch 51 average loss: avg_loss: 3.29572, avg_total_loss: 3.29572
# 2025-10-28 16:03:07,050: Epoch 51 average validation loss: 8.34656 -- Median validation metrics: avg_loss: 8.34656, MAPE: 15.94612, NSE: 0.94867, MSE: 28.42772, RMSE: 5.33176
# 2025-10-28 16:03:27,670: Epoch 52 average loss: avg_loss: 3.30629, avg_total_loss: 3.30629
# 2025-10-28 16:03:32,110: Epoch 52 average validation loss: 8.32464 -- Median validation metrics: avg_loss: 8.32464, MAPE: 15.42867, NSE: 0.94883, MSE: 28.33759, RMSE: 5.32331
# 2025-10-28 16:03:32,111: Early stopping triggered at epoch 52 with validation loss 8.32464. Training stopped.

# %% [markdown]
# ### Plot of the Loss and Metrics

# %%
# Path to your output.log file
log_path = Path(f"{cfg.base_run_dir}/{runFile}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path)

print("Plotting the losses and metrics throughout the training process: ")
plot_training_curves(train_df, val_df)
plot_validation_metrics(val_df)
# Out:
# ✅ Parsed 40 training epochs and 40 validation evaluations.
# Plotting the losses and metrics throughout the training process:

# %% [markdown]
# ---

# %% [markdown]
# ## Evaluation on the **TEST** Dataset
# The run directory that needs to be specified for evaluation is printed in the output log above. Since the folder name is created dynamically (including the date and time of the start of the run) you will need to change the `run_dir` argument according to your local directory name. By default, it will use the same device as during the training process.

# %%
run_dir = Path(f"{cfg.base_run_dir}/{runFile}")

if Evaluation_TEST:
    print(" Starting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test")
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")
# Out:
#  Testing process skipped !

# %% [markdown]
# ---

# %% [markdown]
# ### Load and inspect model predictions
# Next, we load the results file and compare the model predictions with observations. The results file is always a pickled dictionary with one key per basin (even for a single basin). The next-lower dictionary level is the temporal resolution of the predictions.
#
# In this case, we trained a model only on daily data ('1D'). Within the temporal resolution, the next-lower dictionary level are `xr`(an xarray Dataset that contains observations and predictions), as well as one key for each metric that was specified in the config file.
#
# NOTE: The data variables in the xarray Dataset are named according to the name of the target variables, with suffix `_obs` for the observations and suffix `_sim` for the simulations.

# %%
# model_str = f"model_epoch{str(cfg.epochs).zfill(3)}"
model_str = f"model_epoch055"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
basin = "massa_2"
# results.keys()
results[basin]['1h']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 4
#       2 model_str = f"model_epoch055"
#       3 testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
# ----> 4 with open(testPath, "rb") as fp:
#       5     results = pickle.load(fp)
#       6 basin = "massa_2"
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'runs\\m2_base\\test\\model_epoch055\\test_results.p'

# %% [markdown]
# ### Plotting model predictions vs observations

# %% [markdown]
# Code for 24h predictions:

# %%
from custom.functions.Plot import plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series
from custom.functions.utils_fla import info_results, mape_array, dict_without_xr_key
from custom.functions.Plot import plot_mape_horizon

results_ = results[basin]["1h"]["xr"]
scores = dict_without_xr_key(results[basin]['1h'])

# store only the values in numpy arrays from xarray DataArrays
y_true = results_['streamflow_obs']#.values
y_pred = results_['streamflow_sim']#.values
# print(y_pred-y_true)
verb = False
if verb: 
    print("\n-- Calculating MAPE values for each horizon: --\n")
    mapes = mape_array(y_true, y_pred, verbose=verb)
    print("\n-- MAPE calculation per horizon completed. --\n")
else:
    mapes = mape_array(y_true, y_pred, verbose=verb)

# %%
# Example usage (variables `mapes`, `horizons`, and `basin` exist in the notebook):
plot_mape_horizon(
    mapes,
    color="#e76f51",
    title=f"MAPE vs Forecast Horizon for basin {basin}"
)

# %%
from custom.functions.Plot import plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series

scores_str = str.join(', ', [f"{key} : {scores[key]:.2f}" for key in scores])
title24 = f"Massa – {cfg.predict_last_n}h | " + scores_str
# plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[1, 6, cfg.predict_last_n])
plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[cfg.predict_last_n])

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
plot_forecast_horizon_24h(
    issue_date="2024-08-10 00:00:00",
    xr_ds=results_
).show()
plot_forecast_horizon_24h(
    issue_date="2024-08-10 01:00:00",
    xr_ds=results_
).show()

# %%
plot_forecast_horizon_series(
    issue_date="2024-06-10 00:00:00",
    xr_ds=results_,
    n_forecasts=10
).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores
# Next, we are going to compute all metrics that are implemented in the NeuralHydrology package. You will find additional hydrological signatures implemented in `neuralhydrology.evaluation.signatures`.

# %%
qobs=results_['streamflow_obs']
qsim=results_['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.859
# MSE: 89.599
# RMSE: 9.466
# KGE: 0.909
# Alpha-NSE: 1.037
# Beta-KGE: 1.050
# Beta-NSE: 0.042
# Pearson-r: 0.933
# FHV: -4.251
# FMS: 4.568
# FLV: -25.575
# Peak-Timing: nan
# Peak-MAPE: 17.775
# MAPE: 19.354

# %%
values = metrics.calculate_all_metrics(qobs.isel(time_step=6), qsim.isel(time_step=6))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.999
# MSE: 0.333
# RMSE: 0.577
# KGE: 0.999
# Alpha-NSE: 1.000
# Beta-KGE: 1.000
# Beta-NSE: 0.000
# Pearson-r: 1.000
# FHV: -0.669
# FMS: 0.309
# FLV: 24.263
# Peak-Timing: nan
# Peak-MAPE: 2.336
# MAPE: 2.830
