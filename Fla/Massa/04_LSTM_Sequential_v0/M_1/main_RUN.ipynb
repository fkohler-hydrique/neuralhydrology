# %% [markdown]
# #  Run of Model **$X$** on the App **MASSA**
#
# **Paramaters**
# The parameters of all models should be available in the parent folder, in an EXCEL file.

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
import torch

from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run
from neuralhydrology.datasetzoo import register_dataset

# %% [markdown]
# ### Adding our Dataset | Metrics | Models

# %%
from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)
from neuralhydrology.utils.config import Config

# Custom functions plot_training_curves
from custom.functions.Plot import plot_hydrograph, plot_training_curves, plot_validation_metrics
from custom.functions.utils_fla import parse_neuralhydrology_log

# %% [markdown]
# ---

# %% [markdown]
# ### Run parameters

# %%
configPath = Path("M1.yml")

runFile = "M4_10"

cfg = Config(configPath)
TRAIN = True
Evaluation_TEST =  False

# %% [markdown]
# ---
# ## **Training**

# %%
import pandas as pd
csv_path = r"..\..\data\massa_1.csv"
data = pd.read_csv(csv_path)
print("Columns of the csv:  ", data.columns)
# print(data.dtypes)
# data['date'] = pd.to_datetime(data['date'])


# print some information about the dataset

# print(data.head())
# print(data.describe())
# Out:
# Columns of the csv:   Index(['date', 'massa_blatten', 'massa_blatten_hindcast', 'null_values',
#        'bruchji_prec', 'blatten_prec', 'blatten_temp', 'blatten_ray',
#        'blatten_pres_vap', 'eggishorn_temp', 'eggishorn_ray',
#        'fc_bruchji_prec', 'fc_blatten_temp', 'fc_blatten_prec',
#        'fc_eggishorn_temp', 'mo', 'hr', 'bruchji_prec_6h', 'blatten_prec_6h',
#        'blatten_temp_6h', 'blatten_ray_6h', 'blatten_pres_vap_6h',
#        'eggishorn_temp_6h', 'eggishorn_degreeday', 'eggishorn_ray_6h',
#        'fc_bruchji_prec_6h', 'fc_blatten_temp_6h', 'fc_blatten_prec_6h',
#        'fc_eggishorn_temp_6h', 'fc_eggishorn_degreeday', 'streamflow',
#        'streamflow_hindcast'],
#       dtype='object')

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    # by default we assume that you have at least one cuda-capable nvidia gpu or macos with metal support
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        start_run(config_file=Path(configPath))
    # fall back to cpu-only mode
    else:
        print("Using CPU")
        start_run(config_file=Path(configPath), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-10-21 08:43:28,317: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\M_1\runs\m1_2110_084328\output.log initialized.
# 2025-10-21 08:43:28,318: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\M_1\runs\m1_2110_084328
# 2025-10-21 08:43:28,319: ### Run configurations for m1
# 2025-10-21 08:43:28,319: experiment_name: m1
# 2025-10-21 08:43:28,320: base_run_dir: runs
# 2025-10-21 08:43:28,320: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\M_1\runs\m1_2110_084328\train_data
# 2025-10-21 08:43:28,321: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\M_1\runs\m1_2110_084328\img_log
# 2025-10-21 08:43:28,322: seed: 42
# 2025-10-21 08:43:28,322: device: cuda:0
# 2025-10-21 08:43:28,323: num_workers: 16
# 2025-10-21 08:43:28,323: data_dir: ..\..\data
# 2025-10-21 08:43:28,323: dataset: swisshourly
# 2025-10-21 08:43:28,324: train_basin_file: ..\..\data\basins_1.txt
# 2025-10-21 08:43:28,324: validation_basin_file: ..\..\data\basins_1.txt
# 2025-10-21 08:43:28,324: test_basin_file: ..\..\data\basins_1.txt
# 2025-10-21 08:43:28,325: train_start_date: 2020-01-03 00:00:00
# 2025-10-21 08:43:28,325: train_end_date: 2023-02-28 00:00:00
# 2025-10-21 08:43:28,325: validation_start_date: 2023-03-01 00:00:00
# 2025-10-21 08:43:28,326: validation_end_date: 2024-03-31 00:00:00
# 2025-10-21 08:43:28,326: test_start_date: 2024-04-01 00:00:00
# 2025-10-21 08:43:28,326: test_end_date: 2025-05-29 00:00:00
# 2025-10-21 08:43:28,327: dynamic_inputs: ['massa_blatten_hindcast', 'null_values', 'bruchji_prec', 'blatten_prec', 'blatten_temp', 'blatten_ray', 'eggishorn_temp', 'eggishorn_ray', 'bruchji_prec_6h', 'blatten_prec_6h', 'eggishorn_degreeday', 'fc_bruchji_prec', 'fc_blatten_prec', 'fc_blatten_temp', 'fc_eggishorn_temp', 'fc_bruchji_prec_6h', 'fc_blatten_prec_6h', 'fc_eggishorn_degreeday', 'hr', 'mo']
# 2025-10-21 08:43:28,328: hindcast_inputs: ['massa_blatten_hindcast', 'bruchji_prec', 'blatten_prec', 'blatten_temp', 'blatten_ray', 'eggishorn_temp', 'eggishorn_ray', 'bruchji_prec_6h', 'blatten_prec_6h', 'eggishorn_degreeday', 'hr', 'mo']
# 2025-10-21 08:43:28,328: forecast_inputs: ['null_values', 'fc_bruchji_prec', 'fc_blatten_prec', 'fc_blatten_temp', 'blatten_ray', 'fc_eggishorn_temp', 'eggishorn_ray', 'fc_bruchji_prec_6h', 'fc_blatten_prec_6h', 'fc_eggishorn_degreeday', 'hr', 'mo']
# 2025-10-21 08:43:28,329: forecast_seq_length: 24
# 2025-10-21 08:43:28,329: forecast_overlap: None
# 2025-10-21 08:43:28,329: timestep_counter: True
# 2025-10-21 08:43:28,330: target_variables: ['massa_blatten']
# 2025-10-21 08:43:28,330: clip_targets_to_zero: ['massa_blatten']
# 2025-10-21 08:43:28,331: model: sequential_forecast_lstm
# 2025-10-21 08:43:28,331: head: regression
# 2025-10-21 08:43:28,331: hidden_size: 256
# 2025-10-21 08:43:28,332: output_activation: linear
# 2025-10-21 08:43:28,332: output_dropout: 0.1
# 2025-10-21 08:43:28,333: initial_forget_bias: 2.5
# 2025-10-21 08:43:28,333: epochs: 1000
# 2025-10-21 08:43:28,334: max_updates_per_epoch: None
# 2025-10-21 08:43:28,334: batch_size: 64
# 2025-10-21 08:43:28,335: optimizer: AdamW
# 2025-10-21 08:43:28,335: loss: nse
# 2025-10-21 08:43:28,336: learning_rate: 0.001
# 2025-10-21 08:43:28,336: clip_gradient_norm: 3.0
# 2025-10-21 08:43:28,337: seq_length: 360
# 2025-10-21 08:43:28,337: predict_last_n: 24
# 2025-10-21 08:43:28,338: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-10-21 08:43:28,338: validate_every: 1
# 2025-10-21 08:43:28,338: validate_n_random_basins: 1
# 2025-10-21 08:43:28,339: early_stopping: True
# 2025-10-21 08:43:28,339: patience_early_stopping: 10
# 2025-10-21 08:43:28,340: minimum_epochs_before_early_stopping: 20
# 2025-10-21 08:43:28,341: min_delta_early_stopping: 5e-07
# 2025-10-21 08:43:28,341: dynamic_learning_rate: True
# 2025-10-21 08:43:28,342: patience_dynamic_learning_rate: 5
# 2025-10-21 08:43:28,342: factor_dynamic_learning_rate: 0.6
# 2025-10-21 08:43:28,342: log_interval: 10
# 2025-10-21 08:43:28,343: log_n_figures: 1
# 2025-10-21 08:43:28,343: log_tensorboard: True
# 2025-10-21 08:43:28,344: save_train_data: False
# 2025-10-21 08:43:28,344: save_validation_results: False
# 2025-10-21 08:43:28,345: save_all_output: False
# 2025-10-21 08:43:28,345: save_weights_every: 10
# 2025-10-21 08:43:28,346: save_git_diff: False
# 2025-10-21 08:43:28,346: verbose: 1
# 2025-10-21 08:43:28,347: nan_handling_method: masked_mean
# 2025-10-21 08:43:28,347: nan_step_probability: 0.0
# 2025-10-21 08:43:28,347: nan_sequence_probability: 0.0
# 2025-10-21 08:43:28,348: nan_handling_pos_encoding_size: 0
# 2025-10-21 08:43:28,348: number_of_basins: 1
# 2025-10-21 08:43:28,349: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\M_1\runs\m1_2110_084328
# 2025-10-21 08:43:28,357: ### Device cuda:0 will be used for training
# 2025-10-21 08:43:28,359: Loading basin data into xarray data set.
# 2025-10-21 08:43:28,520: Calculating target variable stds per basin
# 2025-10-21 08:43:28,536: Create lookup table and convert to pytorch tensor
# 2025-10-21 08:44:20,148: Epoch 1 average loss: avg_loss: 0.00012, avg_total_loss: 0.00012
# 2025-10-21 08:44:23,392: Epoch 1 average validation loss: 0.00010 -- Median validation metrics: avg_loss: 0.00010, MAPE: 1118688.37500, NSE: 0.93617, MSE: 35.46599, RMSE: 5.95533
# 2025-10-21 08:44:36,454: Epoch 2 average loss: avg_loss: 0.00005, avg_total_loss: 0.00005
# 2025-10-21 08:44:39,056: Epoch 2 average validation loss: 0.00009 -- Median validation metrics: avg_loss: 0.00009, MAPE: 1137593.00000, NSE: 0.94202, MSE: 32.21413, RMSE: 5.67575
# 2025-10-21 08:44:51,963: Epoch 3 average loss: avg_loss: 0.00004, avg_total_loss: 0.00004
# 2025-10-21 08:44:54,680: Epoch 3 average validation loss: 0.00009 -- Median validation metrics: avg_loss: 0.00009, MAPE: 2916335.25000, NSE: 0.93855, MSE: 34.14079, RMSE: 5.84301
# 2025-10-21 08:45:07,688: Epoch 4 average loss: avg_loss: 0.00002, avg_total_loss: 0.00002
# 2025-10-21 08:45:10,290: Epoch 4 average validation loss: 0.00010 -- Median validation metrics: avg_loss: 0.00010, MAPE: 1676592.00000, NSE: 0.92943, MSE: 39.21252, RMSE: 6.26199
# 2025-10-21 08:45:23,539: Epoch 5 average loss: avg_loss: 0.00002, avg_total_loss: 0.00002
# 2025-10-21 08:45:26,159: Epoch 5 average validation loss: 0.00010 -- Median validation metrics: avg_loss: 0.00010, MAPE:
average validation loss: 0.00010 -- Median validation metrics: avg_loss: 0.00010, MAPE: 1488615.87500, NSE: 0.92869, MSE: 39.61886, RMSE: 6.29435
# 2025-10-21 08:52:21,863: Epoch 28 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-10-21 08:52:24,934: Epoch 28 average validation loss: 0.00010 -- Median validation metrics: avg_loss: 0.00010, MAPE: 1795003.75000, NSE: 0.92855, MSE: 39.69725, RMSE: 6.30058
# 2025-10-21 08:52:39,378: Epoch 29 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-10-21 08:52:42,490: Epoch 29 average validation loss: 0.00010 -- Median validation metrics: avg_loss: 0.00010, MAPE: 1274292.00000, NSE: 0.92924, MSE: 39.31470, RMSE: 6.27014
# 2025-10-21 08:52:57,797: Epoch 30 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-10-21 08:53:01,324: Epoch 30 average validation loss: 0.00010 -- Median validation metrics: avg_loss: 0.00010, MAPE: 1951412.75000, NSE: 0.92916, MSE: 39.36258, RMSE: 6.27396
# 2025-10-21 08:53:01,326: [Scheduler] - Learning rate changed from 3.6e-04 to 2.2e-04
# 2025-10-21 08:53:15,556: Epoch 31 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-10-21 08:53:18,554: Epoch 31 average validation loss: 0.00010 -- Median validation metrics: avg_loss: 0.00010, MAPE: 1868467.62500, NSE: 0.93027, MSE: 38.74547, RMSE: 6.22459
# 2025-10-21 08:53:34,101: Epoch 32 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-10-21 08:53:37,681: Epoch 32 average validation loss: 0.00010 -- Median validation metrics: avg_loss: 0.00010, MAPE: 1437936.75000, NSE: 0.93163, MSE: 37.98916, RMSE: 6.16353
# 2025-10-21 08:53:54,042: Epoch 33 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-10-21 08:53:58,728: Epoch 33 average validation loss: 0.00010 -- Median validation metrics: avg_loss: 0.00010, MAPE: 1210507.87500, NSE: 0.93013, MSE: 38.81841, RMSE: 6.23044
# 2025-10-21 08:54:15,177: Epoch 34 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-10-21 08:54:18,451: Epoch 34 average validation loss: 0.00011 -- Median validation metrics: avg_loss: 0.00011, MAPE: 1459385.37500, NSE: 0.92775, MSE: 40.14478, RMSE: 6.33599
# 2025-10-21 08:54:37,255: Epoch 35 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-10-21 08:54:42,123: Epoch 35 average validation loss: 0.00010 -- Median validation metrics: avg_loss: 0.00010, MAPE: 1475251.87500, NSE: 0.93139, MSE: 38.11965, RMSE: 6.17411
# 2025-10-21 08:54:57,941: Epoch 36 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-10-21 08:55:01,159: Epoch 36 average validation loss: 0.00010 -- Median validation metrics: avg_loss: 0.00010, MAPE: 1407215.00000, NSE: 0.92993, MSE: 38.93213, RMSE: 6.23956
# 2025-10-21 08:55:17,091: Epoch 37 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# 2025-10-21 08:55:20,784: Epoch 37 average validation loss: 0.00010 -- Median validation metrics: avg_loss: 0.00010, MAPE: 1337161.50000, NSE: 0.93121, MSE: 38.22202, RMSE: 6.18240
# 2025-10-21 08:55:37,438: Epoch 38 average loss: avg_loss: 0.00000, avg_total_loss: 0.00000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       4 if torch.cuda.is_available() or torch.backends.mps.is_available():
#       5     print("Using GPU")
# ----> 6     start_run(config_file=Path(configPath))
#       7 # fall back to cpu-only mode
#       8 else:
#       9     print("Using CPU")
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\nh_run.py:77, in start_run(config_file, gpu)
#      74 if gpu is not None and gpu < 0:
#      75     config.device = "cpu"
# ---> 77 start_training(config)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\train.py:20, in start_training(cfg)
#      18     raise ValueError(f"Unknown head {cfg.head}.")
#      19 trainer.initialize_training()
# ---> 20 trainer.train_and_validate()
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\basetrainer.py:246, in BaseTrainer.train_and_validate(self)
#     243     self._save_weights_and_optimizer(epoch)
#     245 if (self.validator is not None) and (epoch % self.cfg.validate_every == 0):
# --> 246     self.validator.evaluate(epoch=epoch,
#     247                             save_results=self.cfg.save_validation_results,
#     248                             save_all_output=self.cfg.save_all_output,
#     249                             metrics=self.cfg.metrics,
#     250                             model=self.model,
#     251                             experiment_logger=self.experiment_logger.valid())
#     253     valid_metrics = self.experiment_logger.summarise()
#     254     print_msg = f"Epoch {epoch} average validation loss: {valid_metrics['avg_total_loss']:.5f}"
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\evaluation\tester.py:226, in BaseTester.evaluate(self, epoch, save_results, save_all_output, metrics, model, experiment_logger)
#     222         self.cached_datasets[basin] = ds
#     224 loader = DataLoader(ds, batch_size=self.cfg.batch_size, num_workers=0, collate_fn=ds.collate_fn)
# --> 226 y_hat, y, dates, all_losses, all_output[basin] = self._evaluate(model, loader, ds.frequencies,
#     227                                                                 save_all_output)
#     229 # log loss of this basin plus number of samples in the logger to compute epoch aggregates later
#     230 if experiment_logger is not None:
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\evaluation\tester.py:473, in BaseTester._evaluate(self, model, loader, frequencies, save_all_output)
#     471 losses = []
#     472 with torch.no_grad():
# --> 473     for data in loader:
#     475         for key in data:
#     476             if key.startswith('x_d'):
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\utils\data\dataloader.py:734, in _BaseDataLoaderIter.__next__(self)
#     731 if self._sampler_iter is None:
#     732     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     733     self._reset()  # type: ignore[call-arg]
# --> 734 data = self._next_data()
#     735 self._num_yielded += 1
#     736 if (
#     737     self._dataset_kind == _DatasetKind.Iterable
#     738     and self._IterableDataset_len_called is not None
#     739     and self._num_yielded > self._IterableDataset_len_called
#     740 ):
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\utils\data\dataloader.py:790, in _SingleProcessDataLoaderIter._next_data(self)
#     788 def _next_data(self):
#     789     index = self._next_index()  # may raise StopIteration
# --> 790     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     791     if self._pin_memory:
#     792         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\datasetzoo\basedataset.py:886, in BaseDataset.collate_fn(samples)
#     883     batch[feature] = np.stack([sample[feature] for sample in samples], axis=0)
#     884 elif feature.startswith('x_d'):
#     885     # Dynamics are stored as dictionaries with feature names as keys.
# --> 886     batch[feature] = {k: torch.stack([sample[feature][k] for sample in samples], dim=0)
#     887                       for k in samples[0][feature]}
#     888 else:
#     889     # Everything else is a torch.Tensor.
#     890     batch[feature] = torch.stack([sample[feature] for sample in samples], dim=0)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Plot of the Loss and Metrics

# %%
# Path to your output.log file
log_path = Path(f"{cfg.base_run_dir}/{runFile}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path)

print("Plotting the losses and metrics throughout the training process: ")
plot_training_curves(train_df, val_df)
plot_validation_metrics(val_df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Path to your output.log file
#       2 log_path = Path(f"{cfg.base_run_dir}/{runFile}/output.log")
# ----> 3 train_df, val_df = parse_neuralhydrology_log(log_path)
#       5 print("Plotting the losses and metrics throughout the training process: ")
#       6 plot_training_curves(train_df, val_df)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\custom\functions\utils_fla.py:8, in parse_neuralhydrology_log(log_path)
#       6 """Parse output.log from NeuralHydrology training run."""
#       7 log_path = Path(log_path)
# ----> 8 text = log_path.read_text(encoding="utf-8")
#      10 # Regex patterns
#      11 train_pattern = r"Epoch (\d+) average loss: avg_loss: ([\d\.]+), avg_total_loss: ([\d\.]+)"
#
# File C:\Python313\Lib\pathlib\_local.py:546, in Path.read_text(self, encoding, errors, newline)
#     543 # Call io.text_encoding() here to ensure any warning is raised at an
#     544 # appropriate stack level.
#     545 encoding = io.text_encoding(encoding)
# --> 546 return PathBase.read_text(self, encoding, errors, newline)
#
# File C:\Python313\Lib\pathlib\_abc.py:632, in PathBase.read_text(self, encoding, errors, newline)
#     628 def read_text(self, encoding=None, errors=None, newline=None):
#     629     """
#     630     Open the file in text mode, read it, and close the file.
#     631     """
# --> 632     with self.open(mode='r', encoding=encoding, errors=errors, newline=newline) as f:
#     633         return f.read()
#
# File C:\Python313\Lib\pathlib\_local.py:537, in Path.open(self, mode, buffering, encoding, errors, newline)
#     535 if "b" not in mode:
#     536     encoding = io.text_encoding(encoding)
# --> 537 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'runs\\M4_10\\output.log'

# %% [markdown]
# ---

# %% [markdown]
# ## Evaluation on the **TEST** Dataset
# The run directory that needs to be specified for evaluation is printed in the output log above. Since the folder name is created dynamically (including the date and time of the start of the run) you will need to change the `run_dir` argument according to your local directory name. By default, it will use the same device as during the training process.

# %%
run_dir = Path(f"{cfg.base_run_dir}/{runFile}")

if Evaluation_TEST:
    print(" Starting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test")
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")
# Out:
#  Testing process skipped !

# %% [markdown]
# ---

# %% [markdown]
# ### Load and inspect model predictions
# Next, we load the results file and compare the model predictions with observations. The results file is always a pickled dictionary with one key per basin (even for a single basin). The next-lower dictionary level is the temporal resolution of the predictions.
#
# In this case, we trained a model only on daily data ('1D'). Within the temporal resolution, the next-lower dictionary level are `xr`(an xarray Dataset that contains observations and predictions), as well as one key for each metric that was specified in the config file.
#
# NOTE: The data variables in the xarray Dataset are named according to the name of the target variables, with suffix `_obs` for the observations and suffix `_sim` for the simulations.

# %%
# model_str = f"model_epoch{str(cfg.epochs).zfill(3)}"
model_str = f"model_epoch030"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
basin = "massa"
# results.keys()
results[basin]['1h']
# Out:
# {'xr': <xarray.Dataset> Size: 2MB
#  Dimensions:         (date: 10201, time_step: 24)
#  Coordinates:
#    * date            (date) datetime64[ns] 82kB 2024-04-01T23:00:00 ... 2025-0...
#    * time_step       (time_step) int64 192B -23 -22 -21 -20 -19 ... -4 -3 -2 -1 0
#  Data variables:
#      streamflow_obs  (date, time_step) float32 979kB 1.155 1.146 ... 27.32 26.4
#      streamflow_sim  (date, time_step) float32 979kB 1.415 1.368 ... 29.96 29.47,
#  'MAPE': 14.445847511291504,
#  'NSE': 0.9508161544799805,
#  'MSE': 29.1690673828125,
#  'RMSE': 5.400839507225937}

# %% [markdown]
# ### Plotting model predictions vs observations

# %% [markdown]
# Code for 1h prediction:

# %%
# qobs=results['massa']['1h']['xr']['streamflow_obs']
# qsim=results['massa']['1h']['xr']['streamflow_sim']
# plot_hydrograph(
#     qobs=qobs,
#     qsim=qsim,
#     results=results,
#     basin='massa',
#     freq='1h',
#     plot_peaks=False  # turn on high-flow markers
# )

# %% [markdown]
# Code for 24h predictions:

# %%
from custom.functions.Plot import plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series

xr_ds = results[basin]["1h"]["xr"]
title24 = f"Massa – {cfg.predict_last_n}h | MAPE {results[basin]['1h']['MAPE']:.3f}, NSE {results[basin]['1h']['NSE']:.3f}, RMSE {results[basin]['1h']['MSE']:.3f}"

# last forecast of the horizon vs obs
plot_forecast_24h(xr_ds, title=title24).show()
# All spaghetti forecasts
# plot_forecast_24h(xr_ds, mode="spaghetti").show()

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
plot_forecast_horizon_24h(
    xr_ds,
    issue_date="2024-08-10 00:00:00"
).show()
plot_forecast_horizon_24h(
    xr_ds,
    issue_date="2024-08-10 01:00:00"
).show()

# %%
plot_forecast_horizon_series(
    xr_ds,
    issue_date="2024-06-10 00:00:00",
    n_forecasts=5
).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores
# Next, we are going to compute all metrics that are implemented in the NeuralHydrology package. You will find additional hydrological signatures implemented in `neuralhydrology.evaluation.signatures`.

# %%
qobs=results[basin]['1h']['xr']['streamflow_obs']
qsim=results[basin]['1h']['xr']['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.951
# MSE: 29.169
# RMSE: 5.401
# KGE: 0.898
# Alpha-NSE: 0.919
# Beta-KGE: 0.942
# Beta-NSE: -0.041
# Pearson-r: 0.978
# FHV: -8.906
# FMS: -0.063
# FLV: -1872.925
# Peak-Timing: nan
# Peak-MAPE: 21.589
# MAPE: 14.447
