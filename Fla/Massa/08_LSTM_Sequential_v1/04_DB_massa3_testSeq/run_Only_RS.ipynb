# %% [markdown]
# ## Imports

# %%
from   pathlib import Path
import matplotlib.pyplot as plt
import pickle
import torch
import pandas as pd
# import mlflow

from neuralhydrology.evaluation     import metrics
from neuralhydrology.nh_run         import start_run, eval_run
from neuralhydrology.datasetzoo     import register_dataset
from neuralhydrology.utils.config   import Config

from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)

# Custom functions plot_training_curves
from custom.functions.Plot import plot_training_curves, plot_validation_metrics
from custom.functions.Plot import plot_mape_horizon, plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series
from custom.functions.utils_fla import parse_neuralhydrology_log
from custom.functions.utils_fla import info_results, mape_array, dict_without_xr_key

# %% [markdown]
# ## Parameters of the run

# %%
# Initialisation of the config file, name of the experiment in the parameter experiment_name
config_file = Path("config_Only_RS.yml")
cfg = Config(config_file)

# Here write the name of the run if renamed run or if you want to plot the specified run, otherwise will take the run_dir created during training
# example: "expName_TimeStamp" 
runFile = None 

# list of basins, DB -> name of the basin.txt where the name of the csv is indicated
basin = "massa3"

# Whether you want to run a training, put false to plot your specific run folder for example
TRAIN, Evaluation_TEST = True, True

save_plots_training = True

# %% [markdown]
# ## Run

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        run_dir = start_run(config_file=Path(config_file))
    else:
        print("Using CPU")
        run_dir = start_run(config_file=Path(config_file), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
if runFile is not None:
    run_dir = Path(f"./runs/{runFile}")

if Evaluation_TEST:
    print("\nStarting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test", from_best=cfg.save_best_enabled)
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")

model_str = f"model_from_best"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-11-10 15:37:31: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\04_DB_massa3_testSeq\runs\try1_1011_153731\output.log initialized.
# 2025-11-10 15:37:31: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\04_DB_massa3_testSeq\runs\try1_1011_153731
# 2025-11-10 15:37:31: ### Run configurations for try1
# 2025-11-10 15:37:31: experiment_name: try1
# 2025-11-10 15:37:31: base_run_dir: runs
# 2025-11-10 15:37:31: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\04_DB_massa3_testSeq\runs\try1_1011_153731\img_log
# 2025-11-10 15:37:31: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\04_DB_massa3_testSeq\runs\try1_1011_153731\train_data
# 2025-11-10 15:37:31: seed: 42
# 2025-11-10 15:37:31: device: cuda:0
# 2025-11-10 15:37:31: num_workers: 16
# 2025-11-10 15:37:31: data_dir: ..\..\data
# 2025-11-10 15:37:31: dataset: swisshourly
# 2025-11-10 15:37:31: train_basin_file: ..\..\data\massa3.txt
# 2025-11-10 15:37:31: validation_basin_file: ..\..\data\massa3.txt
# 2025-11-10 15:37:31: test_basin_file: ..\..\data\massa3.txt
# 2025-11-10 15:37:31: train_start_date: 2020-03-01 00:00:00
# 2025-11-10 15:37:31: train_end_date: 2022-02-28 00:00:00
# 2025-11-10 15:37:31: validation_start_date: 2022-03-01 00:00:00
# 2025-11-10 15:37:31: validation_end_date: 2023-02-02 00:00:00
# 2025-11-10 15:37:31: test_start_date: 2023-02-03 00:00:00
# 2025-11-10 15:37:31: test_end_date: 2024-02-04 00:00:00
# 2025-11-10 15:37:31: dynamic_inputs: ['streamflow_hindcast', 'null_values', 'noon', 'june', 'daylight', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A']
# 2025-11-10 15:37:31: hindcast_inputs: ['streamflow_hindcast', 'noon', 'june', 'daylight', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A']
# 2025-11-10 15:37:31: forecast_inputs: ['null_values', 'noon', 'june', 'daylight', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A']
# 2025-11-10 15:37:31: timestep_counter: True
# 2025-11-10 15:37:31: target_variables: ['streamflow']
# 2025-11-10 15:37:31: clip_targets_to_zero: ['streamflow']
# 2025-11-10 15:37:31: model: sequential_forecast_lstm
# 2025-11-10 15:37:31: head: regression
# 2025-11-10 15:37:31: hidden_size: 64
# 2025-11-10 15:37:31: output_activation: linear
# 2025-11-10 15:37:31: output_dropout: 0.01
# 2025-11-10 15:37:31: lstm_dropout: 0.0
# 2025-11-10 15:37:31: num_layers: 2
# 2025-11-10 15:37:31: initial_forget_bias: 1.5
# 2025-11-10 15:37:31: epochs: 10000
# 2025-11-10 15:37:31: learning_rate: 0.001
# 2025-11-10 15:37:31: batch_size: 16
# 2025-11-10 15:37:31: optimizer: AdamW
# 2025-11-10 15:37:31: loss: custom_loss
# 2025-11-10 15:37:31: seq_length: 150
# 2025-11-10 15:37:31: predict_last_n: 24
# 2025-11-10 15:37:31: forecast_seq_length: 24
# 2025-11-10 15:37:31: forecast_overlap: None
# 2025-11-10 15:37:31: custom_loss: {'losses': ['smape', 'nse', 'mse'], 'weights': [0.8, 0.1, 0.1]}
# 2025-11-10 15:37:31: clip_gradient_norm: 5.0
# 2025-11-10 15:37:31: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-11-10 15:37:31: validate_every: 1
# 2025-11-10 15:37:31: validate_n_random_basins: 1
# 2025-11-10 15:37:31: early_stopping: True
# 2025-11-10 15:37:31: patience_early_stopping: 20
# 2025-11-10 15:37:31: minimum_epochs_before_early_stopping: 20
# 2025-11-10 15:37:31: min_delta_early_stopping: 1e-07
# 2025-11-10 15:37:31: dynamic_learning_rate: True
# 2025-11-10 15:37:31: patience_dynamic_learning_rate: 5
# 2025-11-10 15:37:31: factor_dynamic_learning_rate: 0.4
# 2025-11-10 15:37:31: log_interval: 10
# 2025-11-10 15:37:31: log_n_figures: 1
# 2025-11-10 15:37:31: log_tensorboard: True
# 2025-11-10 15:37:31: save_train_data: False
# 2025-11-10 15:37:31: save_validation_results: False
# 2025-11-10 15:37:31: save_all_output: False
# 2025-11-10 15:37:31: save_weights_every: 10
# 2025-11-10 15:37:31: verbose: 1
# 2025-11-10 15:37:31: save_best_enabled: True
# 2025-11-10 15:37:31: save_best_criterion: sum_metrics
# 2025-11-10 15:37:31: save_in_csv: True
# 2025-11-10 15:37:31: csv_metrics_name: Metrics_over_Experiments
# 2025-11-10 15:37:31: nan_handling_method: masked_mean
# 2025-11-10 15:37:31: nan_step_probability: 0.0
# 2025-11-10 15:37:31: nan_sequence_probability: 0.0
# 2025-11-10 15:37:31: nan_handling_pos_encoding_size: 0
# 2025-11-10 15:37:31: number_of_basins: 1
# 2025-11-10 15:37:31: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\04_DB_massa3_testSeq\runs\try1_1011_153731
# 2025-11-10 15:37:31: ### Device cuda:0 will be used for training
# 2025-11-10 15:37:31: Loading basin data into xarray data set.
# 2025-11-10 15:37:31: Calculating target variable stds per basin
# 2025-11-10 15:37:31: Create lookup table and convert to pytorch tensor
# 2025-11-10 15:38:18: Epoch 1 average loss: avg_loss: 12.75190, avg_total_loss: 12.75190
# 2025-11-10 15:38:22: Epoch 1 average validation loss: 39.29850 -- Median validation metrics: avg_loss: 39.29850, MAPE: 243.81523, NSE: 0.91153, MSE: 59.98440, RMSE: 7.74496
# 2025-11-10 15:38:22: [saveBest] New best model found at epoch 1: 303.888100 (prev inf)
# 2025-11-10 15:38:33: Epoch 2 average loss: avg_loss: 8.36251, avg_total_loss: 8.36251
# 2025-11-10 15:38:36: Epoch 2 average validation loss: 36.78510 -- Median validation metrics: avg_loss: 36.78510, MAPE: 230.38890, NSE: 0.93460, MSE: 44.34446, RMSE: 6.65916
# 2025-11-10 15:38:36: [saveBest] New best model found at epoch 2: 274.798761 (prev 303.888100)
# 2025-11-10 15:38:48: Epoch 3 average loss: avg_loss: 7.28452, avg_total_loss: 7.28452
# 2025-11-10 15:38:51: Epoch 3 average validation loss: 31.54294 -- Median validation metrics: avg_loss: 31.54294, MAPE: 135.63762, NSE: 0.91528, MSE: 57.44576, RMSE: 7.57930
# 2025-11-10 15:48:07: Epoch 40 average validation loss: 29.89848 -- Median validation metrics: avg_loss: 29.89848, MAPE: 58.83485, NSE: 0.94140, MSE: 39.73524, RMSE: 6.30359
# 2025-11-10 15:48:20: Epoch 41 average loss: avg_loss: 1.83376, avg_total_loss: 1.83376
# 2025-11-10 15:48:24: Epoch 41 average validation loss: 29.86889 -- Median validation metrics: avg_loss: 29.86889, MAPE: 58.49198, NSE: 0.94059, MSE: 40.28336, RMSE: 6.34692
# 2025-11-10 15:48:37: Epoch 42 average loss: avg_loss: 1.83520, avg_total_loss: 1.83520
# 2025-11-10 15:48:41: Epoch 42 average validation loss: 30.04083 -- Median validation metrics: avg_loss: 30.04083, MAPE: 59.97090, NSE: 0.94156, MSE: 39.62391, RMSE: 6.29475
# 2025-11-10 15:48:54: Epoch 43 average loss: avg_loss: 1.82762, avg_total_loss: 1.82762
# 2025-11-10 15:48:57: Epoch 43 average validation loss: 29.87029 -- Median validation metrics: avg_loss: 29.87029, MAPE: 58.92979, NSE: 0.94155, MSE: 39.62854, RMSE: 6.29512
# 2025-11-10 15:49:09: Epoch 44 average loss: avg_loss: 1.81859, avg_total_loss: 1.81859
# 2025-11-10 15:49:13: Epoch 44 average validation loss: 29.80039 -- Median validation metrics: avg_loss: 29.80039, MAPE: 58.11549, NSE: 0.94150, MSE: 39.66726, RMSE: 6.29819
# 2025-11-10 15:49:24: Epoch 45 average loss: avg_loss: 1.82166, avg_total_loss: 1.82166
# 2025-11-10 15:49:27: Epoch 45 average validation loss: 29.83808 -- Median validation metrics: avg_loss: 29.83808, MAPE: 58.77776, NSE: 0.94214, MSE: 39.22851, RMSE: 6.26327
# 2025-11-10 15:49:27: Early stopping triggered at epoch 45 with validation loss 29.83808. Training stopped.
# ==================================
#   Training ended successfully !
# ==================================
#
# Starting the EVALUATION on the test period:
# 2025-11-10 15:49:28: Using the model weights from c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\04_DB_massa3_testSeq\runs\try1_1011_153731\best_model.pt
# from best ma gueule
# ==================================
#   TEST ended successfully !
# ==================================

# %%
Metrics = dict_without_xr_key(results[basin]['1h'])
Metrics_ = Metrics.copy()

if cfg.save_in_csv and Evaluation_TEST:
    if Metrics_ is not None:
        summary_file =  Path(f"./{cfg.csv_metrics_name}.csv")
        Metrics_['experiment'] = run_dir.name

        summary_df = pd.DataFrame([Metrics_])
        
        # Append to summary file, creating it with a header if it doesn't exist
        summary_df.to_csv(f"{cfg.csv_metrics_name}.csv", mode='a', header=not summary_file.exists(), index=False)

# %% [markdown]
# ---

# %%
print("Metrics on the cuncatenated last predictions, on the Evaluation period:")
print(Metrics)
# Out:
# Metrics on the cuncatenated last predictions, on the Evaluation period:
# {'MAPE': 180.87741088867188, 'NSE': 0.8477575182914734, 'MSE': 87.58233642578125, 'RMSE': 9.358543499165949}

# %%
# Path to your output.log file
log_path = Path(f"{run_dir}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path, verbose=False)


plot_training_curves(train_df, val_df, save_fig = save_plots_training, run_dir=run_dir)
plot_validation_metrics(val_df, save_fig = save_plots_training, run_dir=run_dir)

# %% [markdown]
# ---

# %% [markdown]
# ### Extract results from Test period

# %%
results_ = results[basin]["1h"]["xr"]
scores = dict_without_xr_key(results[basin]['1h'])

# store only the values in numpy arrays from xarray DataArrays
y_true = results_['streamflow_obs']
y_pred = results_['streamflow_sim']

verb = False
if verb: 
    print("\n-- Calculating MAPE values for each horizon: --\n")
    mapes = mape_array(y_true, y_pred, verbose=verb)
    print("\n-- MAPE calculation per horizon completed. --\n")
else:
    mapes = mape_array(y_true, y_pred, verbose=verb)

# %%
plot_mape_horizon(
    mapes,
    color="#e76f51",
    title=f"MAPE vs Forecast Horizon for basin {basin}"
)

# %%
scores_str = str.join(', ', [f"{key} : {scores[key]:.2f}" for key in scores])
title24 = f"Massa – {cfg.predict_last_n}h | " + scores_str

# plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[1, 6, cfg.predict_last_n])
plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[cfg.predict_last_n])

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 00:00:00",
#     xr_ds=results_
# ).show()
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 01:00:00",
#     xr_ds=results_
# ).show()

# %%
# Example to plot the forecast issued at the given time stamp and the n_forecast next predictions
# plot_forecast_horizon_series(
#     issue_date="2024-06-10 00:00:00",
#     xr_ds=results_,
#     n_forecasts=10
# ).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores - TEST period

# %% [markdown]
# ### Prediction at $t+24h$

# %%
qobs=results_['streamflow_obs']
qsim=results_['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.848
# MSE: 87.582
# RMSE: 9.359
# KGE: 0.699
# Alpha-NSE: 0.703
# Beta-KGE: 0.977
# Beta-NSE: -0.018
# Pearson-r: 0.955
# FHV: -38.050
# FMS: -43.793
# FLV: -2178.071
# Peak-Timing: nan
# Peak-MAPE: 39.043
# MAPE: 180.900

# %% [markdown]
# ### Prediction at $t+7h$

# %%
values = metrics.calculate_all_metrics(qobs.isel(time_step=6), qsim.isel(time_step=6))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.854
# MSE: 83.801
# RMSE: 9.154
# KGE: 0.694
# Alpha-NSE: 0.698
# Beta-KGE: 1.029
# Beta-NSE: 0.023
# Pearson-r: 0.961
# FHV: -35.250
# FMS: -56.790
# FLV: -2157.634
# Peak-Timing: nan
# Peak-MAPE: 35.842
# MAPE: 260.980
