# %% [markdown]
# ## Imports

# %%
from   pathlib import Path
import matplotlib.pyplot as plt
import pickle
import torch
import pandas as pd
# import mlflow

from neuralhydrology.evaluation     import metrics
from neuralhydrology.nh_run         import start_run, eval_run
from neuralhydrology.datasetzoo     import register_dataset
from neuralhydrology.utils.config   import Config

from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)

# Custom functions plot_training_curves
from custom.functions.Plot import plot_training_curves, plot_validation_metrics
from custom.functions.Plot import plot_mape_horizon, plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series
from custom.functions.utils_fla import parse_neuralhydrology_log
from custom.functions.utils_fla import info_results, mape_array, dict_without_xr_key

# %% [markdown]
# ## Parameters of the run

# %%
# Initialisation of the config file, name of the experiment in the parameter experiment_name
config_file = Path("config_Name1.yml")
cfg = Config(config_file)

# Here write the name of the run if renamed run or if you want to plot the specified run, otherwise will take the run_dir created during training
# example: "expName_TimeStamp" 
runFile = None 

# list of basins, DB -> name of the basin.txt where the name of the csv is indicated
basin = "massa_RS_v1"

# Whether you want to run a training, put false to plot your specific run folder for example
TRAIN, Evaluation_TEST = True, True

save_plots_training = True

# %% [markdown]
# ## Run

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        run_dir = start_run(config_file=Path(config_file))
    else:
        print("Using CPU")
        run_dir = start_run(config_file=Path(config_file), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
if runFile is not None:
    run_dir = Path(f"./runs/{runFile}")

if Evaluation_TEST:
    print("\nStarting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test", from_best=cfg.save_best_enabled)
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")

model_str = f"model_from_best"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-11-18 15:45:40: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\06_DB_RSv1\runs\Name1_1811_154540\output.log initialized.
# 2025-11-18 15:45:40: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\06_DB_RSv1\runs\Name1_1811_154540
# 2025-11-18 15:45:40: ### Run configurations for Name1
# 2025-11-18 15:45:40: experiment_name: Name1
# 2025-11-18 15:45:40: base_run_dir: runs
# 2025-11-18 15:45:40: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\06_DB_RSv1\runs\Name1_1811_154540\img_log
# 2025-11-18 15:45:40: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\06_DB_RSv1\runs\Name1_1811_154540\train_data
# 2025-11-18 15:45:40: seed: 42
# 2025-11-18 15:45:40: device: cuda:0
# 2025-11-18 15:45:40: num_workers: 16
# 2025-11-18 15:45:40: data_dir: ..\..\data
# 2025-11-18 15:45:40: dataset: swisshourly
# 2025-11-18 15:45:40: train_basin_file: ..\..\data\RS_v1.txt
# 2025-11-18 15:45:40: validation_basin_file: ..\..\data\RS_v1.txt
# 2025-11-18 15:45:40: test_basin_file: ..\..\data\RS_v1.txt
# 2025-11-18 15:45:40: train_start_date: 2020-05-03 00:00:00
# 2025-11-18 15:45:40: train_end_date: 2023-03-30 00:00:00
# 2025-11-18 15:45:40: validation_start_date: 2023-04-01 00:00:00
# 2025-11-18 15:45:40: validation_end_date: 2024-02-04 00:00:00
# 2025-11-18 15:45:40: test_start_date: 2023-04-01 00:00:00
# 2025-11-18 15:45:40: test_end_date: 2024-02-04 00:00:00
# 2025-11-18 15:45:40: dynamic_inputs: ['streamflow_hindcast', 'null_values', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'HourOfDaySinus', 'DayOfYearSinus', 'fc_Massa|22_Q simule', 'fc_Massa|69_i', 'fc_Massa|69_T', 'fc_Massa|70_h', 'fc_Massa|71_h']
# 2025-11-18 15:45:40: hindcast_inputs: ['streamflow_hindcast', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'HourOfDaySinus', 'DayOfYearSinus']
# 2025-11-18 15:45:40: forecast_inputs: ['null_values', 'fc_Massa|22_Q simule', 'fc_Massa|69_i', 'fc_Massa|69_T', 'fc_Massa|70_h', 'fc_Massa|71_h', 'HourOfDaySinus', 'DayOfYearSinus']
# 2025-11-18 15:45:40: timestep_counter: True
# 2025-11-18 15:45:40: target_variables: ['streamflow']
# 2025-11-18 15:45:40: clip_targets_to_zero: ['streamflow']
# 2025-11-18 15:45:40: high_flow_only: True
# 2025-11-18 15:45:40: high_flow_target: streamflow
# 2025-11-18 15:45:40: high_flow_threshold: 10.0
# 2025-11-18 15:45:40: model: sequential_forecast_lstm
# 2025-11-18 15:45:40: head: regression
# 2025-11-18 15:45:40: hidden_size: 96
# 2025-11-18 15:45:40: output_activation: linear
# 2025-11-18 15:45:40: output_dropout: 0.05
# 2025-11-18 15:45:40: lstm_dropout: 0.0
# 2025-11-18 15:45:40: num_layers: 1
# 2025-11-18 15:45:40: initial_forget_bias: 1.5
# 2025-11-18 15:45:40: epochs: 10000
# 2025-11-18 15:45:40: learning_rate: 0.001
# 2025-11-18 15:45:40: batch_size: 32
# 2025-11-18 15:45:40: optimizer: Adam
# 2025-11-18 15:45:40: loss: custom_loss
# 2025-11-18 15:45:40: seq_length: 120
# 2025-11-18 15:45:40: predict_last_n: 24
# 2025-11-18 15:45:40: forecast_seq_length: 24
# 2025-11-18 15:45:40: forecast_overlap: None
# 2025-11-18 15:45:40: custom_loss: {'losses': ['smape', 'nse', 'mse'], 'weights': [0.5, 0.2, 0.3]}
# 2025-11-18 15:45:40: clip_gradient_norm: 5.0
# 2025-11-18 15:45:40: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-11-18 15:45:40: validate_every: 1
# 2025-11-18 15:45:40: validate_n_random_basins: 1
# 2025-11-18 15:45:40: early_stopping: True
# 2025-11-18 15:45:40: patience_early_stopping: 10
# 2025-11-18 15:45:40: minimum_epochs_before_early_stopping: 15
# 2025-11-18 15:45:40: min_delta_early_stopping: 1e-07
# 2025-11-18 15:45:40: dynamic_learning_rate: True
# 2025-11-18 15:45:40: patience_dynamic_learning_rate: 5
# 2025-11-18 15:45:40: factor_dynamic_learning_rate: 0.4
# 2025-11-18 15:45:40: log_interval: 10
# 2025-11-18 15:45:40: log_n_figures: 1
# 2025-11-18 15:45:40: log_tensorboard: True
# 2025-11-18 15:45:40: save_train_data: False
# 2025-11-18 15:45:40: save_validation_results: False
# 2025-11-18 15:45:40: save_all_output: False
# 2025-11-18 15:45:40: save_weights_every: 10
# 2025-11-18 15:45:40: verbose: 1
# 2025-11-18 15:45:40: save_best_enabled: True
# 2025-11-18 15:45:40: save_best_criterion: sum_metrics
# 2025-11-18 15:45:40: save_in_csv: True
# 2025-11-18 15:45:40: csv_metrics_name: Metrics_over_Experiments
# 2025-11-18 15:45:40: nan_handling_method: masked_mean
# 2025-11-18 15:45:40: nan_step_probability: 0.0
# 2025-11-18 15:45:40: nan_sequence_probability: 0.0
# 2025-11-18 15:45:40: nan_handling_pos_encoding_size: 0
# 2025-11-18 15:45:40: number_of_basins: 1
# 2025-11-18 15:45:40: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\06_DB_RSv1\runs\Name1_1811_154540
# 2025-11-18 15:45:40: ### Device cuda:0 will be used for training
# 2025-11-18 15:45:40: Loading basin data into xarray dataset.
# 2025-11-18 15:45:41: Calculating target variable stds per basin
# 2025-11-18 15:45:41: Create lookup table and convert to pytorch tensor
# 2025-11-18 15:46:20: Epoch 1 average loss: avg_loss: 19.88430, avg_total_loss: 19.88430
# 2025-11-18 15:46:22: Epoch 1 average validation loss: 15.64862 -- Median validation metrics: avg_loss: 15.64862, MAPE: 17.38275, NSE: 0.88201, MSE: 57.55760, RMSE: 7.58667
# 2025-11-18 15:46:22: [saveBest] New best model found at epoch 1: 75.058332 (prev inf)
# 2025-11-18 15:46:25: Epoch 2 average loss: avg_loss: 14.07583, avg_total_loss: 14.07583
# 2025-11-18 15:46:27: Epoch 2 average validation loss: 15.39738 -- Median validation metrics: avg_loss: 15.39738, MAPE: 12.19256, NSE: 0.87652, MSE: 60.23730, RMSE: 7.76127
# 2025-11-18 15:46:27: [saveBest] New best model found at epoch 2: 72.553348 (prev 75.058332)
# 2025-11-18 15:46:30: Epoch 3 average loss: avg_loss: 12.40906, avg_total_loss: 12.40906
# 2025-11-18 15:46:31: Epoch 3 average validation loss: 13.39254 -- Median validation metrics: avg_loss: 13.39254, MAPE: 11.54676, NSE: 0.88338, MSE: 56.89144, RMSE: 7.54264
# 2025-11-18 15:47:52: [Scheduler] Learning rate changed from 4.0e-04 to 1.6e-04
# 2025-11-18 15:47:56: Epoch 21 average loss: avg_loss: 4.72608, avg_total_loss: 4.72608
# 2025-11-18 15:47:57: Epoch 21 average validation loss: 12.66989 -- Median validation metrics: avg_loss: 12.66989, MAPE: 11.44372, NSE: 0.91506, MSE: 41.43493, RMSE: 6.43700
# 2025-11-18 15:48:01: Epoch 22 average loss: avg_loss: 4.64789, avg_total_loss: 4.64789
# 2025-11-18 15:48:02: Epoch 22 average validation loss: 12.62894 -- Median validation metrics: avg_loss: 12.62894, MAPE: 11.40481, NSE: 0.91619, MSE: 40.88612, RMSE: 6.39423
# 2025-11-18 15:48:06: Epoch 23 average loss: avg_loss: 4.59578, avg_total_loss: 4.59578
# 2025-11-18 15:48:07: Epoch 23 average validation loss: 12.54586 -- Median validation metrics: avg_loss: 12.54586, MAPE: 11.28158, NSE: 0.91582, MSE: 41.06614, RMSE: 6.40829
# 2025-11-18 15:48:10: Epoch 24 average loss: avg_loss: 4.55346, avg_total_loss: 4.55346
# 2025-11-18 15:48:11: Epoch 24 average validation loss: 12.64936 -- Median validation metrics: avg_loss: 12.64936, MAPE: 11.43217, NSE: 0.91416, MSE: 41.87764, RMSE: 6.47129
# 2025-11-18 15:48:15: Epoch 25 average loss: avg_loss: 4.50795, avg_total_loss: 4.50795
# 2025-11-18 15:48:16: Epoch 25 average validation loss: 12.76253 -- Median validation metrics: avg_loss: 12.76253, MAPE: 11.39923, NSE: 0.91321, MSE: 42.33863, RMSE: 6.50681
# 2025-11-18 15:48:20: Epoch 26 average loss: avg_loss: 4.48311, avg_total_loss: 4.48311
# 2025-11-18 15:48:21: Epoch 26 average validation loss: 12.58316 -- Median validation metrics: avg_loss: 12.58316, MAPE: 11.29426, NSE: 0.91507, MSE: 41.43333, RMSE: 6.43687
# 2025-11-18 15:48:21: Early stopping triggered at epoch 26 with validation loss 12.58316. Training stopped.
# ==================================
#   Training ended successfully !
# ==================================
#
# Starting the EVALUATION on the test period:
# 2025-11-18 15:48:22: Using the model weights from c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\06_DB_RSv1\runs\Name1_1811_154540\best_model.pt
# ==================================
#   TEST ended successfully !
# ==================================

# %%
# basin="massa_RS_v1"
Metrics = dict_without_xr_key(results[basin]['1h'])
Metrics_ = Metrics.copy()

if cfg.save_in_csv and Evaluation_TEST:
    if Metrics_ is not None:
        summary_file =  Path(f"./{cfg.csv_metrics_name}.csv")
        Metrics_['experiment'] = run_dir.name

        summary_df = pd.DataFrame([Metrics_])
        
        # Append to summary file, creating it with a header if it doesn't exist
        summary_df.to_csv(f"{cfg.csv_metrics_name}.csv", mode='a', header=not summary_file.exists(), index=False)

# %% [markdown]
# ---

# %%
print("Metrics on the cuncatenated last predictions, on the Evaluation period:")
print(Metrics)
# Out:
# Metrics on the cuncatenated last predictions, on the Evaluation period:
# {'MAPE': 10.306257247924805, 'NSE': 0.9304522275924683, 'MSE': 33.92784118652344, 'RMSE': 5.8247610411521125}

# %%
# Path to your output.log file
log_path = Path(f"{run_dir}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path, verbose=False)


plot_training_curves(train_df, val_df, save_fig = save_plots_training, run_dir=run_dir)
plot_validation_metrics(val_df, save_fig = save_plots_training, run_dir=run_dir)

# %% [markdown]
# ---

# %% [markdown]
# ### Extract results from Test period

# %%
results_ = results[basin]["1h"]["xr"]
scores = dict_without_xr_key(results[basin]['1h'])

# store only the values in numpy arrays from xarray DataArrays
y_true = results_['streamflow_obs']
y_pred = results_['streamflow_sim']

verb = False
if verb: 
    print("\n-- Calculating MAPE values for each horizon: --\n")
    mapes = mape_array(y_true, y_pred, verbose=verb)
    print("\n-- MAPE calculation per horizon completed. --\n")
else:
    mapes = mape_array(y_true, y_pred, verbose=verb)

# %%
plot_mape_horizon(
    mapes,
    color="#e76f51",
    title=f"MAPE vs Forecast Horizon for basin {basin}"
)

# %%
scores_str = str.join(', ', [f"{key} : {scores[key]:.2f}" for key in scores])
title24 = f"Massa – {cfg.predict_last_n}h | " + scores_str

# plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[1, 6, cfg.predict_last_n])
plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[cfg.predict_last_n])

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 00:00:00",
#     xr_ds=results_
# ).show()
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 01:00:00",
#     xr_ds=results_
# ).show()

# %%
# Example to plot the forecast issued at the given time stamp and the n_forecast next predictions
# plot_forecast_horizon_series(
#     issue_date="2024-06-10 00:00:00",
#     xr_ds=results_,
#     n_forecasts=10
# ).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores - TEST period

# %% [markdown]
# ### Prediction at $t+24h$

# %%
qobs=results_['streamflow_obs']
qsim=results_['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.930
# MSE: 33.928
# RMSE: 5.825
# KGE: 0.946
# Alpha-NSE: 0.960
# Beta-KGE: 1.002
# Beta-NSE: 0.004
# Pearson-r: 0.965
# FHV: -10.783
# FMS: -5.762
# FLV: 5.100
# Peak-Timing: nan
# Peak-MAPE: 18.176
# MAPE: 10.306

# %% [markdown]
# ### Prediction at $t+7h$

# %%
values = metrics.calculate_all_metrics(qobs.isel(time_step=6), qsim.isel(time_step=6))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.953
# MSE: 22.565
# RMSE: 4.750
# KGE: 0.974
# Alpha-NSE: 1.005
# Beta-KGE: 1.010
# Beta-NSE: 0.018
# Pearson-r: 0.977
# FHV: -5.867
# FMS: -3.448
# FLV: -14.480
# Peak-Timing: nan
# Peak-MAPE: 13.149
# MAPE: 8.249
