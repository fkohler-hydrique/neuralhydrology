# %% [markdown]
# ## Imports

# %%
from   pathlib import Path
import matplotlib.pyplot as plt
import pickle
import torch
import pandas as pd
# import mlflow

from neuralhydrology.evaluation     import metrics
from neuralhydrology.nh_run         import start_run, eval_run
from neuralhydrology.datasetzoo     import register_dataset
from neuralhydrology.utils.config   import Config

from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)

# Custom functions plot_training_curves
from custom.functions.Plot import plot_training_curves, plot_validation_metrics
from custom.functions.Plot import plot_mape_horizon, plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series
from custom.functions.utils_fla import parse_neuralhydrology_log
from custom.functions.utils_fla import info_results, mape_array, dict_without_xr_key

# %% [markdown]
# ## Parameters of the run

# %%
# Initialisation of the config file, name of the experiment in the parameter experiment_name
config_file = Path("config_RSm_Q10.yml")
cfg = Config(config_file)

# Here write the name of the run if renamed run or if you want to plot the specified run, otherwise will take the run_dir created during training
# example: "expName_TimeStamp" 
runFile = None 

# list of basins, DB -> name of the basin.txt where the name of the csv is indicated
basin = "massa_with_RS"

# Whether you want to run a training, put false to plot your specific run folder for example
TRAIN, Evaluation_TEST = True, True

save_plots_training = True

# %% [markdown]
# ## Run

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        run_dir = start_run(config_file=Path(config_file))
    else:
        print("Using CPU")
        run_dir = start_run(config_file=Path(config_file), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
if runFile is not None:
    run_dir = Path(f"./runs/{runFile}")

if Evaluation_TEST:
    print("\nStarting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test", from_best=cfg.save_best_enabled)
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")

model_str = f"model_from_best"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-11-19 09:22:53: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\runs\RSm_Q10_1911_092253\output.log initialized.
# 2025-11-19 09:22:53: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\runs\RSm_Q10_1911_092253
# 2025-11-19 09:22:53: ### Run configurations for RSm_Q10
# 2025-11-19 09:22:53: experiment_name: RSm_Q10
# 2025-11-19 09:22:53: base_run_dir: runs
# 2025-11-19 09:22:53: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\runs\RSm_Q10_1911_092253\img_log
# 2025-11-19 09:22:53: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\runs\RSm_Q10_1911_092253\train_data
# 2025-11-19 09:22:53: seed: 42
# 2025-11-19 09:22:53: device: cuda:0
# 2025-11-19 09:22:53: num_workers: 16
# 2025-11-19 09:22:53: data_dir: ..\..\data
# 2025-11-19 09:22:53: dataset: swisshourly
# 2025-11-19 09:22:53: train_basin_file: ..\..\data\Data_RS.txt
# 2025-11-19 09:22:53: validation_basin_file: ..\..\data\Data_RS.txt
# 2025-11-19 09:22:53: test_basin_file: ..\..\data\Data_RS.txt
# 2025-11-19 09:22:53: train_start_date: 1983-03-04 00:00:00
# 2025-11-19 09:22:53: train_end_date: 2021-04-30 00:00:00
# 2025-11-19 09:22:53: validation_start_date: 2021-03-01 00:00:00
# 2025-11-19 09:22:53: validation_end_date: 2023-02-02 00:00:00
# 2025-11-19 09:22:53: test_start_date: 2023-02-03 00:00:00
# 2025-11-19 09:22:53: test_end_date: 2024-02-04 00:00:00
# 2025-11-19 09:22:53: dynamic_inputs: ['streamflow_hindcast', 'null_values', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus']
# 2025-11-19 09:22:53: hindcast_inputs: ['streamflow_hindcast', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus']
# 2025-11-19 09:22:53: forecast_inputs: ['null_values', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus']
# 2025-11-19 09:22:53: timestep_counter: True
# 2025-11-19 09:22:53: target_variables: ['streamflow']
# 2025-11-19 09:22:53: clip_targets_to_zero: ['streamflow']
# 2025-11-19 09:22:53: high_flow_only: True
# 2025-11-19 09:22:53: high_flow_target: streamflow
# 2025-11-19 09:22:53: high_flow_threshold: 10.0
# 2025-11-19 09:22:53: model: sequential_forecast_lstm
# 2025-11-19 09:22:53: head: regression
# 2025-11-19 09:22:53: hidden_size: 256
# 2025-11-19 09:22:53: output_activation: linear
# 2025-11-19 09:22:53: output_dropout: 0.1
# 2025-11-19 09:22:53: lstm_dropout: 0.0
# 2025-11-19 09:22:53: num_layers: 2
# 2025-11-19 09:22:53: initial_forget_bias: 1.5
# 2025-11-19 09:22:53: epochs: 10000
# 2025-11-19 09:22:53: learning_rate: 0.001
# 2025-11-19 09:22:53: batch_size: 32
# 2025-11-19 09:22:53: optimizer: AdamW
# 2025-11-19 09:22:53: loss: custom_loss
# 2025-11-19 09:22:53: seq_length: 72
# 2025-11-19 09:22:53: predict_last_n: 24
# 2025-11-19 09:22:53: forecast_seq_length: 24
# 2025-11-19 09:22:53: forecast_overlap: None
# 2025-11-19 09:22:53: custom_loss: {'losses': ['smape', 'nse', 'mse'], 'weights': [0.7, 0.2, 0.1]}
# 2025-11-19 09:22:53: clip_gradient_norm: 5.0
# 2025-11-19 09:22:53: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-11-19 09:22:53: validate_every: 1
# 2025-11-19 09:22:53: validate_n_random_basins: 1
# 2025-11-19 09:22:53: early_stopping: True
# 2025-11-19 09:22:53: patience_early_stopping: 10
# 2025-11-19 09:22:53: minimum_epochs_before_early_stopping: 10
# 2025-11-19 09:22:53: min_delta_early_stopping: 1e-07
# 2025-11-19 09:22:53: dynamic_learning_rate: True
# 2025-11-19 09:22:53: patience_dynamic_learning_rate: 5
# 2025-11-19 09:22:53: factor_dynamic_learning_rate: 0.4
# 2025-11-19 09:22:53: log_interval: 10
# 2025-11-19 09:22:53: log_n_figures: 1
# 2025-11-19 09:22:53: log_tensorboard: True
# 2025-11-19 09:22:53: save_train_data: False
# 2025-11-19 09:22:53: save_validation_results: False
# 2025-11-19 09:22:53: save_all_output: False
# 2025-11-19 09:22:53: save_weights_every: 10
# 2025-11-19 09:22:53: verbose: 1
# 2025-11-19 09:22:53: save_best_enabled: True
# 2025-11-19 09:22:53: save_best_criterion: sum_metrics
# 2025-11-19 09:22:53: save_in_csv: True
# 2025-11-19 09:22:53: csv_metrics_name: Metrics_over_Experiments
# 2025-11-19 09:22:53: nan_handling_method: masked_mean
# 2025-11-19 09:22:53: nan_step_probability: 0.0
# 2025-11-19 09:22:53: nan_sequence_probability: 0.0
# 2025-11-19 09:22:53: nan_handling_pos_encoding_size: 0
# 2025-11-19 09:22:53: number_of_basins: 1
# 2025-11-19 09:22:53: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\runs\RSm_Q10_1911_092253
# 2025-11-19 09:22:53: ### Device cuda:0 will be used for training
# 2025-11-19 09:22:53: Loading basin data into xarray dataset.
# 2025-11-19 09:22:54: Calculating target variable stds per basin
# 2025-11-19 09:22:54: Create lookup table and convert to pytorch tensor
# 2025-11-19 09:24:52: Epoch 1 average loss: avg_loss: 22.33130, avg_total_loss: 22.33130
# 2025-11-19 09:24:56: Epoch 1 average validation loss: 15.40973 -- Median validation metrics: avg_loss: 15.40973, MAPE: 11.10452, NSE: 0.91796, MSE: 34.20817, RMSE: 5.84878
# 2025-11-19 09:24:56: [saveBest] New best model found at epoch 1: 45.394724 (prev inf)
# 2025-11-19 09:26:07: Epoch 2 average loss: avg_loss: 16.20366, avg_total_loss: 16.20366
# 2025-11-19 09:26:09: Epoch 2 average validation loss: 14.11661 -- Median validation metrics: avg_loss: 14.11661, MAPE: 9.83062, NSE: 0.92936, MSE: 29.45752, RMSE: 5.42748
# 2025-11-19 09:26:09: [saveBest] New best model found at epoch 2: 39.358789 (prev 45.394724)
# 2025-11-19 09:27:21: Epoch 3 average loss: avg_loss: 14.51797, avg_total_loss: 14.51797
# 2025-11-19 09:27:24: Epoch 3 average validation loss: 12.88148 -- Median validation metrics: avg_loss: 12.88148, MAPE: 8.67340, NSE: 0.93982, MSE: 25.09387, RMSE: 5.00938
# 2025-11-19 09:27:24: [saveBest] New best model found at epoch 3: 33.827452 (prev 39.358789)
# 2025-11-19 09:28:36: Epoch 4 average loss: avg_loss: 13.35911, avg_total_loss: 13.35911
# 2025-11-19 09:28:39: Epoch 4 average validation loss: 12.74797 -- Median validation metrics: avg_loss: 12.74797, MAPE: 8.91565, NSE: 0.92923, MSE: 29.50909, RMSE: 5.43223
# 2025-11-19 09:29:59: Epoch 5 average loss: avg_loss: 12.41365, avg_total_loss: 12.41365
# 2025-11-19 09:30:01: Epoch 5 average validation loss: 12.14082 -- Median validation metrics: avg_loss: 12.14082, MAPE: 8.36778, NSE: 0.94075, MSE: 24.70619, RMSE: 4.97053
# 2025-11-19 09:30:01: [saveBest] New best model found at epoch 5: 33.133216 (prev 33.827452)
# 2025-11-19 09:31:14: Epoch 6 average loss: avg_loss: 11.58036, avg_total_loss: 11.58036
# 2025-11-19 09:31:16: Epoch 6 average validation loss: 12.49077 -- Median validation metrics: avg_loss: 12.49077, MAPE: 8.58126, NSE: 0.93566, MSE: 26.82971, RMSE: 5.17974
# 2025-11-19 09:32:29: Epoch 7 average loss: avg_loss: 10.79413, avg_total_loss: 10.79413
# 2025-11-19 09:32:31: Epoch 7 average validation loss: 12.54591 -- Median validation metrics: avg_loss: 12.54591, MAPE: 8.98752, NSE: 0.93531, MSE: 26.97502, RMSE: 5.19375
# 2025-11-19 09:33:44: Epoch 8 average loss: avg_loss: 10.08868, avg_total_loss: 10.08868
# 2025-11-19 09:33:46: Epoch 8 average validation loss: 12.29354 -- Median validation metrics: avg_loss: 12.29354, MAPE: 8.77821, NSE: 0.93985, MSE: 25.08313, RMSE: 5.00831
# 2025-11-19 09:34:59: Epoch 9 average loss: avg_loss: 9.49904, avg_total_loss: 9.49904
# 2025-11-19 09:35:01: Epoch 9 average validation loss: 12.36206 -- Median validation metrics: avg_loss: 12.36206, MAPE: 8.95017, NSE: 0.93682, MSE: 26.34491, RMSE: 5.13273
# 2025-11-19 09:36:15: Epoch 10 average loss: avg_loss: 8.98031, avg_total_loss: 8.98031
# 2025-11-19 09:36:17: Epoch 10 average validation loss: 12.08712 -- Median validation metrics: avg_loss: 12.08712, MAPE: 8.66712, NSE: 0.93439, MSE: 27.36048, RMSE: 5.23072
# 2025-11-19 09:37:38: Epoch 11 average loss: avg_loss: 8.54813, avg_total_loss: 8.54813
# 2025-11-19 09:37:41: Epoch 11 average validation loss: 12.53364 -- Median validation metrics: avg_loss: 12.53364, MAPE: 9.21050, NSE: 0.92990, MSE: 29.23137, RMSE: 5.40660
# 2025-11-19 09:37:41: [Scheduler] Learning rate changed from 1.0e-03 to 4.0e-04
# 2025-11-19 09:39:01: Epoch 12 average loss: avg_loss: 6.78380, avg_total_loss: 6.78380
# 2025-11-19 09:39:04: Epoch 12 average validation loss: 12.52499 -- Median validation metrics: avg_loss: 12.52499, MAPE: 9.31130, NSE: 0.92460, MSE: 31.44046, RMSE: 5.60718
# 2025-11-19 09:40:32: Epoch 13 average loss: avg_loss: 6.26560, avg_total_loss: 6.26560
# 2025-11-19 09:40:35: Epoch 13 average validation loss: 12.74866 -- Median validation metrics: avg_loss: 12.74866, MAPE: 9.32224, NSE: 0.92767, MSE: 30.16229, RMSE: 5.49202
# 2025-11-19 09:42:11: Epoch 14 average loss: avg_loss: 5.98903, avg_total_loss: 5.98903
# 2025-11-19 09:42:15: Epoch 14 average validation loss: 13.16411 -- Median validation metrics: avg_loss: 13.16411, MAPE: 9.49756, NSE: 0.92250, MSE: 32.31587, RMSE: 5.68471
# 2025-11-19 09:43:47: Epoch 15 average loss: avg_loss: 5.76357, avg_total_loss: 5.76357
# 2025-11-19 09:43:50: Epoch 15 average validation loss: 13.04596 -- Median validation metrics: avg_loss: 13.04596, MAPE: 9.57904, NSE: 0.92168, MSE: 32.65765, RMSE: 5.71469
# 2025-11-19 09:45:22: Epoch 16 average loss: avg_loss: 5.58098, avg_total_loss: 5.58098
# 2025-11-19 09:45:25: Epoch 16 average validation loss: 13.27269 -- Median validation metrics: avg_loss: 13.27269, MAPE: 9.73476, NSE: 0.92144, MSE: 32.75916, RMSE: 5.72356
# 2025-11-19 09:46:53: Epoch 17 average loss: avg_loss: 5.39428, avg_total_loss: 5.39428
# 2025-11-19 09:46:56: Epoch 17 average validation loss: 13.18739 -- Median validation metrics: avg_loss: 13.18739, MAPE: 9.65659, NSE: 0.92292, MSE: 32.14182, RMSE: 5.66938
# 2025-11-19 09:48:29: Epoch 18 average loss: avg_loss: 5.24728, avg_total_loss: 5.24728
# 2025-11-19 09:48:32: Epoch 18 average validation loss: 13.37426 -- Median validation metrics: avg_loss: 13.37426, MAPE: 9.94641, NSE: 0.91894, MSE: 33.80135, RMSE: 5.81389
# 2025-11-19 09:50:04: Epoch 19 average loss: avg_loss: 5.12389, avg_total_loss: 5.12389
# 2025-11-19 09:50:07: Epoch 19 average validation loss: 13.07781 -- Median validation metrics: avg_loss: 13.07781, MAPE: 9.63628, NSE: 0.92173, MSE: 32.63931, RMSE: 5.71308
# 2025-11-19 09:51:27: Epoch 20 average loss: avg_loss: 5.02537, avg_total_loss: 5.02537
# 2025-11-19 09:51:30: Epoch 20 average validation loss: 13.22089 -- Median validation metrics: avg_loss: 13.22089, MAPE: 9.79334, NSE: 0.92237, MSE: 32.37117, RMSE: 5.68957
# 2025-11-19 09:51:30: [Scheduler] Learning rate changed from 4.0e-04 to 1.6e-04
# 2025-11-19 09:53:04: Epoch 21 average loss: avg_loss: 4.18757, avg_total_loss: 4.18757
# 2025-11-19 09:53:07: Epoch 21 average validation loss: 13.51530 -- Median validation metrics: avg_loss: 13.51530, MAPE: 9.80712, NSE: 0.92045, MSE: 33.16946, RMSE: 5.75929
# 2025-11-19 09:54:31: Epoch 22 average loss: avg_loss: 4.02081, avg_total_loss: 4.02081
# 2025-11-19 09:54:33: Epoch 22 average validation loss: 13.50717 -- Median validation metrics: avg_loss: 13.50717, MAPE: 9.82740, NSE: 0.91945, MSE: 33.58998, RMSE: 5.79569
# 2025-11-19 09:54:33: Early stopping triggered at epoch 22 with validation loss 13.50717. Training stopped.
# ==================================
#   Training ended successfully !
# ==================================
#
# Starting the EVALUATION on the test period:
# 2025-11-19 09:54:35: Using the model weights from c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\runs\RSm_Q10_1911_092253\best_model.pt
# ==================================
#   TEST ended successfully !
# ==================================

# %%
Metrics = dict_without_xr_key(results[basin]['1h'])
Metrics_ = Metrics.copy()

if cfg.save_in_csv and Evaluation_TEST:
    if Metrics_ is not None:
        summary_file =  Path(f"./{cfg.csv_metrics_name}.csv")
        Metrics_['experiment'] = run_dir.name

        summary_df = pd.DataFrame([Metrics_])
        
        # Append to summary file, creating it with a header if it doesn't exist
        summary_df.to_csv(f"{cfg.csv_metrics_name}.csv", mode='a', header=not summary_file.exists(), index=False)

# %% [markdown]
# ---

# %%
print("Metrics on the cuncatenated last predictions, on the Evaluation period:")
print(Metrics)
# Out:
# Metrics on the cuncatenated last predictions, on the Evaluation period:
# {'MAPE': 9.350318908691406, 'NSE': 0.9359154105186462, 'MSE': 30.555335998535156, 'RMSE': 5.527688124210261}

# %%
# Path to your output.log file
log_path = Path(f"{run_dir}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path, verbose=False)


plot_training_curves(train_df, val_df, save_fig = save_plots_training, run_dir=run_dir)
plot_validation_metrics(val_df, save_fig = save_plots_training, run_dir=run_dir)

# %% [markdown]
# ---

# %% [markdown]
# ### Extract results from Test period

# %%
results_ = results[basin]["1h"]["xr"]
scores = dict_without_xr_key(results[basin]['1h'])

# store only the values in numpy arrays from xarray DataArrays
y_true = results_['streamflow_obs']
y_pred = results_['streamflow_sim']

verb = False
if verb: 
    print("\n-- Calculating MAPE values for each horizon: --\n")
    mapes = mape_array(y_true, y_pred, verbose=verb)
    print("\n-- MAPE calculation per horizon completed. --\n")
else:
    mapes = mape_array(y_true, y_pred, verbose=verb)

# %%
plot_mape_horizon(
    mapes,
    color="#e76f51",
    title=f"MAPE vs Forecast Horizon for basin {basin}"
)

# %%
y_true[:,0]
# Out:
# <xarray.DataArray 'streamflow_obs' (date: 4082)> Size: 16kB
# array([11.858    , 11.5564995, 11.413    , ...,  6.6279993,  6.4945   ,
#         6.347    ], shape=(4082,), dtype=float32)
# Coordinates:
#   * date       (date) datetime64[ns] 33kB 2023-05-07T22:00:00 ... 2023-10-24T...
#     time_step  int64 8B -23

# %%
scores_str = str.join(', ', [f"{key} : {scores[key]:.2f}" for key in scores])
title24 = f"Massa – {cfg.predict_last_n}h | " + scores_str

plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[1, 6, cfg.predict_last_n])
plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[cfg.predict_last_n])

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 00:00:00",
#     xr_ds=results_
# ).show()
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 01:00:00",
#     xr_ds=results_
# ).show()

# %%
# Example to plot the forecast issued at the given time stamp and the n_forecast next predictions
# plot_forecast_horizon_series(
#     issue_date="2024-06-10 00:00:00",
#     xr_ds=results_,
#     n_forecasts=10
# ).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores - TEST period

# %% [markdown]
# ### Prediction at $t+24h$

# %%
qobs=results_['streamflow_obs']
qsim=results_['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.936
# MSE: 30.555
# RMSE: 5.528
# KGE: 0.955
# Alpha-NSE: 0.969
# Beta-KGE: 1.001
# Beta-NSE: 0.002
# Pearson-r: 0.967
# FHV: -8.575
# FMS: -1.839
# FLV: -8.368
# Peak-Timing: nan
# Peak-MAPE: 16.084
# MAPE: 9.350

# %% [markdown]
# ### Prediction at $t+7h$

# %%
values = metrics.calculate_all_metrics(qobs.isel(time_step=6), qsim.isel(time_step=6))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.970
# MSE: 14.150
# RMSE: 3.762
# KGE: 0.981
# Alpha-NSE: 0.995
# Beta-KGE: 1.010
# Beta-NSE: 0.019
# Pearson-r: 0.985
# FHV: -3.703
# FMS: -1.426
# FLV: -7.931
# Peak-Timing: nan
# Peak-MAPE: 8.576
# MAPE: 5.831
