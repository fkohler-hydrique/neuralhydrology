# %% [markdown]
# ## Imports

# %%
from   pathlib import Path
import matplotlib.pyplot as plt
import pickle
import torch
import pandas as pd
# import mlflow

from neuralhydrology.evaluation     import metrics
from neuralhydrology.nh_run         import start_run, eval_run
from neuralhydrology.datasetzoo     import register_dataset
from neuralhydrology.utils.config   import Config

from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)

# Custom functions plot_training_curves
from custom.functions.Plot import plot_training_curves, plot_validation_metrics
from custom.functions.Plot import plot_mape_horizon, plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series
from custom.functions.utils_fla import parse_neuralhydrology_log
from custom.functions.utils_fla import info_results, mape_array, dict_without_xr_key

# %% [markdown]
# ## Parameters of the run

# %%
# Initialisation of the config file, name of the experiment in the parameter experiment_name
config_file = Path("config_explo1.yml")
cfg = Config(config_file)

# Here write the name of the run if renamed run or if you want to plot the specified run, otherwise will take the run_dir created during training
# example: "expName_TimeStamp" 
runFile = None 

# list of basins, DB -> name of the basin.txt where the name of the csv is indicated
basin = "massa_with_RS"

# Whether you want to run a training, put false to plot your specific run folder for example
TRAIN, Evaluation_TEST = True, True

save_plots_training = True

# %% [markdown]
# ## Run

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        run_dir = start_run(config_file=Path(config_file))
    else:
        print("Using CPU")
        run_dir = start_run(config_file=Path(config_file), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
if runFile is not None:
    run_dir = Path(f"./runs/{runFile}")

if Evaluation_TEST:
    print("\nStarting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test", from_best=cfg.save_best_enabled)
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")

model_str = f"model_from_best"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-11-10 09:05:26: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\Exploration\runs\explo1_1011_090526\output.log initialized.
# 2025-11-10 09:05:26: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\Exploration\runs\explo1_1011_090526
# 2025-11-10 09:05:26: ### Run configurations for explo1
# 2025-11-10 09:05:26: experiment_name: explo1
# 2025-11-10 09:05:26: base_run_dir: runs
# 2025-11-10 09:05:26: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\Exploration\runs\explo1_1011_090526\img_log
# 2025-11-10 09:05:26: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\Exploration\runs\explo1_1011_090526\train_data
# 2025-11-10 09:05:26: seed: 42
# 2025-11-10 09:05:26: device: cuda:0
# 2025-11-10 09:05:26: num_workers: 16
# 2025-11-10 09:05:26: data_dir: ..\..\..\data
# 2025-11-10 09:05:26: dataset: swisshourly
# 2025-11-10 09:05:26: train_basin_file: ..\..\..\data\Data_RS.txt
# 2025-11-10 09:05:26: validation_basin_file: ..\..\..\data\Data_RS.txt
# 2025-11-10 09:05:26: test_basin_file: ..\..\..\data\Data_RS.txt
# 2025-11-10 09:05:26: train_start_date: 1983-03-04 00:00:00
# 2025-11-10 09:05:26: train_end_date: 2021-04-30 00:00:00
# 2025-11-10 09:05:26: validation_start_date: 2021-03-01 00:00:00
# 2025-11-10 09:05:26: validation_end_date: 2023-02-02 00:00:00
# 2025-11-10 09:05:26: test_start_date: 2023-02-03 00:00:00
# 2025-11-10 09:05:26: test_end_date: 2024-02-04 00:00:00
# 2025-11-10 09:05:26: dynamic_inputs: ['streamflow_hindcast', 'null_values', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus']
# 2025-11-10 09:05:26: hindcast_inputs: ['streamflow_hindcast', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus']
# 2025-11-10 09:05:26: forecast_inputs: ['null_values', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus']
# 2025-11-10 09:05:26: timestep_counter: True
# 2025-11-10 09:05:26: target_variables: ['streamflow']
# 2025-11-10 09:05:26: clip_targets_to_zero: ['streamflow']
# 2025-11-10 09:05:26: model: sequential_forecast_lstm
# 2025-11-10 09:05:26: head: regression
# 2025-11-10 09:05:26: hidden_size: 256
# 2025-11-10 09:05:26: output_activation: linear
# 2025-11-10 09:05:26: output_dropout: 0.1
# 2025-11-10 09:05:26: lstm_dropout: 0.0
# 2025-11-10 09:05:26: num_layers: 2
# 2025-11-10 09:05:26: initial_forget_bias: 1.5
# 2025-11-10 09:05:26: epochs: 10000
# 2025-11-10 09:05:26: learning_rate: 0.001
# 2025-11-10 09:05:26: batch_size: 32
# 2025-11-10 09:05:26: optimizer: AdamW
# 2025-11-10 09:05:26: loss: custom_loss
# 2025-11-10 09:05:26: seq_length: 256
# 2025-11-10 09:05:26: predict_last_n: 24
# 2025-11-10 09:05:26: forecast_seq_length: 24
# 2025-11-10 09:05:26: forecast_overlap: None
# 2025-11-10 09:05:26: custom_loss: {'losses': ['smape', 'nse', 'mse'], 'weights': [0.7, 0.2, 0.1]}
# 2025-11-10 09:05:26: clip_gradient_norm: 5.0
# 2025-11-10 09:05:26: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-11-10 09:05:26: validate_every: 1
# 2025-11-10 09:05:26: validate_n_random_basins: 1
# 2025-11-10 09:05:26: early_stopping: True
# 2025-11-10 09:05:26: patience_early_stopping: 20
# 2025-11-10 09:05:26: minimum_epochs_before_early_stopping: 20
# 2025-11-10 09:05:26: min_delta_early_stopping: 1e-07
# 2025-11-10 09:05:26: dynamic_learning_rate: True
# 2025-11-10 09:05:26: patience_dynamic_learning_rate: 5
# 2025-11-10 09:05:26: factor_dynamic_learning_rate: 0.4
# 2025-11-10 09:05:26: log_interval: 10
# 2025-11-10 09:05:26: log_n_figures: 1
# 2025-11-10 09:05:26: log_tensorboard: True
# 2025-11-10 09:05:26: save_train_data: False
# 2025-11-10 09:05:26: save_validation_results: False
# 2025-11-10 09:05:26: save_all_output: False
# 2025-11-10 09:05:26: save_weights_every: 10
# 2025-11-10 09:05:26: verbose: 1
# 2025-11-10 09:05:26: save_best_enabled: True
# 2025-11-10 09:05:26: save_best_criterion: sum_metrics
# 2025-11-10 09:05:26: save_in_csv: True
# 2025-11-10 09:05:26: csv_metrics_name: Metrics_over_Experiments
# 2025-11-10 09:05:26: nan_handling_method: masked_mean
# 2025-11-10 09:05:26: nan_step_probability: 0.0
# 2025-11-10 09:05:26: nan_sequence_probability: 0.0
# 2025-11-10 09:05:26: nan_handling_pos_encoding_size: 0
# 2025-11-10 09:05:26: number_of_basins: 1
# 2025-11-10 09:05:26: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\Exploration\runs\explo1_1011_090526
# 2025-11-10 09:05:26: ### Device cuda:0 will be used for training
# 2025-11-10 09:05:26: Loading basin data into xarray data set.
# 2025-11-10 09:05:27: Calculating target variable stds per basin
# 2025-11-10 09:05:27: Create lookup table and convert to pytorch tensor
# 2025-11-10 09:17:55: Epoch 1 average loss: avg_loss: 8.80276, avg_total_loss: 8.80276
# 2025-11-10 09:18:14: Epoch 1 average validation loss: 6.24847 -- Median validation metrics: avg_loss: 6.24847, MAPE: 14.87795, NSE: 0.97851, MSE: 11.17566, RMSE: 3.34300
# 2025-11-10 09:18:14: [saveBest] New best model found at epoch 1: 26.075095 (prev inf)
# 2025-11-10 09:28:35: Epoch 2 average loss: avg_loss: 6.56045, avg_total_loss: 6.56045
# 2025-11-10 09:28:50: Epoch 2 average validation loss: 5.76762 -- Median validation metrics: avg_loss: 5.76762, MAPE: 8.41648, NSE: 0.98036, MSE: 10.21672, RMSE: 3.19636
# 2025-11-10 09:28:50: [saveBest] New best model found at epoch 2: 18.652849 (prev 26.075095)
# 2025-11-10 09:38:27: Epoch 3 average loss: avg_loss: 5.97811, avg_total_loss: 5.97811
# 2025-11-10 09:38:42: Epoch 3 average validation loss: 5.27485 -- Median validation metrics: avg_loss: 5.27485, MAPE: 8.30568, NSE: 0.98298, MSE: 8.85149, RMSE: 2.97514
# 2025-11-10 09:38:42: [saveBest] New best model found at epoch 3: 17.174182 (prev 18.652849)
# 2025-11-10 09:48:43: Epoch 4 average loss: avg_loss: 6.21480, avg_total_loss: 6.21480
# 2025-11-10 09:48:59: Epoch 4 average validation loss: 5.86608 -- Median validation metrics: avg_loss: 5.86608, MAPE: 19.70263, NSE: 0.98143, MSE: 9.66136, RMSE: 3.10827
# 2025-11-10 09:58:04: Epoch 5 average loss: avg_loss: 5.39077, avg_total_loss: 5.39077
# 2025-11-10 09:58:19: Epoch 5 average validation loss: 5.63575 -- Median validation metrics: avg_loss: 5.63575, MAPE: 11.49939, NSE: 0.98243, MSE: 9.13668, RMSE: 3.02269
# 2025-11-10 10:07:33: Epoch 6 average loss: avg_loss: 5.12619, avg_total_loss: 5.12619
# 2025-11-10 10:07:49: Epoch 6 average validation loss: 5.76367 -- Median validation metrics: avg_loss: 5.76367, MAPE: 10.16518, NSE: 0.98053, MSE: 10.12487, RMSE: 3.18196
# 2025-11-10 10:17:12: Epoch 7 average loss: avg_loss: 4.88066, avg_total_loss: 4.88066
# 2025-11-10 10:17:28: Epoch 7 average validation loss: 5.73337 -- Median validation metrics: avg_loss: 5.73337, MAPE: 20.68365, NSE: 0.98295, MSE: 8.86989, RMSE: 2.97824
# 2025-11-10 10:26:38: Epoch 8 average loss: avg_loss: 4.68241, avg_total_loss: 4.68241
# 2025-11-10 10:26:54: Epoch 8 average validation loss: 5.73171 -- Median validation metrics: avg_loss: 5.73171, MAPE: 11.09423, NSE: 0.98166, MSE: 9.53836, RMSE: 3.08842
# 2025-11-10 10:36:34: Epoch 9 average loss: avg_loss: 4.50866, avg_total_loss: 4.50866
# 2025-11-10 10:36:50: Epoch 9 average validation loss: 5.89675 -- Median validation metrics: avg_loss: 5.89675, MAPE: 21.76544, NSE: 0.98174, MSE: 9.49929, RMSE: 3.08209
# 2025-11-10 10:36:50: [Scheduler] - Learning rate changed from 1.0e-03 to 4.0e-04
# 2025-11-10 10:46:02: Epoch 10 average loss: avg_loss: 3.61827, avg_total_loss: 3.61827
# 2025-11-10 10:46:18: Epoch 10 average validation loss: 5.97728 -- Median validation metrics: avg_loss: 5.97728, MAPE: 12.72303, NSE: 0.97882, MSE: 11.01760, RMSE: 3.31928
# 2025-11-10 10:56:42: Epoch 11 average loss: avg_loss: 3.40368, avg_total_loss: 3.40368
# 2025-11-10 10:57:00: Epoch 11 average validation loss: 5.92759 -- Median validation metrics: avg_loss: 5.92759, MAPE: 7.92145, NSE: 0.98041, MSE: 10.18977, RMSE: 3.19214
# 2025-11-10 11:07:40: Epoch 12 average loss: avg_loss: 3.28671, avg_total_loss: 3.28671
# 2025-11-10 11:07:56: Epoch 12 average validation loss: 5.94458 -- Median validation metrics: avg_loss: 5.94458, MAPE: 8.00628, NSE: 0.97839, MSE: 11.24063, RMSE: 3.35270
# 2025-11-10 11:18:29: Epoch 13 average loss: avg_loss: 3.21391, avg_total_loss: 3.21391
# 2025-11-10 11:18:47: Epoch 13 average validation loss: 6.11443 -- Median validation metrics: avg_loss: 6.11443, MAPE: 9.06400, NSE: 0.97819, MSE: 11.34561, RMSE: 3.36832
# 2025-11-10 11:28:26: Epoch 14 average loss: avg_loss: 3.13470, avg_total_loss: 3.13470
# 2025-11-10 11:28:41: Epoch 14 average validation loss: 6.16056 -- Median validation metrics: avg_loss: 6.16056, MAPE: 11.39766, NSE: 0.97807, MSE: 11.40800, RMSE: 3.37757
# 2025-11-10 11:38:22: Epoch 15 average loss: avg_loss: 3.08156, avg_total_loss: 3.08156
# 2025-11-10 11:38:40: Epoch 15 average validation loss: 6.02370 -- Median validation metrics: avg_loss: 6.02370, MAPE: 8.17382, NSE: 0.97932, MSE: 10.75459, RMSE: 3.27942
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       3 if torch.cuda.is_available() or torch.backends.mps.is_available():
#       4     print("Using GPU")
# ----> 5     run_dir = start_run(config_file=Path(config_file))
#       6 else:
#       7     print("Using CPU")
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\nh_run.py:77, in start_run(config_file, gpu)
#      74 if gpu is not None and gpu < 0:
#      75     config.device = "cpu"
# ---> 77 return(start_training(config))
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\train.py:20, in start_training(cfg)
#      18     raise ValueError(f"Unknown head {cfg.head}.")
#      19 trainer.initialize_training()
# ---> 20 trainer.train_and_validate()
#      21 return cfg.run_dir
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\basetrainer.py:259, in BaseTrainer.train_and_validate(self)
#     256         for param_group in self.optimizer.param_groups:
#     257             param_group["lr"] = self.cfg.learning_rate[epoch]
# --> 259 self._train_epoch(epoch=epoch)
#     260 avg_losses = self.experiment_logger.summarise()
#     261 loss_str = ", ".join(f"{k}: {v:.5f}" for k, v in avg_losses.items())
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\basetrainer.py:447, in BaseTrainer._train_epoch(self, epoch)
#     444 nan_count = 0
#     446 # get gradients
# --> 447 loss.backward()
#     449 if self.cfg.clip_gradient_norm is not None:
#     450     torch.nn.utils.clip_grad_norm_(self.model.parameters(), self.cfg.clip_gradient_norm)
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)    645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\autograd\graph.py:829, in _engine_run_backward(t_outputs, *args, **kwargs)
#     827     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828 try:
# --> 829     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830         t_outputs, *args, **kwargs
#     831     )  # Calls into the C++ engine to run the backward pass
#     832 finally:
#     833     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
Metrics = dict_without_xr_key(results[basin]['1h'])
Metrics_ = Metrics.copy()

if cfg.save_in_csv and Evaluation_TEST:
    if Metrics_ is not None:
        summary_file =  Path(f"./{cfg.csv_metrics_name}.csv")
        Metrics_['experiment'] = run_dir.name

        summary_df = pd.DataFrame([Metrics_])
        
        # Append to summary file, creating it with a header if it doesn't exist
        summary_df.to_csv(f"{cfg.csv_metrics_name}.csv", mode='a', header=not summary_file.exists(), index=False)

# %% [markdown]
# ---

# %%
print("Metrics on the cuncatenated last predictions, on the Evaluation period:")
print(Metrics)
# Out:
# Metrics on the cuncatenated last predictions, on the Evaluation period:
# {'MAPE': 9.510801315307617, 'NSE': 0.9754041433334351, 'MSE': 14.149535179138184, 'RMSE': 3.761586790057912}

# %%
# Path to your output.log file
log_path = Path(f"{run_dir}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path, verbose=False)


plot_training_curves(train_df, val_df, save_fig = save_plots_training, run_dir=run_dir)
plot_validation_metrics(val_df, save_fig = save_plots_training, run_dir=run_dir)

# %% [markdown]
# ---

# %% [markdown]
# ### Extract results from Test period

# %%
results_ = results[basin]["1h"]["xr"]
scores = dict_without_xr_key(results[basin]['1h'])

# store only the values in numpy arrays from xarray DataArrays
y_true = results_['streamflow_obs']
y_pred = results_['streamflow_sim']

verb = False
if verb: 
    print("\n-- Calculating MAPE values for each horizon: --\n")
    mapes = mape_array(y_true, y_pred, verbose=verb)
    print("\n-- MAPE calculation per horizon completed. --\n")
else:
    mapes = mape_array(y_true, y_pred, verbose=verb)

# %%
plot_mape_horizon(
    mapes,
    color="#e76f51",
    title=f"MAPE vs Forecast Horizon for basin {basin}"
)

# %%
scores_str = str.join(', ', [f"{key} : {scores[key]:.2f}" for key in scores])
title24 = f"Massa – {cfg.predict_last_n}h | " + scores_str

# plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[1, 6, cfg.predict_last_n])
plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[cfg.predict_last_n])

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 00:00:00",
#     xr_ds=results_
# ).show()
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 01:00:00",
#     xr_ds=results_
# ).show()

# %%
# Example to plot the forecast issued at the given time stamp and the n_forecast next predictions
# plot_forecast_horizon_series(
#     issue_date="2024-06-10 00:00:00",
#     xr_ds=results_,
#     n_forecasts=10
# ).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores - TEST period

# %% [markdown]
# ### Prediction at $t+24h$

# %%
qobs=results_['streamflow_obs']
qsim=results_['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.975
# MSE: 14.150
# RMSE: 3.762
# KGE: 0.975
# Alpha-NSE: 0.982
# Beta-KGE: 0.988
# Beta-NSE: -0.010
# Pearson-r: 0.988
# FHV: -4.532
# FMS: 0.672
# FLV: 5.326
# Peak-Timing: nan
# Peak-MAPE: 16.777
# MAPE: 9.511

# %% [markdown]
# ### Prediction at $t+7h$

# %%
values = metrics.calculate_all_metrics(qobs.isel(time_step=6), qsim.isel(time_step=6))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.989
# MSE: 6.205
# RMSE: 2.491
# KGE: 0.968
# Alpha-NSE: 0.974
# Beta-KGE: 0.983
# Beta-NSE: -0.013
# Pearson-r: 0.995
# FHV: -5.197
# FMS: -1.354
# FLV: -83.610
# Peak-Timing: nan
# Peak-MAPE: 10.759
# MAPE: 7.563
