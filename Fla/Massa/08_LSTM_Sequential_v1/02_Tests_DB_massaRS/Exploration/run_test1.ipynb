# %% [markdown]
# ## Imports

# %%
from   pathlib import Path
import matplotlib.pyplot as plt
import pickle
import torch
import pandas as pd
# import mlflow

from neuralhydrology.evaluation     import metrics
from neuralhydrology.nh_run         import start_run, eval_run
from neuralhydrology.datasetzoo     import register_dataset
from neuralhydrology.utils.config   import Config

from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)

# Custom functions plot_training_curves
from custom.functions.Plot import plot_training_curves, plot_validation_metrics
from custom.functions.Plot import plot_mape_horizon, plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series
from custom.functions.utils_fla import parse_neuralhydrology_log
from custom.functions.utils_fla import info_results, mape_array, dict_without_xr_key

# %% [markdown]
# ## Parameters of the run

# %%
# Initialisation of the config file, name of the experiment in the parameter experiment_name
config_file = Path("config_test1.yml")
cfg = Config(config_file)

# Here write the name of the run if renamed run or if you want to plot the specified run, otherwise will take the run_dir created during training
# example: "expName_TimeStamp" 
runFile = None 

# list of basins, DB -> name of the basin.txt where the name of the csv is indicated
basin = "massa_with_RS"

# Whether you want to run a training, put false to plot your specific run folder for example
TRAIN, Evaluation_TEST = True, True

save_plots_training = True

# %% [markdown]
# ## Run

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        run_dir = start_run(config_file=Path(config_file))
    else:
        print("Using CPU")
        run_dir = start_run(config_file=Path(config_file), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
if runFile is not None:
    run_dir = Path(f"./runs/{runFile}")

if Evaluation_TEST:
    print("\nStarting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test", from_best=cfg.save_best_enabled)
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")

model_str = f"model_from_best"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-11-14 09:57:29: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\Exploration\runs\test1_1411_095729\output.log initialized.
# 2025-11-14 09:57:29: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\Exploration\runs\test1_1411_095729
# 2025-11-14 09:57:29: ### Run configurations for test1
# 2025-11-14 09:57:29: experiment_name: test1
# 2025-11-14 09:57:29: base_run_dir: runs
# 2025-11-14 09:57:29: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\Exploration\runs\test1_1411_095729\img_log
# 2025-11-14 09:57:29: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\Exploration\runs\test1_1411_095729\train_data
# 2025-11-14 09:57:29: seed: 42
# 2025-11-14 09:57:29: device: cuda:0
# 2025-11-14 09:57:29: num_workers: 16
# 2025-11-14 09:57:29: data_dir: ..\..\..\data
# 2025-11-14 09:57:29: dataset: swisshourly
# 2025-11-14 09:57:29: train_basin_file: ..\..\..\data\Data_RS.txt
# 2025-11-14 09:57:29: validation_basin_file: ..\..\..\data\Data_RS.txt
# 2025-11-14 09:57:29: test_basin_file: ..\..\..\data\Data_RS.txt
# 2025-11-14 09:57:29: train_start_date: 1983-03-04 00:00:00
# 2025-11-14 09:57:29: train_end_date: 2019-04-30 00:00:00
# 2025-11-14 09:57:29: validation_start_date: 2019-03-01 00:00:00
# 2025-11-14 09:57:29: validation_end_date: 2022-02-02 00:00:00
# 2025-11-14 09:57:29: test_start_date: 2022-02-03 00:00:00
# 2025-11-14 09:57:29: test_end_date: 2024-02-04 00:00:00
# 2025-11-14 09:57:29: dynamic_inputs: ['Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus', 'streamflow_hindcast', 'null_values']
# 2025-11-14 09:57:29: hindcast_inputs: ['Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus', 'streamflow_hindcast']
# 2025-11-14 09:57:29: forecast_inputs: ['Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus', 'null_values']
# 2025-11-14 09:57:29: timestep_counter: True
# 2025-11-14 09:57:29: target_variables: ['streamflow']
# 2025-11-14 09:57:29: clip_targets_to_zero: ['streamflow']
# 2025-11-14 09:57:29: model: sequential_forecast_lstm
# 2025-11-14 09:57:29: head: regression
# 2025-11-14 09:57:29: hidden_size: 64
# 2025-11-14 09:57:29: output_activation: linear
# 2025-11-14 09:57:29: output_dropout: 0.15
# 2025-11-14 09:57:29: lstm_dropout: 0.0
# 2025-11-14 09:57:29: num_layers: 1
# 2025-11-14 09:57:29: initial_forget_bias: 2.5
# 2025-11-14 09:57:29: epochs: 10000
# 2025-11-14 09:57:29: learning_rate: 0.001
# 2025-11-14 09:57:29: batch_size: 256
# 2025-11-14 09:57:29: optimizer: AdamW
# 2025-11-14 09:57:29: loss: custom_loss
# 2025-11-14 09:57:29: seq_length: 96
# 2025-11-14 09:57:29: predict_last_n: 24
# 2025-11-14 09:57:29: forecast_seq_length: 24
# 2025-11-14 09:57:29: forecast_overlap: None
# 2025-11-14 09:57:29: custom_loss: {'losses': ['smape', 'mse', 'nse'], 'weights': [0.8, 0.1, 0.1]}
# 2025-11-14 09:57:29: clip_gradient_norm: 5.0
# 2025-11-14 09:57:29: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-11-14 09:57:29: validate_every: 1
# 2025-11-14 09:57:29: validate_n_random_basins: 1
# 2025-11-14 09:57:29: early_stopping: True
# 2025-11-14 09:57:29: patience_early_stopping: 10
# 2025-11-14 09:57:29: minimum_epochs_before_early_stopping: 10
# 2025-11-14 09:57:29: min_delta_early_stopping: 1e-07
# 2025-11-14 09:57:29: dynamic_learning_rate: True
# 2025-11-14 09:57:29: patience_dynamic_learning_rate: 3
# 2025-11-14 09:57:29: factor_dynamic_learning_rate: 0.4
# 2025-11-14 09:57:29: log_interval: 10
# 2025-11-14 09:57:29: log_n_figures: 1
# 2025-11-14 09:57:29: log_tensorboard: True
# 2025-11-14 09:57:29: save_train_data: False
# 2025-11-14 09:57:29: save_validation_results: False
# 2025-11-14 09:57:29: save_all_output: False
# 2025-11-14 09:57:29: save_weights_every: 10
# 2025-11-14 09:57:29: verbose: 1
# 2025-11-14 09:57:29: save_best_enabled: True
# 2025-11-14 09:57:29: save_best_criterion: MAPE
# 2025-11-14 09:57:29: save_in_csv: True
# 2025-11-14 09:57:29: csv_metrics_name: Metrics_over_Experiments
# 2025-11-14 09:57:29: nan_handling_method: masked_mean
# 2025-11-14 09:57:29: nan_step_probability: 0.0
# 2025-11-14 09:57:29: nan_sequence_probability: 0.0
# 2025-11-14 09:57:29: nan_handling_pos_encoding_size: 0
# 2025-11-14 09:57:29: number_of_basins: 1
# 2025-11-14 09:57:29: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\Exploration\runs\test1_1411_095729
# 2025-11-14 09:57:29: ### Device cuda:0 will be used for training
# 2025-11-14 09:57:29: Loading basin data into xarray dataset.
# 2025-11-14 09:57:30: Calculating target variable stds per basin
# 2025-11-14 09:57:30: Create lookup table and convert to PyTorch tensor
# 2025-11-14 09:58:42: Epoch 1 average loss: avg_loss: 16.12439, avg_total_loss: 16.12439
# 2025-11-14 09:58:46: Epoch 1 average validation loss: 10.06586 -- Median validation metrics: avg_loss: 10.06586, MAPE: 24.70192, NSE: 0.95602, MSE: 20.08517, RMSE: 4.48165
# 2025-11-14 09:58:46: [saveBest] New best model found at epoch 1: 24.701916 (prev inf)
# 2025-11-14 09:59:06: Epoch 2 average loss: avg_loss: 11.01115, avg_total_loss: 11.01115
# 2025-11-14 09:59:09: Epoch 2 average validation loss: 8.87629 -- Median validation metrics: avg_loss: 8.87629, MAPE: 12.18002, NSE: 0.96540, MSE: 15.80145, RMSE: 3.97510
# 2025-11-14 09:59:09: [saveBest] New best model found at epoch 2: 12.180020 (prev 24.701916)
# 2025-11-14 09:59:28: Epoch 3 average loss: avg_loss: 9.97080, avg_total_loss: 9.97080
# 2025-11-14 09:59:32: Epoch 3 average validation loss: 8.84616 -- Median validation metrics: avg_loss: 8.84616, MAPE: 11.94231, NSE: 0.97158, MSE: 12.97823, RMSE: 3.60253
# 2025-11-14 09:59:32: [saveBest] New best model found at epoch 3: 11.942309 (prev 12.180020)
# 2025-11-14 09:59:51: Epoch 4 average loss: avg_loss: 9.45349, avg_total_loss: 9.45349
# 2025-11-14 09:59:53: Epoch 4 average validation loss: 8.02857 -- Median validation metrics: avg_loss: 8.02857, MAPE: 16.82279, NSE: 0.97167, MSE: 12.93869, RMSE: 3.59704
# 2025-11-14 10:00:12: Epoch 5 average loss: avg_loss: 9.13232, avg_total_loss: 9.13232
# 2025-11-14 10:00:15: Epoch 5 average validation loss: 8.15819 -- Median validation metrics: avg_loss: 8.15819, MAPE: 13.56702, NSE: 0.97154, MSE: 12.99992, RMSE: 3.60554
# 2025-11-14 10:00:33: Epoch 6 average loss: avg_loss: 8.91577, avg_total_loss: 8.91577
# 2025-11-14 10:00:35: Epoch 6 average validation loss: 7.67084 -- Median validation metrics: avg_loss: 7.67084, MAPE: 9.43568, NSE: 0.97661, MSE: 10.68151, RMSE: 3.26826
# 2025-11-14 10:00:35: [saveBest] New best model found at epoch 6: 9.435676 (prev 11.942309)
# 2025-11-14 10:00:52: Epoch 7 average loss: avg_loss: 8.79060, avg_total_loss: 8.79060
# 2025-11-14 10:00:55: Epoch 7 average validation loss: 7.78260 -- Median validation metrics: avg_loss: 7.78260, MAPE: 9.02221, NSE: 0.97499, MSE: 11.42148, RMSE: 3.37957
# 2025-11-14 10:00:55: [saveBest] New best model found at epoch 7: 9.022209 (prev 9.435676)
# 2025-11-14 10:01:13: Epoch 8 average loss: avg_loss: 8.68063, avg_total_loss: 8.68063
# 2025-11-14 10:01:15: Epoch 8 average validation loss: 7.82284 -- Median validation metrics: avg_loss: 7.82284, MAPE: 14.31465, NSE: 0.97325, MSE: 12.21702, RMSE: 3.49528
# 2025-11-14 10:01:15: [Scheduler] Learning rate changed from 1.0e-03 to 4.0e-04
# 2025-11-14 10:01:33: Epoch 9 average loss: avg_loss: 8.31284, avg_total_loss: 8.31284
# 2025-11-14 10:01:36: Epoch 9 average validation loss: 7.39710 -- Median validation metrics: avg_loss: 7.39710, MAPE: 8.69922, NSE: 0.97694, MSE: 10.53241, RMSE: 3.24537
# 2025-11-14 10:01:36: [saveBest] New best model found at epoch 9: 8.699224 (prev 9.022209)
# 2025-11-14 10:01:54: Epoch 10 average loss: avg_loss: 8.25408, avg_total_loss: 8.25408
# 2025-11-14 10:01:57: Epoch 10 average validation loss: 7.19761 -- Median validation metrics: avg_loss: 7.19761, MAPE: 8.68594, NSE: 0.97701, MSE: 10.49841, RMSE: 3.24012
# 2025-11-14 10:01:57: [saveBest] New best model found at epoch 10: 8.685941 (prev 8.699224)
# 2025-11-14 10:02:17: Epoch 11 average loss: avg_loss: 8.18181, avg_total_loss: 8.18181
# 2025-11-14 10:02:20: Epoch 11 average validation loss: 7.36248 -- Median validation metrics: avg_loss: 7.36248, MAPE: 11.59879, NSE: 0.97771, MSE: 10.17970, RMSE: 3.19056
# 2025-11-14 10:10:18: Epoch 30 average loss: avg_loss: 7.62175, avg_total_loss: 7.62175
# 2025-11-14 10:10:21: Epoch 30 average validation loss: 7.14059 -- Median validation metrics: avg_loss: 7.14059, MAPE: 8.04685, NSE: 0.97774, MSE: 10.16774, RMSE: 3.18869
# 2025-11-14 10:10:43: Epoch 31 average loss: avg_loss: 7.61620, avg_total_loss: 7.61620
# 2025-11-14 10:10:46: Epoch 31 average validation loss: 7.13938 -- Median validation metrics: avg_loss: 7.13938, MAPE: 8.06808, NSE: 0.97813, MSE: 9.98975, RMSE: 3.16066
# 2025-11-14 10:11:07: Epoch 32 average loss: avg_loss: 7.61524, avg_total_loss: 7.61524
# 2025-11-14 10:11:10: Epoch 32 average validation loss: 7.15439 -- Median validation metrics: avg_loss: 7.15439, MAPE: 8.03228, NSE: 0.97868, MSE: 9.73771, RMSE: 3.12053
# 2025-11-14 10:11:31: Epoch 33 average loss: avg_loss: 7.61279, avg_total_loss: 7.61279
# 2025-11-14 10:11:34: Epoch 33 average validation loss: 7.14856 -- Median validation metrics: avg_loss: 7.14856, MAPE: 8.31524, NSE: 0.97796, MSE: 10.06726, RMSE: 3.17289
# 2025-11-14 10:11:54: Epoch 34 average loss: avg_loss: 7.61434, avg_total_loss: 7.61434
# 2025-11-14 10:11:57: Epoch 34 average validation loss: 7.09313 -- Median validation metrics: avg_loss: 7.09313, MAPE: 8.18173, NSE: 0.97861, MSE: 9.77045, RMSE: 3.12577
# 2025-11-14 10:12:19: Epoch 35 average loss: avg_loss: 7.60633, avg_total_loss: 7.60633
# 2025-11-14 10:12:22: Epoch 35 average validation loss: 7.06156 -- Median validation metrics: avg_loss: 7.06156, MAPE: 7.79023, NSE: 0.97839, MSE: 9.87048, RMSE: 3.14173
# 2025-11-14 10:12:22: [saveBest] New best model found at epoch 35: 7.790235 (prev 7.855462)
# 2025-11-14 10:12:22: Early stopping triggered at epoch 35 with validation loss 7.06156. Training stopped.
# ==================================
#   Training ended successfully !
# ==================================
#
# Starting the EVALUATION on the test period:
# 2025-11-14 10:12:25: Using the model weights from c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\Exploration\runs\test1_1411_095729\best_model.pt
# ==================================
#   TEST ended successfully !
# ==================================

# %%
Metrics = dict_without_xr_key(results[basin]['1h'])
Metrics_ = Metrics.copy()

if cfg.save_in_csv and Evaluation_TEST:
    if Metrics_ is not None:
        summary_file =  Path(f"./{cfg.csv_metrics_name}.csv")
        Metrics_['experiment'] = run_dir.name

        summary_df = pd.DataFrame([Metrics_])
        
        # Append to summary file, creating it with a header if it doesn't exist
        summary_df.to_csv(f"{cfg.csv_metrics_name}.csv", mode='a', header=not summary_file.exists(), index=False)

# %% [markdown]
# ---

# %%
print("Metrics on the cuncatenated last predictions, on the Evaluation period:")
print(Metrics)
# Out:
# Metrics on the cuncatenated last predictions, on the Evaluation period:
# {'MAPE': 8.886185646057129, 'NSE': 0.9765158295631409, 'MSE': 14.492006301879883, 'RMSE': 3.806836784244878}

# %%
# Path to your output.log file
log_path = Path(f"{run_dir}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path, verbose=False)


plot_training_curves(train_df, val_df, save_fig = save_plots_training, run_dir=run_dir)
plot_validation_metrics(val_df, save_fig = save_plots_training, run_dir=run_dir)

# %% [markdown]
# ---

# %% [markdown]
# ### Extract results from Test period

# %%
results_ = results[basin]["1h"]["xr"]
scores = dict_without_xr_key(results[basin]['1h'])

# store only the values in numpy arrays from xarray DataArrays
y_true = results_['streamflow_obs']
y_pred = results_['streamflow_sim']

verb = False
if verb: 
    print("\n-- Calculating MAPE values for each horizon: --\n")
    mapes = mape_array(y_true, y_pred, verbose=verb)
    print("\n-- MAPE calculation per horizon completed. --\n")
else:
    mapes = mape_array(y_true, y_pred, verbose=verb)

# %%
plot_mape_horizon(
    mapes,
    color="#e76f51",
    title=f"MAPE vs Forecast Horizon for basin {basin}"
)

# %%
scores_str = str.join(', ', [f"{key} : {scores[key]:.2f}" for key in scores])
title24 = f"Massa – {cfg.predict_last_n}h | " + scores_str

# plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[1, 6, cfg.predict_last_n])
plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[cfg.predict_last_n])

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 00:00:00",
#     xr_ds=results_
# ).show()
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 01:00:00",
#     xr_ds=results_
# ).show()

# %%
# Example to plot the forecast issued at the given time stamp and the n_forecast next predictions
# plot_forecast_horizon_series(
#     issue_date="2024-06-10 00:00:00",
#     xr_ds=results_,
#     n_forecasts=10
# ).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores - TEST period

# %% [markdown]
# ### Prediction at $t+24h$

# %%
qobs=results_['streamflow_obs']
qsim=results_['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.977
# MSE: 14.492
# RMSE: 3.807
# KGE: 0.956
# Alpha-NSE: 0.963
# Beta-KGE: 0.980
# Beta-NSE: -0.015
# Pearson-r: 0.989
# FHV: -10.416
# FMS: 0.284
# FLV: 11.870
# Peak-Timing: nan
# Peak-MAPE: 16.229
# MAPE: 8.886

# %% [markdown]
# ### Prediction at $t+7h$

# %%
values = metrics.calculate_all_metrics(qobs.isel(time_step=6), qsim.isel(time_step=6))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.985
# MSE: 9.197
# RMSE: 3.033
# KGE: 0.969
# Alpha-NSE: 0.972
# Beta-KGE: 0.990
# Beta-NSE: -0.008
# Pearson-r: 0.993
# FHV: -9.601
# FMS: -0.176
# FLV: 15.574
# Peak-Timing: nan
# Peak-MAPE: 13.150
# MAPE: 6.549
