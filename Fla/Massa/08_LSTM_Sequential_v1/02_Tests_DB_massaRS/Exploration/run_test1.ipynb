# %% [markdown]
# ## Imports

# %%
from   pathlib import Path
import matplotlib.pyplot as plt
import pickle
import torch
import pandas as pd
# import mlflow

from neuralhydrology.evaluation     import metrics
from neuralhydrology.nh_run         import start_run, eval_run
from neuralhydrology.datasetzoo     import register_dataset
from neuralhydrology.utils.config   import Config

from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)

# Custom functions plot_training_curves
from custom.functions.Plot import plot_training_curves, plot_validation_metrics
from custom.functions.Plot import plot_mape_horizon, plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series
from custom.functions.utils_fla import parse_neuralhydrology_log
from custom.functions.utils_fla import info_results, mape_array, dict_without_xr_key

# %% [markdown]
# ## Parameters of the run

# %%
# Initialisation of the config file, name of the experiment in the parameter experiment_name
config_file = Path("config_test1.yml")
cfg = Config(config_file)

# Here write the name of the run if renamed run or if you want to plot the specified run, otherwise will take the run_dir created during training
# example: "expName_TimeStamp" 
runFile = None 

# list of basins, DB -> name of the basin.txt where the name of the csv is indicated
basin = "massa_with_RS"

# Whether you want to run a training, put false to plot your specific run folder for example
TRAIN, Evaluation_TEST = True, True

save_plots_training = True

# %% [markdown]
# ## Run

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        run_dir = start_run(config_file=Path(config_file))
    else:
        print("Using CPU")
        run_dir = start_run(config_file=Path(config_file), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
if runFile is not None:
    run_dir = Path(f"./runs/{runFile}")

if Evaluation_TEST:
    print("\nStarting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test", from_best=cfg.save_best_enabled)
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")

model_str = f"model_from_best"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-11-11 16:13:24: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\Exploration\runs\test1_1111_161324\output.log initialized.
# 2025-11-11 16:13:24: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\Exploration\runs\test1_1111_161324
# 2025-11-11 16:13:24: ### Run configurations for test1
# 2025-11-11 16:13:24: experiment_name: test1
# 2025-11-11 16:13:24: base_run_dir: runs
# 2025-11-11 16:13:24: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\Exploration\runs\test1_1111_161324\img_log
# 2025-11-11 16:13:24: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\Exploration\runs\test1_1111_161324\train_data
# 2025-11-11 16:13:24: seed: 42
# 2025-11-11 16:13:24: device: cuda:0
# 2025-11-11 16:13:24: num_workers: 16
# 2025-11-11 16:13:24: data_dir: ..\..\..\data
# 2025-11-11 16:13:24: dataset: swisshourly
# 2025-11-11 16:13:24: train_basin_file: ..\..\..\data\Data_RS.txt
# 2025-11-11 16:13:24: validation_basin_file: ..\..\..\data\Data_RS.txt
# 2025-11-11 16:13:24: test_basin_file: ..\..\..\data\Data_RS.txt
# 2025-11-11 16:13:24: train_start_date: 1983-03-04 00:00:00
# 2025-11-11 16:13:24: train_end_date: 2019-04-30 00:00:00
# 2025-11-11 16:13:24: validation_start_date: 2019-03-01 00:00:00
# 2025-11-11 16:13:24: validation_end_date: 2022-02-02 00:00:00
# 2025-11-11 16:13:24: test_start_date: 2022-02-03 00:00:00
# 2025-11-11 16:13:24: test_end_date: 2024-02-04 00:00:00
# 2025-11-11 16:13:24: dynamic_inputs: ['Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus', 'streamflow_hindcast', 'null_values']
# 2025-11-11 16:13:24: hindcast_inputs: ['Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus', 'streamflow_hindcast']
# 2025-11-11 16:13:24: forecast_inputs: ['Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus', 'null_values']
# 2025-11-11 16:13:24: timestep_counter: True
# 2025-11-11 16:13:24: target_variables: ['streamflow']
# 2025-11-11 16:13:24: clip_targets_to_zero: ['streamflow']
# 2025-11-11 16:13:24: model: sequential_forecast_lstm
# 2025-11-11 16:13:24: head: regression
# 2025-11-11 16:13:24: hidden_size: 64
# 2025-11-11 16:13:24: output_activation: linear
# 2025-11-11 16:13:24: output_dropout: 0.15
# 2025-11-11 16:13:24: lstm_dropout: 0.0
# 2025-11-11 16:13:24: num_layers: 1
# 2025-11-11 16:13:24: initial_forget_bias: 2.5
# 2025-11-11 16:13:24: epochs: 10000
# 2025-11-11 16:13:24: learning_rate: 0.001
# 2025-11-11 16:13:24: batch_size: 256
# 2025-11-11 16:13:24: optimizer: AdamW
# 2025-11-11 16:13:24: loss: custom_loss
# 2025-11-11 16:13:24: seq_length: 96
# 2025-11-11 16:13:24: predict_last_n: 24
# 2025-11-11 16:13:24: forecast_seq_length: 24
# 2025-11-11 16:13:24: forecast_overlap: None
# 2025-11-11 16:13:24: custom_loss: {'losses': ['smape', 'mse', 'nse'], 'weights': [0.8, 0.1, 0.1]}
# 2025-11-11 16:13:24: clip_gradient_norm: 5.0
# 2025-11-11 16:13:24: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-11-11 16:13:24: validate_every: 1
# 2025-11-11 16:13:24: validate_n_random_basins: 1
# 2025-11-11 16:13:24: early_stopping: True
# 2025-11-11 16:13:24: patience_early_stopping: 10
# 2025-11-11 16:13:24: minimum_epochs_before_early_stopping: 10
# 2025-11-11 16:13:24: min_delta_early_stopping: 1e-07
# 2025-11-11 16:13:24: dynamic_learning_rate: True
# 2025-11-11 16:13:24: patience_dynamic_learning_rate: 3
# 2025-11-11 16:13:24: factor_dynamic_learning_rate: 0.4
# 2025-11-11 16:13:24: log_interval: 10
# 2025-11-11 16:13:24: log_n_figures: 1
# 2025-11-11 16:13:24: log_tensorboard: True
# 2025-11-11 16:13:24: save_train_data: False
# 2025-11-11 16:13:24: save_validation_results: False
# 2025-11-11 16:13:24: save_all_output: False
# 2025-11-11 16:13:24: save_weights_every: 10
# 2025-11-11 16:13:24: verbose: 1
# 2025-11-11 16:13:24: save_best_enabled: True
# 2025-11-11 16:13:24: save_best_criterion: MAPE
# 2025-11-11 16:13:24: save_in_csv: True
# 2025-11-11 16:13:24: csv_metrics_name: Metrics_over_Experiments
# 2025-11-11 16:13:24: nan_handling_method: masked_mean
# 2025-11-11 16:13:24: nan_step_probability: 0.0
# 2025-11-11 16:13:24: nan_sequence_probability: 0.0
# 2025-11-11 16:13:24: nan_handling_pos_encoding_size: 0
# 2025-11-11 16:13:24: number_of_basins: 1
# 2025-11-11 16:13:24: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\Exploration\runs\test1_1111_161324
# 2025-11-11 16:13:24: ### Device cuda:0 will be used for training
# 2025-11-11 16:13:24: Loading basin data into xarray data set.
# 2025-11-11 16:13:25: Calculating target variable stds per basin
# 2025-11-11 16:13:25: Create lookup table and convert to pytorch tensor
# 2025-11-11 16:14:41: Epoch 1 average loss: avg_loss: 14.69603, avg_total_loss: 14.69603
# 2025-11-11 16:14:46: Epoch 1 average validation loss: 9.68830 -- Median validation metrics: avg_loss: 9.68830, MAPE: 20.27828, NSE: 0.95598, MSE: 20.10462, RMSE: 4.48382
# 2025-11-11 16:14:46: [saveBest] New best model found at epoch 1: 20.278284 (prev inf)
# 2025-11-11 16:15:05: Epoch 2 average loss: avg_loss: 10.92085, avg_total_loss: 10.92085
# 2025-11-11 16:15:08: Epoch 2 average validation loss: 8.38689 -- Median validation metrics: avg_loss: 8.38689, MAPE: 13.31809, NSE: 0.96954, MSE: 13.91129, RMSE: 3.72978
# 2025-11-11 16:15:08: [saveBest] New best model found at epoch 2: 13.318088 (prev 20.278284)
# 2025-11-11 16:15:27: Epoch 3 average loss: avg_loss: 10.07150, avg_total_loss: 10.07150
# 2025-11-11 16:15:30: Epoch 3 average validation loss: 8.34341 -- Median validation metrics: avg_loss: 8.34341, MAPE: 14.43908, NSE: 0.96584, MSE: 15.60312, RMSE: 3.95008
# 2025-11-11 16:15:49: Epoch 4 average loss: avg_loss: 9.63681, avg_total_loss: 9.63681
# 2025-11-11 16:15:52: Epoch 4 average validation loss: 7.86900 -- Median validation metrics: avg_loss: 7.86900, MAPE: 10.18114, NSE: 0.97454, MSE: 11.62693, RMSE: 3.40983
# 2025-11-11 16:22:42: Epoch 22 average loss: avg_loss: 7.76169, avg_total_loss: 7.76169
# 2025-11-11 16:22:46: Epoch 22 average validation loss: 6.90923 -- Median validation metrics: avg_loss: 6.90923, MAPE: 7.86423, NSE: 0.97806, MSE: 10.01978, RMSE: 3.16540
# 2025-11-11 16:22:46: [Scheduler] - Learning rate changed from 1.6e-04 to 6.4e-05
# 2025-11-11 16:23:08: Epoch 23 average loss: avg_loss: 7.68448, avg_total_loss: 7.68448
# 2025-11-11 16:23:11: Epoch 23 average validation loss: 6.85574 -- Median validation metrics: avg_loss: 6.85574, MAPE: 8.59722, NSE: 0.97968, MSE: 9.28141, RMSE: 3.04654
# 2025-11-11 16:23:30: Epoch 24 average loss: avg_loss: 7.67954, avg_total_loss: 7.67954
# 2025-11-11 16:23:33: Epoch 24 average validation loss: 6.77744 -- Median validation metrics: avg_loss: 6.77744, MAPE: 7.93667, NSE: 0.97975, MSE: 9.24873, RMSE: 3.04117
# 2025-11-11 16:23:54: Epoch 25 average loss: avg_loss: 7.66769, avg_total_loss: 7.66769
# 2025-11-11 16:23:57: Epoch 25 average validation loss: 6.83828 -- Median validation metrics: avg_loss: 6.83828, MAPE: 7.63206, NSE: 0.97928, MSE: 9.46166, RMSE: 3.07598
# 2025-11-11 16:23:57: [saveBest] New best model found at epoch 25: 7.632061 (prev 7.699536)
# 2025-11-11 16:24:16: Epoch 26 average loss: avg_loss: 7.66500, avg_total_loss: 7.66500
# 2025-11-11 16:24:19: Epoch 26 average validation loss: 6.98826 -- Median validation metrics: avg_loss: 6.98826, MAPE: 7.71620, NSE: 0.97923, MSE: 9.48589, RMSE: 3.07992
# 2025-11-11 16:24:38: Epoch 27 average loss: avg_loss: 7.65862, avg_total_loss: 7.65862
# 2025-11-11 16:24:41: Epoch 27 average validation loss: 6.89065 -- Median validation metrics: avg_loss: 6.89065, MAPE: 7.67976, NSE: 0.97919, MSE: 9.50640, RMSE: 3.08325
# 2025-11-11 16:24:41: Early stopping triggered at epoch 27 with validation loss 6.89065. Training stopped.
# ==================================
#   Training ended successfully !
# ==================================
#
# Starting the EVALUATION on the test period:
# 2025-11-11 16:24:44: Using the model weights from c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\02_Tests_DB_massaRS\Exploration\runs\test1_1111_161324\best_model.pt
# from best ma gueule
# ==================================
#   TEST ended successfully !
# ==================================

# %%
Metrics = dict_without_xr_key(results[basin]['1h'])
Metrics_ = Metrics.copy()

if cfg.save_in_csv and Evaluation_TEST:
    if Metrics_ is not None:
        summary_file =  Path(f"./{cfg.csv_metrics_name}.csv")
        Metrics_['experiment'] = run_dir.name

        summary_df = pd.DataFrame([Metrics_])
        
        # Append to summary file, creating it with a header if it doesn't exist
        summary_df.to_csv(f"{cfg.csv_metrics_name}.csv", mode='a', header=not summary_file.exists(), index=False)

# %% [markdown]
# ---

# %%
print("Metrics on the cuncatenated last predictions, on the Evaluation period:")
print(Metrics)
# Out:
# Metrics on the cuncatenated last predictions, on the Evaluation period:
# {'MAPE': 9.01746940612793, 'NSE': 0.9733861088752747, 'MSE': 16.423320770263672, 'RMSE': 4.052569650266812}

# %%
# Path to your output.log file
log_path = Path(f"{run_dir}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path, verbose=False)


plot_training_curves(train_df, val_df, save_fig = save_plots_training, run_dir=run_dir)
plot_validation_metrics(val_df, save_fig = save_plots_training, run_dir=run_dir)

# %% [markdown]
# ---

# %% [markdown]
# ### Extract results from Test period

# %%
results_ = results[basin]["1h"]["xr"]
scores = dict_without_xr_key(results[basin]['1h'])

# store only the values in numpy arrays from xarray DataArrays
y_true = results_['streamflow_obs']
y_pred = results_['streamflow_sim']

verb = False
if verb: 
    print("\n-- Calculating MAPE values for each horizon: --\n")
    mapes = mape_array(y_true, y_pred, verbose=verb)
    print("\n-- MAPE calculation per horizon completed. --\n")
else:
    mapes = mape_array(y_true, y_pred, verbose=verb)

# %%
plot_mape_horizon(
    mapes,
    color="#e76f51",
    title=f"MAPE vs Forecast Horizon for basin {basin}"
)

# %%
scores_str = str.join(', ', [f"{key} : {scores[key]:.2f}" for key in scores])
title24 = f"Massa – {cfg.predict_last_n}h | " + scores_str

# plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[1, 6, cfg.predict_last_n])
plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[cfg.predict_last_n])

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 00:00:00",
#     xr_ds=results_
# ).show()
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 01:00:00",
#     xr_ds=results_
# ).show()

# %%
# Example to plot the forecast issued at the given time stamp and the n_forecast next predictions
# plot_forecast_horizon_series(
#     issue_date="2024-06-10 00:00:00",
#     xr_ds=results_,
#     n_forecasts=10
# ).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores - TEST period

# %% [markdown]
# ### Prediction at $t+24h$

# %%
qobs=results_['streamflow_obs']
qsim=results_['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.973
# MSE: 16.423
# RMSE: 4.053
# KGE: 0.965
# Alpha-NSE: 0.973
# Beta-KGE: 0.983
# Beta-NSE: -0.013
# Pearson-r: 0.987
# FHV: -8.952
# FMS: 0.600
# FLV: 6.236
# Peak-Timing: nan
# Peak-MAPE: 16.239
# MAPE: 9.017

# %% [markdown]
# ### Prediction at $t+7h$

# %%
values = metrics.calculate_all_metrics(qobs.isel(time_step=6), qsim.isel(time_step=6))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.986
# MSE: 8.881
# RMSE: 2.980
# KGE: 0.973
# Alpha-NSE: 0.977
# Beta-KGE: 0.988
# Beta-NSE: -0.009
# Pearson-r: 0.993
# FHV: -7.718
# FMS: 0.226
# FLV: -4.802
# Peak-Timing: nan
# Peak-MAPE: 13.578
# MAPE: 6.371
