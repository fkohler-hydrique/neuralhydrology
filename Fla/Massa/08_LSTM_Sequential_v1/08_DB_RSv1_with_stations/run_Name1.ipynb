# %% [markdown]
# ## Imports

# %%
from   pathlib import Path
import matplotlib.pyplot as plt
import pickle
import torch
import pandas as pd
# import mlflow

from neuralhydrology.evaluation     import metrics
from neuralhydrology.nh_run         import start_run, eval_run
from neuralhydrology.datasetzoo     import register_dataset
from neuralhydrology.utils.config   import Config

from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)

# Custom functions plot_training_curves
from custom.functions.Plot import plot_training_curves, plot_validation_metrics
from custom.functions.Plot import plot_mape_horizon, plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series
from custom.functions.utils_fla import parse_neuralhydrology_log
from custom.functions.utils_fla import info_results, mape_array, dict_without_xr_key

# %% [markdown]
# ## Parameters of the run

# %%
# Initialisation of the config file, name of the experiment in the parameter experiment_name
config_file = Path("config_Name1.yml")
cfg = Config(config_file)

# Here write the name of the run if renamed run or if you want to plot the specified run, otherwise will take the run_dir created during training
# example: "expName_TimeStamp" 
runFile = None 

# list of basins, DB -> name of the basin.txt where the name of the csv is indicated
basin = "massa_RS_v1"

# Whether you want to run a training, put false to plot your specific run folder for example
TRAIN, Evaluation_TEST = True, True

save_plots_training = True

# %% [markdown]
# ## Run

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        run_dir = start_run(config_file=Path(config_file))
    else:
        print("Using CPU")
        run_dir = start_run(config_file=Path(config_file), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
if runFile is not None:
    run_dir = Path(f"./runs/{runFile}")

if Evaluation_TEST:
    print("\nStarting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test", from_best=cfg.save_best_enabled)
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")

model_str = f"model_from_best"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-11-18 17:07:20: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\08_DB_RSv1_with_stations\runs\Name1_1811_170720\output.log initialized.
# 2025-11-18 17:07:20: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\08_DB_RSv1_with_stations\runs\Name1_1811_170720
# 2025-11-18 17:07:20: ### Run configurations for Name1
# 2025-11-18 17:07:20: experiment_name: Name1
# 2025-11-18 17:07:20: base_run_dir: runs
# 2025-11-18 17:07:20: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\08_DB_RSv1_with_stations\runs\Name1_1811_170720\img_log
# 2025-11-18 17:07:20: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\08_DB_RSv1_with_stations\runs\Name1_1811_170720\train_data
# 2025-11-18 17:07:20: seed: 42
# 2025-11-18 17:07:20: device: cuda:0
# 2025-11-18 17:07:20: num_workers: 16
# 2025-11-18 17:07:20: data_dir: ..\..\data
# 2025-11-18 17:07:20: dataset: swisshourly
# 2025-11-18 17:07:20: train_basin_file: ..\..\data\RS_v1.txt
# 2025-11-18 17:07:20: validation_basin_file: ..\..\data\RS_v1.txt
# 2025-11-18 17:07:20: test_basin_file: ..\..\data\RS_v1.txt
# 2025-11-18 17:07:20: train_start_date: 2020-05-03 00:00:00
# 2025-11-18 17:07:20: train_end_date: 2023-03-30 00:00:00
# 2025-11-18 17:07:20: validation_start_date: 2023-04-01 00:00:00
# 2025-11-18 17:07:20: validation_end_date: 2024-02-04 00:00:00
# 2025-11-18 17:07:20: test_start_date: 2023-04-01 00:00:00
# 2025-11-18 17:07:20: test_end_date: 2024-02-04 00:00:00
# 2025-11-18 17:07:20: dynamic_inputs: ['streamflow_hindcast', 'null_values', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'HourOfDaySinus', 'DayOfYearSinus', 'fc_Massa|22_Q simule', 'fc_Massa|69_i', 'fc_Massa|69_T', 'fc_Massa|70_h', 'fc_Massa|71_h', 'temp_m1', 'fc_temp_m1', 'is_m1_snow', 'fc_is_m1_snow', 'temp_m1_12h', 'fc_temp_m1_12h']
# 2025-11-18 17:07:20: hindcast_inputs: ['streamflow_hindcast', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'HourOfDaySinus', 'DayOfYearSinus', 'temp_m1', 'is_m1_snow', 'temp_m1_12h']
# 2025-11-18 17:07:20: forecast_inputs: ['null_values', 'fc_Massa|22_Q simule', 'fc_Massa|69_i', 'fc_Massa|69_T', 'fc_Massa|70_h', 'fc_Massa|71_h', 'HourOfDaySinus', 'DayOfYearSinus', 'fc_temp_m1', 'fc_is_m1_snow', 'fc_temp_m1_12h']
# 2025-11-18 17:07:20: timestep_counter: True
# 2025-11-18 17:07:20: target_variables: ['streamflow']
# 2025-11-18 17:07:20: clip_targets_to_zero: ['streamflow']
# 2025-11-18 17:07:20: high_flow_only: True
# 2025-11-18 17:07:20: high_flow_target: streamflow
# 2025-11-18 17:07:20: high_flow_threshold: 10.0
# 2025-11-18 17:07:20: model: sequential_forecast_lstm
# 2025-11-18 17:07:20: head: regression
# 2025-11-18 17:07:20: hidden_size: 128
# 2025-11-18 17:07:20: output_activation: linear
# 2025-11-18 17:07:20: output_dropout: 0.4
# 2025-11-18 17:07:20: lstm_dropout: 0.0
# 2025-11-18 17:07:20: num_layers: 1
# 2025-11-18 17:07:20: initial_forget_bias: 1
# 2025-11-18 17:07:20: epochs: 10000
# 2025-11-18 17:07:20: learning_rate: 0.001
# 2025-11-18 17:07:20: batch_size: 32
# 2025-11-18 17:07:20: optimizer: AdamW
# 2025-11-18 17:07:20: loss: custom_loss
# 2025-11-18 17:07:20: seq_length: 96
# 2025-11-18 17:07:20: predict_last_n: 24
# 2025-11-18 17:07:20: forecast_seq_length: 24
# 2025-11-18 17:07:20: forecast_overlap: None
# 2025-11-18 17:07:20: custom_loss: {'losses': ['smape', 'nse', 'mse'], 'weights': [0.6, 0.2, 0.2]}
# 2025-11-18 17:07:20: clip_gradient_norm: 2.0
# 2025-11-18 17:07:20: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-11-18 17:07:20: validate_every: 1
# 2025-11-18 17:07:20: validate_n_random_basins: 1
# 2025-11-18 17:07:20: early_stopping: True
# 2025-11-18 17:07:20: patience_early_stopping: 10
# 2025-11-18 17:07:20: minimum_epochs_before_early_stopping: 15
# 2025-11-18 17:07:20: min_delta_early_stopping: 1e-07
# 2025-11-18 17:07:20: dynamic_learning_rate: True
# 2025-11-18 17:07:20: patience_dynamic_learning_rate: 5
# 2025-11-18 17:07:20: factor_dynamic_learning_rate: 0.4
# 2025-11-18 17:07:20: log_interval: 10
# 2025-11-18 17:07:20: log_n_figures: 1
# 2025-11-18 17:07:20: log_tensorboard: True
# 2025-11-18 17:07:20: save_train_data: False
# 2025-11-18 17:07:20: save_validation_results: False
# 2025-11-18 17:07:20: save_all_output: False
# 2025-11-18 17:07:20: save_weights_every: 10
# 2025-11-18 17:07:20: verbose: 1
# 2025-11-18 17:07:20: save_best_enabled: True
# 2025-11-18 17:07:20: save_best_criterion: sum_metrics
# 2025-11-18 17:07:20: save_in_csv: True
# 2025-11-18 17:07:20: csv_metrics_name: Metrics_over_Experiments
# 2025-11-18 17:07:20: nan_handling_method: masked_mean
# 2025-11-18 17:07:20: nan_step_probability: 0.0
# 2025-11-18 17:07:20: nan_sequence_probability: 0.0
# 2025-11-18 17:07:20: nan_handling_pos_encoding_size: 0
# 2025-11-18 17:07:20: number_of_basins: 1
# 2025-11-18 17:07:20: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\08_DB_RSv1_with_stations\runs\Name1_1811_170720
# 2025-11-18 17:07:20: ### Device cuda:0 will be used for training
# 2025-11-18 17:07:20: Loading basin data into xarray dataset.
# 2025-11-18 17:07:21: Calculating target variable stds per basin
# 2025-11-18 17:07:21: Create lookup table and convert to pytorch tensor
# 2025-11-18 17:08:00: Epoch 1 average loss: avg_loss: 24.30521, avg_total_loss: 24.30521
# 2025-11-18 17:08:01: Epoch 1 average validation loss: 18.27359 -- Median validation metrics: avg_loss: 18.27359, MAPE: 14.07846, NSE: 0.82931, MSE: 82.47079, RMSE: 9.08134
# 2025-11-18 17:08:01: [saveBest] New best model found at epoch 1: 96.719935 (prev inf)
# 2025-11-18 17:08:05: Epoch 2 average loss: avg_loss: 16.69659, avg_total_loss: 16.69659
# 2025-11-18 17:08:07: Epoch 2 average validation loss: 17.52665 -- Median validation metrics: avg_loss: 17.52665, MAPE: 11.82636, NSE: 0.89601, MSE: 50.24510, RMSE: 7.08838
# 2025-11-18 17:08:07: [saveBest] New best model found at epoch 2: 62.175455 (prev 96.719935)
# 2025-11-18 17:08:11: Epoch 3 average loss: avg_loss: 15.03242, avg_total_loss: 15.03242
# 2025-11-18 17:09:40: [Scheduler] Learning rate changed from 4.0e-04 to 1.6e-04
# 2025-11-18 17:09:43: Epoch 21 average loss: avg_loss: 7.35549, avg_total_loss: 7.35549
# 2025-11-18 17:09:44: Epoch 21 average validation loss: 15.90212 -- Median validation metrics: avg_loss: 15.90212, MAPE: 11.67716, NSE: 0.91296, MSE: 42.05548, RMSE: 6.48502
# 2025-11-18 17:09:49: Epoch 22 average loss: avg_loss: 7.28501, avg_total_loss: 7.28501
# 2025-11-18 17:09:50: Epoch 22 average validation loss: 16.02037 -- Median validation metrics: avg_loss: 16.02037, MAPE: 11.53756, NSE: 0.91355, MSE: 41.76654, RMSE: 6.46270
# 2025-11-18 17:09:54: Epoch 23 average loss: avg_loss: 7.25886, avg_total_loss: 7.25886
# 2025-11-18 17:09:55: Epoch 23 average validation loss: 15.85772 -- Median validation metrics: avg_loss: 15.85772, MAPE: 11.67753, NSE: 0.91090, MSE: 43.04799, RMSE: 6.56110
# 2025-11-18 17:09:59: Epoch 24 average loss: avg_loss: 7.20641, avg_total_loss: 7.20641
# 2025-11-18 17:10:00: Epoch 24 average validation loss: 15.96429 -- Median validation metrics: avg_loss: 15.96429, MAPE: 11.58362, NSE: 0.91307, MSE: 42.00015, RMSE: 6.48075
# 2025-11-18 17:10:04: Epoch 25 average loss: avg_loss: 7.14246, avg_total_loss: 7.14246
# 2025-11-18 17:10:05: Epoch 25 average validation loss: 15.85336 -- Median validation metrics: avg_loss: 15.85336, MAPE: 11.61604, NSE: 0.91065, MSE: 43.17080, RMSE: 6.57045
# 2025-11-18 17:10:09: Epoch 26 average loss: avg_loss: 7.14577, avg_total_loss: 7.14577
# 2025-11-18 17:10:10: Epoch 26 average validation loss: 15.80601 -- Median validation metrics: avg_loss: 15.80601, MAPE: 11.55520, NSE: 0.91201, MSE: 42.51487, RMSE: 6.52034
# 2025-11-18 17:10:10: Early stopping triggered at epoch 26 with validation loss 15.80601. Training stopped.
# ==================================
#   Training ended successfully !
# ==================================
#
# Starting the EVALUATION on the test period:
# 2025-11-18 17:10:12: Using the model weights from c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\08_DB_RSv1_with_stations\runs\Name1_1811_170720\best_model.pt
# ==================================
#   TEST ended successfully !
# ==================================

# %%
# basin="massa_RS_v1"
Metrics = dict_without_xr_key(results[basin]['1h'])
Metrics_ = Metrics.copy()

if cfg.save_in_csv and Evaluation_TEST:
    if Metrics_ is not None:
        summary_file =  Path(f"./{cfg.csv_metrics_name}.csv")
        Metrics_['experiment'] = run_dir.name

        summary_df = pd.DataFrame([Metrics_])
        
        # Append to summary file, creating it with a header if it doesn't exist
        summary_df.to_csv(f"{cfg.csv_metrics_name}.csv", mode='a', header=not summary_file.exists(), index=False)

# %% [markdown]
# ---

# %%
print("Metrics on the cuncatenated last predictions, on the Evaluation period:")
print(Metrics)
# Out:
# Metrics on the cuncatenated last predictions, on the Evaluation period:
# {'MAPE': 10.949349403381348, 'NSE': 0.9237952828407288, 'MSE': 36.818668365478516, 'RMSE': 6.06783885460701}

# %%
# Path to your output.log file
log_path = Path(f"{run_dir}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path, verbose=False)


plot_training_curves(train_df, val_df, save_fig = save_plots_training, run_dir=run_dir)
plot_validation_metrics(val_df, save_fig = save_plots_training, run_dir=run_dir)

# %% [markdown]
# ---

# %% [markdown]
# ### Extract results from Test period

# %%
results_ = results[basin]["1h"]["xr"]
scores = dict_without_xr_key(results[basin]['1h'])

# store only the values in numpy arrays from xarray DataArrays
y_true = results_['streamflow_obs']
y_pred = results_['streamflow_sim']

verb = False
if verb: 
    print("\n-- Calculating MAPE values for each horizon: --\n")
    mapes = mape_array(y_true, y_pred, verbose=verb)
    print("\n-- MAPE calculation per horizon completed. --\n")
else:
    mapes = mape_array(y_true, y_pred, verbose=verb)

# %%
plot_mape_horizon(
    mapes,
    color="#e76f51",
    title=f"MAPE vs Forecast Horizon for basin {basin}"
)

# %%
scores_str = str.join(', ', [f"{key} : {scores[key]:.2f}" for key in scores])
title24 = f"Massa – {cfg.predict_last_n}h | " + scores_str

# plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[1, 6, cfg.predict_last_n])
plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[cfg.predict_last_n])

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 00:00:00",
#     xr_ds=results_
# ).show()
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 01:00:00",
#     xr_ds=results_
# ).show()

# %%
# Example to plot the forecast issued at the given time stamp and the n_forecast next predictions
# plot_forecast_horizon_series(
#     issue_date="2024-06-10 00:00:00",
#     xr_ds=results_,
#     n_forecasts=10
# ).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores - TEST period

# %% [markdown]
# ### Prediction at $t+24h$

# %%
qobs=results_['streamflow_obs']
qsim=results_['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.924
# MSE: 36.819
# RMSE: 6.068
# KGE: 0.914
# Alpha-NSE: 0.925
# Beta-KGE: 0.983
# Beta-NSE: -0.031
# Pearson-r: 0.962
# FHV: -10.222
# FMS: -9.429
# FLV: 4.240
# Peak-Timing: nan
# Peak-MAPE: 19.008
# MAPE: 10.949

# %% [markdown]
# ### Prediction at $t+7h$

# %%
values = metrics.calculate_all_metrics(qobs.isel(time_step=6), qsim.isel(time_step=6))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.950
# MSE: 24.103
# RMSE: 4.909
# KGE: 0.951
# Alpha-NSE: 0.959
# Beta-KGE: 0.991
# Beta-NSE: -0.017
# Pearson-r: 0.975
# FHV: -5.768
# FMS: -8.500
# FLV: -24.605
# Peak-Timing: nan
# Peak-MAPE: 15.782
# MAPE: 8.321
