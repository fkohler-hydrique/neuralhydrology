# %% [markdown]
# ## Imports

# %%
from   pathlib import Path
import matplotlib.pyplot as plt
import pickle
import torch
import pandas as pd
# import mlflow

from neuralhydrology.evaluation     import metrics
from neuralhydrology.nh_run         import start_run, eval_run
from neuralhydrology.datasetzoo     import register_dataset
from neuralhydrology.utils.config   import Config

from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)

# Custom functions plot_training_curves
from custom.functions.Plot import plot_training_curves, plot_validation_metrics
from custom.functions.Plot import plot_mape_horizon, plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series
from custom.functions.utils_fla import parse_neuralhydrology_log
from custom.functions.utils_fla import info_results, mape_array, dict_without_xr_key

# %% [markdown]
# ## Parameters of the run

# %%
# Initialisation of the config file, name of the experiment in the parameter experiment_name
config_file = Path("config_p1.yml")
cfg = Config(config_file)

# Here write the name of the run if renamed run or if you want to plot the specified run, otherwise will take the run_dir created during training
# example: "expName_TimeStamp" 
runFile = None 

# list of basins, DB -> name of the basin.txt where the name of the csv is indicated
basin = "massa_with_RS"

# Whether you want to run a training, put false to plot your specific run folder for example
TRAIN, Evaluation_TEST = True, True

save_plots_training = True

# %% [markdown]
# ## Run

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        run_dir = start_run(config_file=Path(config_file))
    else:
        print("Using CPU")
        run_dir = start_run(config_file=Path(config_file), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
if runFile is not None:
    run_dir = Path(f"./runs/{runFile}")

if Evaluation_TEST:
    print("\nStarting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test", from_best=cfg.save_best_enabled)
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")

model_str = f"model_from_best"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-11-14 11:41:30: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\05_DB_massaTS_HighFlows_only\runs\peak1_1411_114130\output.log initialized.
# 2025-11-14 11:41:30: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\05_DB_massaTS_HighFlows_only\runs\peak1_1411_114130
# 2025-11-14 11:41:30: ### Run configurations for peak1
# 2025-11-14 11:41:30: experiment_name: peak1
# 2025-11-14 11:41:30: base_run_dir: runs
# 2025-11-14 11:41:30: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\05_DB_massaTS_HighFlows_only\runs\peak1_1411_114130\img_log
# 2025-11-14 11:41:30: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\05_DB_massaTS_HighFlows_only\runs\peak1_1411_114130\train_data
# 2025-11-14 11:41:30: seed: 42
# 2025-11-14 11:41:30: device: cuda:0
# 2025-11-14 11:41:30: num_workers: 16
# 2025-11-14 11:41:30: data_dir: ..\..\data
# 2025-11-14 11:41:30: dataset: swisshourly
# 2025-11-14 11:41:30: train_basin_file: ..\..\data\Data_RS.txt
# 2025-11-14 11:41:30: validation_basin_file: ..\..\data\Data_RS.txt
# 2025-11-14 11:41:30: test_basin_file: ..\..\data\Data_RS.txt
# 2025-11-14 11:41:30: train_start_date: 1983-03-04 00:00:00
# 2025-11-14 11:41:30: train_end_date: 2021-04-30 00:00:00
# 2025-11-14 11:41:30: validation_start_date: 2021-03-01 00:00:00
# 2025-11-14 11:41:30: validation_end_date: 2023-02-02 00:00:00
# 2025-11-14 11:41:30: test_start_date: 2023-02-03 00:00:00
# 2025-11-14 11:41:30: test_end_date: 2024-02-04 00:00:00
# 2025-11-14 11:41:30: dynamic_inputs: ['streamflow_hindcast', 'null_values', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus']
# 2025-11-14 11:41:30: hindcast_inputs: ['streamflow_hindcast', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus']
# 2025-11-14 11:41:30: forecast_inputs: ['null_values', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus']
# 2025-11-14 11:41:30: timestep_counter: True
# 2025-11-14 11:41:30: target_variables: ['streamflow']
# 2025-11-14 11:41:30: clip_targets_to_zero: ['streamflow']
# 2025-11-14 11:41:30: high_flow_only: True
# 2025-11-14 11:41:30: high_flow_target: streamflow
# 2025-11-14 11:41:30: high_flow_threshold: 40.0
# 2025-11-14 11:41:30: model: sequential_forecast_lstm
# 2025-11-14 11:41:30: head: regression
# 2025-11-14 11:41:30: hidden_size: 64
# 2025-11-14 11:41:30: output_activation: linear
# 2025-11-14 11:41:30: output_dropout: 0.1
# 2025-11-14 11:41:30: lstm_dropout: 0.0
# 2025-11-14 11:41:30: num_layers: 1
# 2025-11-14 11:41:30: initial_forget_bias: 1.5
# 2025-11-14 11:41:30: epochs: 10000
# 2025-11-14 11:41:30: learning_rate: 0.001
# 2025-11-14 11:41:30: batch_size: 64
# 2025-11-14 11:41:30: optimizer: AdamW
# 2025-11-14 11:41:30: loss: custom_loss
# 2025-11-14 11:41:30: seq_length: 72
# 2025-11-14 11:41:30: predict_last_n: 24
# 2025-11-14 11:41:30: forecast_seq_length: 24
# 2025-11-14 11:41:30: forecast_overlap: None
# 2025-11-14 11:41:30: custom_loss: {'losses': ['smape', 'nse', 'mse'], 'weights': [0.5, 0.2, 0.3]}
# 2025-11-14 11:41:30: clip_gradient_norm: 5.0
# 2025-11-14 11:41:30: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-11-14 11:41:30: validate_every: 1
# 2025-11-14 11:41:30: validate_n_random_basins: 1
# 2025-11-14 11:41:30: early_stopping: True
# 2025-11-14 11:41:30: patience_early_stopping: 10
# 2025-11-14 11:41:30: minimum_epochs_before_early_stopping: 15
# 2025-11-14 11:41:30: min_delta_early_stopping: 1e-07
# 2025-11-14 11:41:30: dynamic_learning_rate: True
# 2025-11-14 11:41:30: patience_dynamic_learning_rate: 5
# 2025-11-14 11:41:30: factor_dynamic_learning_rate: 0.4
# 2025-11-14 11:41:30: log_interval: 10
# 2025-11-14 11:41:30: log_n_figures: 1
# 2025-11-14 11:41:30: log_tensorboard: True
# 2025-11-14 11:41:30: save_train_data: False
# 2025-11-14 11:41:30: save_validation_results: False
# 2025-11-14 11:41:30: save_all_output: False
# 2025-11-14 11:41:30: save_weights_every: 10
# 2025-11-14 11:41:30: verbose: 1
# 2025-11-14 11:41:30: save_best_enabled: True
# 2025-11-14 11:41:30: save_best_criterion: sum_metrics
# 2025-11-14 11:41:30: save_in_csv: True
# 2025-11-14 11:41:30: csv_metrics_name: Metrics_over_Experiments
# 2025-11-14 11:41:30: nan_handling_method: masked_mean
# 2025-11-14 11:41:30: nan_step_probability: 0.0
# 2025-11-14 11:41:30: nan_sequence_probability: 0.0
# 2025-11-14 11:41:30: nan_handling_pos_encoding_size: 0
# 2025-11-14 11:41:30: number_of_basins: 1
# 2025-11-14 11:41:30: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\05_DB_massaTS_HighFlows_only\runs\peak1_1411_114130
# 2025-11-14 11:41:30: ### Device cuda:0 will be used for training
# 2025-11-14 11:41:30: Loading basin data into xarray dataset.
# 2025-11-14 11:41:31: Calculating target variable stds per basin
# 2025-11-14 11:41:31: Create lookup table and convert to pytorch tensor
# 2025-11-14 11:42:17: Epoch 1 average loss: avg_loss: 7.68353, avg_total_loss: 7.68353
# 2025-11-14 11:42:19: Epoch 1 average validation loss: 6.10833 -- Median validation metrics: avg_loss: 6.10833, MAPE: 10.24094, NSE: 0.72599, MSE: 65.30431, RMSE: 8.08111
# 2025-11-14 11:42:19: [saveBest] New best model found at epoch 1: 75.819258 (prev inf)
# 2025-11-14 11:42:27: Epoch 2 average loss: avg_loss: 5.62171, avg_total_loss: 5.62171
# 2025-11-14 11:42:30: Epoch 2 average validation loss: 5.28088 -- Median validation metrics: avg_loss: 5.28088, MAPE: 8.99025, NSE: 0.76248, MSE: 56.60770, RMSE: 7.52381
# 2025-11-14 11:42:30: [saveBest] New best model found at epoch 2: 65.835473 (prev 75.819258)
# 2025-11-14 11:42:42: Epoch 3 average loss: avg_loss: 5.16534, avg_total_loss: 5.16534
# 2025-11-14 11:42:43: Epoch 3 average validation loss: 5.14804 -- Median validation metrics: avg_loss: 5.14804, MAPE: 9.24761, NSE: 0.79262, MSE: 49.42393, RMSE: 7.03022
# 2025-11-14 11:42:43: [saveBest] New best model found at epoch 3: 58.878918 (prev 65.835473)
# 2025-11-14 11:42:54: Epoch 4 average loss: avg_loss: 4.87779, avg_total_loss: 4.87779
# 2025-11-14 11:49:45: Epoch 22 average validation loss: 4.63555 -- Median validation metrics: avg_loss: 4.63555, MAPE: 8.19562, NSE: 0.80220, MSE: 47.14132, RMSE: 6.86595
# 2025-11-14 11:50:09: Epoch 23 average loss: avg_loss: 2.96984, avg_total_loss: 2.96984
# 2025-11-14 11:50:12: Epoch 23 average validation loss: 4.59344 -- Median validation metrics: avg_loss: 4.59344, MAPE: 8.26819, NSE: 0.80276, MSE: 47.00900, RMSE: 6.85631
# 2025-11-14 11:50:35: Epoch 24 average loss: avg_loss: 2.93464, avg_total_loss: 2.93464
# 2025-11-14 11:50:38: Epoch 24 average validation loss: 4.95680 -- Median validation metrics: avg_loss: 4.95680, MAPE: 9.72264, NSE: 0.77572, MSE: 53.45325, RMSE: 7.31117
# 2025-11-14 11:51:02: Epoch 25 average loss: avg_loss: 2.91399, avg_total_loss: 2.91399
# 2025-11-14 11:51:05: Epoch 25 average validation loss: 4.70882 -- Median validation metrics: avg_loss: 4.70882, MAPE: 8.76518, NSE: 0.79846, MSE: 48.03283, RMSE: 6.93057
# 2025-11-14 11:51:05: [Scheduler] Learning rate changed from 4.0e-04 to 1.6e-04
# 2025-11-14 11:51:28: Epoch 26 average loss: avg_loss: 2.82524, avg_total_loss: 2.82524
# 2025-11-14 11:51:31: Epoch 26 average validation loss: 4.67772 -- Median validation metrics: avg_loss: 4.67772, MAPE: 8.22262, NSE: 0.79748, MSE: 48.26737, RMSE: 6.94747
# 2025-11-14 11:51:55: Epoch 27 average loss: avg_loss: 2.80817, avg_total_loss: 2.80817
# 2025-11-14 11:51:58: Epoch 27 average validation loss: 4.74453 -- Median validation metrics: avg_loss: 4.74453, MAPE: 8.49533, NSE: 0.79382, MSE: 49.13881, RMSE: 7.00991
# 2025-11-14 11:51:58: Early stopping triggered at epoch 27 with validation loss 4.74453. Training stopped.
# ==================================
#   Training ended successfully !
# ==================================
#
# Starting the EVALUATION on the test period:
# 2025-11-14 11:52:00: Using the model weights from c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\Fla\Massa\08_LSTM_Sequential_v1\05_DB_massaTS_HighFlows_only\runs\peak1_1411_114130\best_model.pt
# ==================================
#   TEST ended successfully !
# ==================================

# %%
Metrics = dict_without_xr_key(results[basin]['1h'])
Metrics_ = Metrics.copy()

if cfg.save_in_csv and Evaluation_TEST:
    if Metrics_ is not None:
        summary_file =  Path(f"./{cfg.csv_metrics_name}.csv")
        Metrics_['experiment'] = run_dir.name

        summary_df = pd.DataFrame([Metrics_])
        
        # Append to summary file, creating it with a header if it doesn't exist
        summary_df.to_csv(f"{cfg.csv_metrics_name}.csv", mode='a', header=not summary_file.exists(), index=False)

# %% [markdown]
# ---

# %%
print("Metrics on the cuncatenated last predictions, on the Evaluation period:")
print(Metrics)
# Out:
# Metrics on the cuncatenated last predictions, on the Evaluation period:
# {'MAPE': 9.743358612060547, 'NSE': 0.7448532581329346, 'MSE': 65.92476654052734, 'RMSE': 8.119406785013751}

# %%
# Path to your output.log file
log_path = Path(f"{run_dir}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path, verbose=False)


plot_training_curves(train_df, val_df, save_fig = save_plots_training, run_dir=run_dir)
plot_validation_metrics(val_df, save_fig = save_plots_training, run_dir=run_dir)

# %% [markdown]
# ---

# %% [markdown]
# ### Extract results from Test period

# %%
results_ = results[basin]["1h"]["xr"]
scores = dict_without_xr_key(results[basin]['1h'])

# store only the values in numpy arrays from xarray DataArrays
y_true = results_['streamflow_obs']
y_pred = results_['streamflow_sim']

verb = False
if verb: 
    print("\n-- Calculating MAPE values for each horizon: --\n")
    mapes = mape_array(y_true, y_pred, verbose=verb)
    print("\n-- MAPE calculation per horizon completed. --\n")
else:
    mapes = mape_array(y_true, y_pred, verbose=verb)

# %%
plot_mape_horizon(
    mapes,
    color="#e76f51",
    title=f"MAPE vs Forecast Horizon for basin {basin}"
)

# %%
y_true[:,0]
# Out:
# <xarray.DataArray 'streamflow_obs' (date: 2432)> Size: 10kB
# array([35.485996, 35.4665  , 35.346   , ..., 47.407997, 47.408   ,
#        47.596   ], shape=(2432,), dtype=float32)
# Coordinates:
#   * date       (date) datetime64[ns] 19kB 2023-06-10T16:00:00 ... 2023-09-19T...
#     time_step  int64 8B -23

# %%
scores_str = str.join(', ', [f"{key} : {scores[key]:.2f}" for key in scores])
title24 = f"Massa – {cfg.predict_last_n}h | " + scores_str

plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[1, 6, cfg.predict_last_n])
plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[cfg.predict_last_n])

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 00:00:00",
#     xr_ds=results_
# ).show()
# plot_forecast_horizon_24h(
#     issue_date="2024-08-10 01:00:00",
#     xr_ds=results_
# ).show()

# %%
# Example to plot the forecast issued at the given time stamp and the n_forecast next predictions
# plot_forecast_horizon_series(
#     issue_date="2024-06-10 00:00:00",
#     xr_ds=results_,
#     n_forecasts=10
# ).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores - TEST period

# %% [markdown]
# ### Prediction at $t+24h$

# %%
qobs=results_['streamflow_obs']
qsim=results_['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.745
# MSE: 65.925
# RMSE: 8.119
# KGE: 0.812
# Alpha-NSE: 0.869
# Beta-KGE: 0.984
# Beta-NSE: -0.059
# Pearson-r: 0.865
# FHV: -9.819
# FMS: -12.268
# FLV: -132.185
# Peak-Timing: nan
# Peak-MAPE: 15.667
# MAPE: 9.743

# %% [markdown]
# ### Prediction at $t+7h$

# %%
values = metrics.calculate_all_metrics(qobs.isel(time_step=6), qsim.isel(time_step=6))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.921
# MSE: 24.509
# RMSE: 4.951
# KGE: 0.945
# Alpha-NSE: 0.962
# Beta-KGE: 1.002
# Beta-NSE: 0.007
# Pearson-r: 0.960
# FHV: -2.570
# FMS: -5.256
# FLV: 0.610
# Peak-Timing: nan
# Peak-MAPE: 10.428
# MAPE: 6.227
