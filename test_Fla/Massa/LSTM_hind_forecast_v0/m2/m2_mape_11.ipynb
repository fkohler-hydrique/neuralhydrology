# %% [markdown]
# #  Run of Model **$X$** on the App **MASSA**
#
# **Paramaters**
# The parameters of all models should be available in the parent folder, in an EXCEL file.

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
import torch

from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run
from neuralhydrology.datasetzoo import register_dataset

# %% [markdown]
# ### Adding our Dataset | Metrics | Models

# %%
from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)
from neuralhydrology.utils.config import Config

# Custom functions plot_training_curves
from custom.functions.Plot import plot_hydrograph, plot_training_curves, plot_validation_metrics
from custom.functions.utils_fla import parse_neuralhydrology_log

# %% [markdown]
# ---

# %% [markdown]
# ### Run parameters

# %%
configPath = Path("m2_mape_11.yml")

runFile = "m2_mape_11"

cfg = Config(configPath)
TRAIN = True
Evaluation_TEST =  False

# %% [markdown]
# ---
# ## **Training**

# %%
import pandas as pd
csv_path = r"..\..\data\massa_2.csv"
data = pd.read_csv(csv_path)
# print("Columns of the csv:  ", data.columns)
# print(data.dtypes)
# data['date'] = pd.to_datetime(data['date'])


# print some information about the dataset

# print(data.head())
# print(data.describe())

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    # by default we assume that you have at least one cuda-capable nvidia gpu or macos with metal support
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        start_run(config_file=Path(configPath))
    # fall back to cpu-only mode
    else:
        print("Using CPU")
        start_run(config_file=Path(configPath), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-10-24 17:04:49,762: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m2_mape_11_2410_170449\output.log initialized.
# 2025-10-24 17:04:49,762: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m2_mape_11_2410_170449
# 2025-10-24 17:04:49,763: ### Run configurations for m2_mape_11
# 2025-10-24 17:04:49,763: experiment_name: m2_mape_11
# 2025-10-24 17:04:49,764: base_run_dir: runs
# 2025-10-24 17:04:49,764: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m2_mape_11_2410_170449\train_data
# 2025-10-24 17:04:49,765: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m2_mape_11_2410_170449\img_log
# 2025-10-24 17:04:49,766: seed: 42
# 2025-10-24 17:04:49,766: device: cuda:0
# 2025-10-24 17:04:49,766: num_workers: 16
# 2025-10-24 17:04:49,767: data_dir: ..\..\data
# 2025-10-24 17:04:49,767: dataset: swisshourly
# 2025-10-24 17:04:49,767: train_basin_file: ..\..\data\basins_2.txt
# 2025-10-24 17:04:49,768: validation_basin_file: ..\..\data\basins_2.txt
# 2025-10-24 17:04:49,768: test_basin_file: ..\..\data\basins_2.txt
# 2025-10-24 17:04:49,768: train_start_date: 2020-03-01 00:00:00
# 2025-10-24 17:04:49,769: train_end_date: 2023-02-28 00:00:00
# 2025-10-24 17:04:49,769: validation_start_date: 2023-03-01 00:00:00
# 2025-10-24 17:04:49,769: validation_end_date: 2024-03-31 00:00:00
# 2025-10-24 17:04:49,770: test_start_date: 2024-04-01 00:00:00
# 2025-10-24 17:04:49,771: test_end_date: 2025-07-02 00:00:00
# 2025-10-24 17:04:49,771: dynamic_inputs: ['streamflow_hindcast', 'streamflow_lag_1year', 'null_values', 'prec_bruchji', 'temp_binn', 'temp_eggishorn', 'temp_jungfraujoch', 'fc_temp_jungfraujoch', 'temp_visp', 'fc_temp_visp', 'prec_fieschertal', 'fc_prec_fieschertal', 'fc_prec_bruchji', 'fc_temp_binn', 'fc_temp_eggishorn', 'ray_eggishorn', 'temp_mean_degree_day', 'fc_temp_mean_degree_day', 'is_Tmean_snow', 'fc_is_Tmean_snow']
# 2025-10-24 17:04:49,772: hindcast_inputs: ['streamflow_hindcast', 'streamflow_lag_1year', 'prec_bruchji', 'prec_fieschertal', 'temp_binn', 'temp_eggishorn', 'temp_visp', 'temp_jungfraujoch', 'ray_eggishorn', 'temp_mean_degree_day', 'is_Tmean_snow']
# 2025-10-24 17:04:49,772: forecast_inputs: ['null_values', 'streamflow_lag_1year', 'fc_prec_bruchji', 'fc_prec_fieschertal', 'fc_temp_binn', 'fc_temp_eggishorn', 'fc_temp_jungfraujoch', 'fc_temp_visp', 'ray_eggishorn', 'fc_temp_mean_degree_day', 'fc_is_Tmean_snow']
# 2025-10-24 17:04:49,772: forecast_seq_length: 24
# 2025-10-24 17:04:49,773: forecast_overlap: None
# 2025-10-24 17:04:49,773: timestep_counter: True
# 2025-10-24 17:04:49,773: target_variables: ['streamflow']
# 2025-10-24 17:04:49,774: clip_targets_to_zero: ['streamflow']
# 2025-10-24 17:04:49,774: model: sequential_forecast_lstm
# 2025-10-24 17:04:49,775: head: regression
# 2025-10-24 17:04:49,775: hidden_size: 256
# 2025-10-24 17:04:49,775: num_layers: 1
# 2025-10-24 17:04:49,776: seq_length: 150
# 2025-10-24 17:04:49,776: predict_last_n: 24
# 2025-10-24 17:04:49,777: output_activation: linear
# 2025-10-24 17:04:49,777: output_dropout: 0.05
# 2025-10-24 17:04:49,778: initial_forget_bias: 4
# 2025-10-24 17:04:49,778: epochs: 1000
# 2025-10-24 17:04:49,778: learning_rate: 0.001
# 2025-10-24 17:04:49,779: batch_size: 64
# 2025-10-24 17:04:49,779: optimizer: AdamW
# 2025-10-24 17:04:49,780: custom_loss: {'losses': ['smape', 'nse'], 'weights': [0.85, 0.15]}
# 2025-10-24 17:04:49,780: loss: custom_loss
# 2025-10-24 17:04:49,780: clip_gradient_norm: 3.0
# 2025-10-24 17:04:49,781: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-10-24 17:04:49,781: validate_every: 1
# 2025-10-24 17:04:49,782: validate_n_random_basins: 1
# 2025-10-24 17:04:49,782: early_stopping: True
# 2025-10-24 17:04:49,782: patience_early_stopping: 35
# 2025-10-24 17:04:49,783: minimum_epochs_before_early_stopping: 20
# 2025-10-24 17:04:49,783: min_delta_early_stopping: 5e-07
# 2025-10-24 17:04:49,783: dynamic_learning_rate: True
# 2025-10-24 17:04:49,785: patience_dynamic_learning_rate: 3
# 2025-10-24 17:04:49,786: factor_dynamic_learning_rate: 0.4
# 2025-10-24 17:04:49,786: log_interval: 10
# 2025-10-24 17:04:49,787: log_n_figures: 1
# 2025-10-24 17:04:49,787: log_tensorboard: True
# 2025-10-24 17:04:49,787: save_train_data: False
# 2025-10-24 17:04:49,788: save_validation_results: False
# 2025-10-24 17:04:49,788: save_all_output: False
# 2025-10-24 17:04:49,788: save_weights_every: 5
# 2025-10-24 17:04:49,789: verbose: 1
# 2025-10-24 17:04:49,789: nan_handling_method: masked_mean
# 2025-10-24 17:04:49,789: nan_step_probability: 0.0
# 2025-10-24 17:04:49,790: nan_sequence_probability: 0.0
# 2025-10-24 17:04:49,790: nan_handling_pos_encoding_size: 0
# 2025-10-24 17:04:49,790: number_of_basins: 1
# 2025-10-24 17:04:49,790: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\m2\runs\m2_mape_11_2410_170449
# 2025-10-24 17:04:49,794: ### Device cuda:0 will be used for training
# 2025-10-24 17:04:49,795: Loading basin data into xarray data set.
# 2025-10-24 17:04:49,980: Calculating target variable stds per basin
# 2025-10-24 17:04:49,995: Create lookup table and convert to pytorch tensor
# c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.05 and num_layers=1
#   warnings.warn(
# 2025-10-24 17:05:33,589: Epoch 1 average loss: avg_loss: 22.83262, avg_total_loss: 22.83262
# 2025-10-24 17:05:36,391: Epoch 1 average validation loss: 17.40050 -- Median validation metrics: avg_loss: 17.40050, MAPE: 35.50316, NSE: 0.93147, MSE: 37.95425, RMSE: 6.16070
# 2025-10-24 17:05:43,136: Epoch 2 average loss: avg_loss: 16.61475, avg_total_loss: 16.61475
# 2025-10-24 17:05:45,114: Epoch 2 average validation loss: 16.48409 -- Median validation metrics: avg_loss: 16.48409, MAPE: 55.05725, NSE: 0.94975, MSE: 27.82857, RMSE: 5.27528
# 2025-10-24 17:05:52,116: Epoch 3 average loss: avg_loss: 14.12946, avg_total_loss: 14.12946
# 2025-10-24 17:05:54,106: Epoch 3 average validation loss: 14.51185 -- Median validation metrics: avg_loss: 14.51185, MAPE: 79.94018, NSE: 0.95364, MSE: 25.67330, RMSE: 5.06688
# 2025-10-24 17:06:01,464: Epoch 4 average loss: avg_loss: 12.24438, avg_total_loss: 12.24438
# 2025-10-24 17:06:03,466: Epoch 4 average validation loss: 14.00569 -- Median validation metrics: avg_loss: 14.00569, MAPE: 22.80116, NSE: 0.95546, MSE: 24.66715, RMSE: 4.96660
# 2025-10-24 17:06:10,623: Epoch 5 average loss: avg_loss: 11.23650, avg_total_loss: 11.23650
# 2025-10-24 17:06:12,656: Epoch 5 average validation loss: 12.69907 -- Median validation metrics: avg_loss: 12.69907, MAPE: 38.69999, NSE: 0.95456, MSE: 25.16314, RMSE: 5.01629
# 2025-10-24 17:09:22,479: Epoch 24 average loss: avg_loss: 3.29024, avg_total_loss: 3.29024
# 2025-10-24 17:09:24,991: Epoch 24 average validation loss: 10.84531 -- Median validation metrics: avg_loss: 10.84531, MAPE: 17.63453, NSE: 0.96512, MSE: 19.31465, RMSE: 4.39484
# 2025-10-24 17:09:33,246: Epoch 25 average loss: avg_loss: 3.23385, avg_total_loss: 3.23385
# 2025-10-24 17:09:35,478: Epoch 25 average validation loss: 10.79063 -- Median validation metrics: avg_loss: 10.79063, MAPE: 16.78997, NSE: 0.96586, MSE: 18.90987, RMSE: 4.34855
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       4 if torch.cuda.is_available() or torch.backends.mps.is_available():
#       5     print("Using GPU")
# ----> 6     start_run(config_file=Path(configPath))
#       7 # fall back to cpu-only mode
#       8 else:
#       9     print("Using CPU")
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\nh_run.py:77, in start_run(config_file, gpu)
#      74 if gpu is not None and gpu < 0:
#      75     config.device = "cpu"
# ---> 77 start_training(config)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\train.py:20, in start_training(cfg)
#      18     raise ValueError(f"Unknown head {cfg.head}.")
#      19 trainer.initialize_training()
# ---> 20 trainer.train_and_validate()
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\basetrainer.py:237, in BaseTrainer.train_and_validate(self)
#     234         for param_group in self.optimizer.param_groups:
#     235             param_group["lr"] = self.cfg.learning_rate[epoch]
# --> 237 self._train_epoch(epoch=epoch)
#     238 avg_losses = self.experiment_logger.summarise()
#     239 loss_str = ", ".join(f"{k}: {v:.5f}" for k, v in avg_losses.items())
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\basetrainer.py:361, in BaseTrainer._train_epoch(self, epoch)
#     358 nan_count = 0
#     360 # get gradients
# --> 361 loss.backward()
#     363 if self.cfg.clip_gradient_norm is not None:
#     364     torch.nn.utils.clip_grad_norm_(self.model.parameters(), self.cfg.clip_gradient_norm)
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)    645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\autograd\graph.py:829, in _engine_run_backward(t_outputs, *args, **kwargs)
#     827     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828 try:
# --> 829     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830         t_outputs, *args, **kwargs
#     831     )  # Calls into the C++ engine to run the backward pass
#     832 finally:
#     833     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Plot of the Loss and Metrics

# %%
# Path to your output.log file
log_path = Path(f"{cfg.base_run_dir}/{runFile}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path)

print("Plotting the losses and metrics throughout the training process: ")
plot_training_curves(train_df, val_df)
plot_validation_metrics(val_df)
# Out:
# ✅ Parsed 42 training epochs and 42 validation evaluations.
# Plotting the losses and metrics throughout the training process:

# %% [markdown]
# ---

# %% [markdown]
# ## Evaluation on the **TEST** Dataset
# The run directory that needs to be specified for evaluation is printed in the output log above. Since the folder name is created dynamically (including the date and time of the start of the run) you will need to change the `run_dir` argument according to your local directory name. By default, it will use the same device as during the training process.

# %%
run_dir = Path(f"{cfg.base_run_dir}/{runFile}")

if Evaluation_TEST:
    print(" Starting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test")
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")
# Out:
#  Testing process skipped !

# %% [markdown]
# ---

# %% [markdown]
# ### Load and inspect model predictions
# Next, we load the results file and compare the model predictions with observations. The results file is always a pickled dictionary with one key per basin (even for a single basin). The next-lower dictionary level is the temporal resolution of the predictions.
#
# In this case, we trained a model only on daily data ('1D'). Within the temporal resolution, the next-lower dictionary level are `xr`(an xarray Dataset that contains observations and predictions), as well as one key for each metric that was specified in the config file.
#
# NOTE: The data variables in the xarray Dataset are named according to the name of the target variables, with suffix `_obs` for the observations and suffix `_sim` for the simulations.

# %%
# model_str = f"model_epoch{str(cfg.epochs).zfill(3)}"
model_str = f"model_epoch040"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
basin = "massa_2"
# results.keys()
results[basin]['1h']
# Out:
# {'xr': <xarray.Dataset> Size: 2MB
#  Dimensions:         (date: 10969, time_step: 24)
#  Coordinates:
#    * date            (date) datetime64[ns] 88kB 2024-04-01T23:00:00 ... 2025-0...
#    * time_step       (time_step) int64 192B -23 -22 -21 -20 -19 ... -4 -3 -2 -1 0
#  Data variables:
#      streamflow_obs  (date, time_step) float32 1MB 1.155 1.146 ... 81.34 77.88
#      streamflow_sim  (date, time_step) float32 1MB 1.555 1.588 ... 103.3 102.6,
#  'MAPE': 12.897814750671387,
#  'NSE': 0.9451906681060791,
#  'MSE': 34.5517578125,
#  'RMSE': 5.878074328596059}

# %% [markdown]
# ### Plotting model predictions vs observations

# %% [markdown]
# Code for 1h prediction:

# %%
# qobs=results['massa']['1h']['xr']['streamflow_obs']
# qsim=results['massa']['1h']['xr']['streamflow_sim']
# plot_hydrograph(
#     qobs=qobs,
#     qsim=qsim,
#     results=results,
#     basin='massa',
#     freq='1h',
#     plot_peaks=False  # turn on high-flow markers
# )

# %% [markdown]
# Code for 24h predictions:

# %%
from custom.functions.Plot import plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series

xr_ds = results[basin]["1h"]["xr"]
title24 = f"Massa – {cfg.predict_last_n}h | MAPE {results[basin]['1h']['MAPE']:.3f}, NSE {results[basin]['1h']['NSE']:.3f}, RMSE {results[basin]['1h']['MSE']:.3f}"

# last forecast of the horizon vs obs
plot_forecast_24h(xr_ds, title=title24).show()
# All spaghetti forecasts
# plot_forecast_24h(xr_ds, mode="spaghetti").show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 7
#       4 title24 = f"Massa – {cfg.predict_last_n}h | MAPE {results[basin]['1h']['MAPE']:.3f}, NSE {results[basin]['1h']['NSE']:.3f}, RMSE {results[basin]['1h']['MSE']:.3f}"
#       6 # last forecast of the horizon vs obs
# ----> 7 plot_forecast_24h(xr_ds, title=title24).show()
#       8 # All spaghetti forecasts
#       9 # plot_forecast_24h(xr_ds, mode="spaghetti").show()
#
# AttributeError: 'NoneType' object has no attribute 'show'

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
plot_forecast_horizon_24h(
    xr_ds,
    issue_date="2024-08-10 00:00:00"
).show()
plot_forecast_horizon_24h(
    xr_ds,
    issue_date="2024-08-10 01:00:00"
).show()

# %%
plot_forecast_horizon_series(
    xr_ds,
    issue_date="2024-06-10 00:00:00",
    n_forecasts=10
).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores
# Next, we are going to compute all metrics that are implemented in the NeuralHydrology package. You will find additional hydrological signatures implemented in `neuralhydrology.evaluation.signatures`.

# %%
qobs=results[basin]['1h']['xr']['streamflow_obs']
qsim=results[basin]['1h']['xr']['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.945
# MSE: 34.552
# RMSE: 5.878
# KGE: 0.907
# Alpha-NSE: 0.927
# Beta-KGE: 0.949
# Beta-NSE: -0.039
# Pearson-r: 0.974
# FHV: -8.158
# FMS: -2.170
# FLV: -87.817
# Peak-Timing: nan
# Peak-MAPE: 22.243
# MAPE: 12.898
