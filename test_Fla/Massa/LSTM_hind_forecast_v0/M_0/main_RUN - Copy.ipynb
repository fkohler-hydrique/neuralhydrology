# %% [markdown]
# #  Run of Model **$X$** on the App **MASSA**
#
# **Paramaters**
# The parameters of all models should be available in the parent folder, in an EXCEL file.

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
import torch

from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run
from neuralhydrology.datasetzoo import register_dataset

# %% [markdown]
# ### Adding our Dataset | Metrics | Models

# %%
from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)
from neuralhydrology.utils.config import Config

# Custom functions plot_training_curves
from custom.functions.Plot import plot_hydrograph, plot_training_curves, plot_validation_metrics
from custom.functions.utils_fla import parse_neuralhydrology_log

# %% [markdown]
# ---

# %% [markdown]
# ### Run parameters

# %%
configPath = Path("M0 - Copy.yml")

runFile = "M2_3"

cfg = Config(configPath)
TRAIN = True
Evaluation_TEST =  False
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       1 configPath = Path("M0 - Copy.yml")
#       3 runFile = "M2_3"
# ----> 5 cfg = Config(configPath)
#       6 TRAIN = True
#       7 Evaluation_TEST =  False
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\utils\config.py:53, in Config.__init__(self, yml_path_or_dict, dev_mode)
#      50     raise ValueError(f'Cannot create a config from input of type {type(yml_path_or_dict)}.')
#      52 if not (self._cfg.get('dev_mode', False) or dev_mode):
# ---> 53     Config._check_cfg_keys(self._cfg)
#      55 # Adjust experiment name
#      56 if "experiment_name" in self._cfg and self._cfg["experiment_name"]:
#      57     # 1. Replace curly-bracketed entries
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\utils\config.py:200, in Config._check_cfg_keys(cfg)
#     195 unknown_keys = [
#     196     k for k in cfg.keys()
#     197     if k not in property_names and k not in Config._deprecated_keys and k not in Config._metadata_keys
#     198 ]
#     199 if unknown_keys:
# --> 200     raise ValueError(f'{unknown_keys} are not recognized config keys.')
#
# ValueError: ['data'] are not recognized config keys.

# %% [markdown]
# ---
# ## **Training**

# %%
import pandas as pd
csv_path = r"..\..\data\massa.csv"
data = pd.read_csv(csv_path)
print("Columns of the csv:  ", data.columns)
# print(data.dtypes)
data['date'] = pd.to_datetime(data['date'])


# print some information about the dataset

# print(data.head())
# print(data.describe())
# Out:
# Columns of the csv:   Index(['date', 'streamflow', 'prec_binn', 'prec_bruchji', 'prec_visp',
#        'temp_binn', 'temp_visp', 'ray_visp', 'forecast_prec_bruchji',
#        'forecast_prec_binn', 'forecast_prec_visp', 'forecast_temp_binn',
#        'forecast_temp_visp', 'daylight', 'hr', 'mean_temp', 'mean_temp >0',
#        'degree_day', 'is_snow', 'mean_prec', 'mean_f_prec', 'mean_f_temp',
#        'null_values'],
#       dtype='object')

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    # by default we assume that you have at least one cuda-capable nvidia gpu or macos with metal support
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        start_run(config_file=Path(configPath))
    # fall back to cpu-only mode
    else:
        print("Using CPU")
        start_run(config_file=Path(configPath), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-10-17 15:09:54,789: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\M_0\runs\M0_1710_150954\output.log initialized.
# 2025-10-17 15:09:54,789: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\M_0\runs\M0_1710_150954
# 2025-10-17 15:09:54,790: ### Run configurations for M0
# 2025-10-17 15:09:54,791: experiment_name: M0
# 2025-10-17 15:09:54,792: base_run_dir: runs
# 2025-10-17 15:09:54,792: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\M_0\runs\M0_1710_150954\train_data
# 2025-10-17 15:09:54,792: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\M_0\runs\M0_1710_150954\img_log
# 2025-10-17 15:09:54,793: seed: 42
# 2025-10-17 15:09:54,794: device: cuda:0
# 2025-10-17 15:09:54,794: num_workers: 16
# 2025-10-17 15:09:54,795: data_dir: ..\..\data
# 2025-10-17 15:09:54,795: dataset: swisshourly
# 2025-10-17 15:09:54,795: train_basin_file: ..\..\data\basins.txt
# 2025-10-17 15:09:54,796: validation_basin_file: ..\..\data\basins.txt
# 2025-10-17 15:09:54,796: test_basin_file: ..\..\data\basins.txt
# 2025-10-17 15:09:54,797: train_start_date: 2020-01-03 00:00:00
# 2025-10-17 15:09:54,797: train_end_date: 2023-02-28 00:00:00
# 2025-10-17 15:09:54,797: validation_start_date: 2023-03-01 00:00:00
# 2025-10-17 15:09:54,798: validation_end_date: 2024-03-31 00:00:00
# 2025-10-17 15:09:54,798: test_start_date: 2024-04-01 00:00:00
# 2025-10-17 15:09:54,798: test_end_date: 2025-05-31 00:00:00
# 2025-10-17 15:09:54,799: dynamic_inputs: ['streamflow', 'prec_bruchji', 'temp_binn', 'ray_visp', 'degree_day', 'is_snow', 'forecast_prec_bruchji', 'forecast_temp_binn', 'null_values']
# 2025-10-17 15:09:54,799: hindcast_inputs: ['degree_day', 'is_snow', 'ray_visp', 'prec_bruchji', 'temp_binn', 'streamflow']
# 2025-10-17 15:09:54,799: forecast_inputs: ['degree_day', 'is_snow', 'ray_visp', 'forecast_prec_bruchji', 'forecast_temp_binn', 'null_values']
# 2025-10-17 15:09:54,800: forecast_seq_length: 24
# 2025-10-17 15:09:54,800: forecast_overlap: None
# 2025-10-17 15:09:54,800: timestep_counter: True
# 2025-10-17 15:09:54,801: SH_addRollingFeatures: False
# 2025-10-17 15:09:54,801: target_variables: ['streamflow']
# 2025-10-17 15:09:54,802: clip_targets_to_zero: ['streamflow']
# 2025-10-17 15:09:54,803: model: sequential_forecast_lstm
# 2025-10-17 15:09:54,803: head: regression
# 2025-10-17 15:09:54,803: hidden_size: 128
# 2025-10-17 15:09:54,804: output_activation: linear
# 2025-10-17 15:09:54,804: output_dropout: 0.2
# 2025-10-17 15:09:54,804: initial_forget_bias: 2.5
# 2025-10-17 15:09:54,805: epochs: 1000
# 2025-10-17 15:09:54,805: max_updates_per_epoch: None
# 2025-10-17 15:09:54,805: batch_size: 128
# 2025-10-17 15:09:54,806: optimizer: AdamW
# 2025-10-17 15:09:54,806: loss: MSE
# 2025-10-17 15:09:54,807: learning_rate: 0.001
# 2025-10-17 15:09:54,807: clip_gradient_norm: 3.0
# 2025-10-17 15:09:54,807: seq_length: 360
# 2025-10-17 15:09:54,808: predict_last_n: 24
# 2025-10-17 15:09:54,808: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-10-17 15:09:54,809: validate_every: 1
# 2025-10-17 15:09:54,809: validate_n_random_basins: 1
# 2025-10-17 15:09:54,809: early_stopping: True
# 2025-10-17 15:09:54,810: patience_early_stopping: 10
# 2025-10-17 15:09:54,810: minimum_epochs_before_early_stopping: 20
# 2025-10-17 15:09:54,810: min_delta_early_stopping: 1e-06
# 2025-10-17 15:09:54,811: dynamic_learning_rate: True
# 2025-10-17 15:09:54,811: patience_dynamic_learning_rate: 5
# 2025-10-17 15:09:54,812: factor_dynamic_learning_rate: 0.3
# 2025-10-17 15:09:54,812: log_interval: 10
# 2025-10-17 15:09:54,812: log_n_figures: 1
# 2025-10-17 15:09:54,813: log_tensorboard: True
# 2025-10-17 15:09:54,813: save_train_data: False
# 2025-10-17 15:09:54,813: save_validation_results: False
# 2025-10-17 15:09:54,814: save_all_output: False
# 2025-10-17 15:09:54,814: save_weights_every: 10
# 2025-10-17 15:09:54,814: save_git_diff: False
# 2025-10-17 15:09:54,815: verbose: 1
# 2025-10-17 15:09:54,815: nan_handling_method: masked_mean
# 2025-10-17 15:09:54,815: nan_step_probability: 0.0
# 2025-10-17 15:09:54,816: nan_sequence_probability: 0.0
# 2025-10-17 15:09:54,816: nan_handling_pos_encoding_size: 0
# 2025-10-17 15:09:54,816: number_of_basins: 1
# 2025-10-17 15:09:54,817: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hind_forecast_v0\M_0\runs\M0_1710_150954
# 2025-10-17 15:09:54,821: ### Device cuda:0 will be used for training
# 2025-10-17 15:09:54,822: Loading basin data into xarray data set.
# 2025-10-17 15:09:54,994: Create lookup table and convert to pytorch tensor
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 6
#       4 if torch.cuda.is_available() or torch.backends.mps.is_available():
#       5     print("Using GPU")
# ----> 6     start_run(config_file=Path(configPath))
#       7 # fall back to cpu-only mode
#       8 else:
#       9     print("Using CPU")
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\nh_run.py:77, in start_run(config_file, gpu)
#      74 if gpu is not None and gpu < 0:
#      75     config.device = "cpu"
# ---> 77 start_training(config)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\train.py:20, in start_training(cfg)
#      18     raise ValueError(f"Unknown head {cfg.head}.")
#      19 trainer.initialize_training()
# ---> 20 trainer.train_and_validate()
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\basetrainer.py:237, in BaseTrainer.train_and_validate(self)
#     234         for param_group in self.optimizer.param_groups:
#     235             param_group["lr"] = self.cfg.learning_rate[epoch]
# --> 237 self._train_epoch(epoch=epoch)
#     238 avg_losses = self.experiment_logger.summarise()
#     239 loss_str = ", ".join(f"{k}: {v:.5f}" for k, v in avg_losses.items())
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\basetrainer.py:338, in BaseTrainer._train_epoch(self, epoch)
#     336 data = self.model.pre_model_hook(data, is_train=True)
#     337 # get predictions
# --> 338 predictions = self.model(data)
#     339 if self.noise_sampler_y is not None:
#     340     for key in filter(lambda k: 'y' in k, data.keys()):
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\modelzoo\sequential_forecast_lstm.py:95, in SequentialForecastLSTM.forward(self, data)
#      92 x_f = self.forecast_embedding_net(data)
#      93 # print("after embedding in forward seq lstm")
#      94 # run hindcast part of the lstm
# ---> 95 lstm_output_hindcast, (h_n_hindcast, c_n_hindcast) = self.lstm(input=x_h)
#      96 lstm_output_hindcast = lstm_output_hindcast.transpose(0, 1)
#      98 # run forecast part of the lstm
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\nn\modules\rnn.py:1101, in LSTM.forward(self, input, hx)
#    1093     c_zeros = torch.zeros(
#    1094         self.num_layers * num_directions,
#    1095         max_batch_size,
#    (...)   1098         device=input.device,
#    1099     )
#    1100     hx = (h_zeros, c_zeros)
# -> 1101     self.check_forward_args(input, hx, batch_sizes)
#    1102 else:
#    1103     if is_batched:
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\nn\modules\rnn.py:1002, in LSTM.check_forward_args(self, input, hidden, batch_sizes)
#     996 def check_forward_args(
#     997     self,
#     998     input: Tensor,
#     999     hidden: tuple[Tensor, Tensor],  # type: ignore[override]
#    1000     batch_sizes: Optional[Tensor],
#    1001 ):
# -> 1002     self.check_input(input, batch_sizes)
#    1003     self.check_hidden_size(
#    1004         hidden[0],
#    1005         self.get_expected_hidden_size(input, batch_sizes),
#    1006         "Expected hidden[0] size {}, got {}",
#    1007     )
#    1008     self.check_hidden_size(
#    1009         hidden[1],
#    1010         self.get_expected_cell_size(input, batch_sizes),
#    1011         "Expected hidden[1] size {}, got {}",
#    1012     )
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\nn\modules\rnn.py:315, in RNNBase.check_input(self, input, batch_sizes)
#     311     raise RuntimeError(
#     312         f"input must have {expected_input_dim} dimensions, got {input.dim()}"
#     313     )
#     314 if self.input_size != input.size(-1):
# --> 315     raise RuntimeError(
#     316         f"input.size(-1) must be equal to input_size. Expected {self.input_size}, got {input.size(-1)}"
#     317     )
#
# RuntimeError: input.size(-1) must be equal to input_size. Expected 7, got 8

# %% [markdown]
# ### Plot of the Loss and Metrics

# %%
# Path to your output.log file
log_path = Path(f"{cfg.base_run_dir}/{runFile}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path)

print("Plotting the losses and metrics throughout the training process: ")
plot_training_curves(train_df, val_df)
plot_validation_metrics(val_df)
# Out:
# ✅ Parsed 32 training epochs and 32 validation evaluations.
# Plotting the losses and metrics throughout the training process:

# %% [markdown]
# ---

# %% [markdown]
# ## Evaluation on the **TEST** Dataset
# The run directory that needs to be specified for evaluation is printed in the output log above. Since the folder name is created dynamically (including the date and time of the start of the run) you will need to change the `run_dir` argument according to your local directory name. By default, it will use the same device as during the training process.

# %%
run_dir = Path(f"{cfg.base_run_dir}/{runFile}")

if Evaluation_TEST:
    print(" Starting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test")
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")
# Out:
#  Testing process skipped !

# %% [markdown]
# ---

# %% [markdown]
# ### Load and inspect model predictions
# Next, we load the results file and compare the model predictions with observations. The results file is always a pickled dictionary with one key per basin (even for a single basin). The next-lower dictionary level is the temporal resolution of the predictions.
#
# In this case, we trained a model only on daily data ('1D'). Within the temporal resolution, the next-lower dictionary level are `xr`(an xarray Dataset that contains observations and predictions), as well as one key for each metric that was specified in the config file.
#
# NOTE: The data variables in the xarray Dataset are named according to the name of the target variables, with suffix `_obs` for the observations and suffix `_sim` for the simulations.

# %%
# model_str = f"model_epoch{str(cfg.epochs).zfill(3)}"
model_str = f"model_epoch040"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
basin = "massa"
# results.keys()
results[basin]['1h']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 4
#       2 model_str = f"model_epoch040"
#       3 testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
# ----> 4 with open(testPath, "rb") as fp:
#       5     results = pickle.load(fp)
#       6 basin = "massa"
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'runs\\M2_3\\test\\model_epoch040\\test_results.p'

# %% [markdown]
# ### Plotting model predictions vs observations

# %% [markdown]
# Code for 1h prediction:

# %%
# qobs=results['massa']['1h']['xr']['streamflow_obs']
# qsim=results['massa']['1h']['xr']['streamflow_sim']
# plot_hydrograph(
#     qobs=qobs,
#     qsim=qsim,
#     results=results,
#     basin='massa',
#     freq='1h',
#     plot_peaks=False  # turn on high-flow markers
# )

# %% [markdown]
# Code for 24h predictions:

# %%
from custom.functions.Plot import plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series

xr_ds = results[basin]["1h"]["xr"]
title24 = f"Massa – {cfg.predict_last_n}h | MAPE {results[basin]['1h']['MAPE']:.3f}, NSE {results[basin]['1h']['NSE']:.3f}, RMSE {results[basin]['1h']['MSE']:.3f}"

# last forecast of the horizon vs obs
plot_forecast_24h(xr_ds, title=title24).show()
# All spaghetti forecasts
# plot_forecast_24h(xr_ds, mode="spaghetti").show()

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
plot_forecast_horizon_24h(
    xr_ds,
    issue_date="2024-08-10 00:00:00"
).show()
plot_forecast_horizon_24h(
    xr_ds,
    issue_date="2024-08-10 01:00:00"
).show()

# %%
plot_forecast_horizon_series(
    xr_ds,
    issue_date="2024-06-10 00:00:00",
    n_forecasts=5
).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores
# Next, we are going to compute all metrics that are implemented in the NeuralHydrology package. You will find additional hydrological signatures implemented in `neuralhydrology.evaluation.signatures`.

# %%
qobs=results[basin]['1h']['xr']['streamflow_obs']
qsim=results[basin]['1h']['xr']['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.938
# MSE: 37.066
# RMSE: 6.088
# KGE: 0.869
# Alpha-NSE: 0.888
# Beta-KGE: 0.938
# Beta-NSE: -0.044
# Pearson-r: 0.973
# FHV: -7.390
# FMS: -7.836
# FLV: -1872.438
# Peak-Timing: nan
# Peak-MAPE: 20.293
# MAPE: 38.441
