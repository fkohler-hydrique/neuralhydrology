# %% [markdown]
# #  Run of Model **$X$** on the App **MASSA**
#
# **Paramaters**
# The parameters of all models should be available in the parent folder, in an EXCEL file.

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
import torch

from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run
from neuralhydrology.datasetzoo import register_dataset

# %% [markdown]
# ### Adding our Dataset | Metrics | Models

# %%
from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)
from neuralhydrology.utils.config import Config

# Custom functions plot_training_curves
from custom.functions.Plot import plot_hydrograph, plot_training_curves, plot_validation_metrics
from custom.functions.utils_fla import parse_neuralhydrology_log

# %% [markdown]
# ---

# %% [markdown]
# ### Run parameters

# %%
configPath = Path("M_0.yml")

runFile = "M_0"

cfg = Config(configPath)
TRAIN = True
Evaluation_TEST = False

# %% [markdown]
# ---
# ## **Training**

# %%
import pandas as pd
csv_path = r"..\..\data\massa_basicWithShiftedFeatures.csv"
data = pd.read_csv(csv_path)
print("Columns of the csv:  ", data.columns)
# print(data.dtypes)
data['date'] = pd.to_datetime(data['date'])


# print some information about the dataset

print(data.head())
# print(data.describe())
# Out:
# Index(['date', 'streamflow', 'temp_binn', 'prec_bruchji', 'ray_visp',
#        'temp_binn_Lag_24h', 'prec_bruchji_Lag_24h', 'ray_visp_Lag_24h',
#        'forecast_prec_bruchji', 'forecast_temp_binn'],
#       dtype='object')
# date                      object
# streamflow               float64
# temp_binn                float64
# prec_bruchji             float64
# ray_visp                 float64
# temp_binn_Lag_24h        float64
# prec_bruchji_Lag_24h     float64
# ray_visp_Lag_24h         float64
# forecast_prec_bruchji    float64
# forecast_temp_binn       float64
# dtype: object
#                  date  streamflow  temp_binn  prec_bruchji  ray_visp  \
# 0 2020-03-01 00:00:00    0.716667       -1.9           1.0       5.0
# 1 2020-03-01 01:00:00    0.703333       -2.2           0.4       4.0
# 2 2020-03-01 02:00:00    0.713333       -2.1           0.4       4.0
# 3 2020-03-01 03:00:00    0.710000       -2.3           0.0       4.0
# 4 2020-03-01 04:00:00    0.696667       -2.3           0.0       4.0
#
#    temp_binn_Lag_24h  prec_bruchji_Lag_24h  ray_visp_Lag_24h  \
# 0               -2.0                   0.0               4.0
# 1               -1.5                   0.0               4.0
# 2               -0.2                   0.0               5.0
# 3                0.3                   0.0               4.0
# 4               -1.3                   0.0               4.0
#
#    forecast_prec_bruchji  forecast_temp_binn
# 0               0.065234            0.737297
# 1               0.065234            0.503676
# 2               0.065234            0.270055
# 3               0.065234            0.036435
# 4               0.065234           -0.197186
#                       date    streamflow     temp_binn  prec_bruchji  \
# count                46032  46032.000000  46032.000000  46032.000000
# mean   2022-10-15 23:30:00     16.928749      6.755005      0.122384
# min    2020-03-01 00:00:00      0.263333    -14.600000      0.000000
# 25%    2021-06-23 11:45:00      0.708000      1.000000      0.000000
# 50%    2022-10-15 23:30:00      4.094184      6.200000      0.000000
# 75%    2024-02-07 11:15:00     30.138750     12.100000      0.000000
# max    2025-05-31 23:00:00    126.370500     30.100000     18.700000
# std                    NaN     22.867877      7.556291      0.482358
#
#            ray_visp  temp_binn_Lag_24h  prec_bruchji_Lag_24h  \
# count  46032.000000       46032.000000          46032.000000
# mean     172.657829           6.746324              0.122469
# min        0.000000         -14.600000              0.000000
# 25%        4.000000           1.000000              0.000000
# 50%       10.000000           6.200000              0.000000
# 75%      252.000000          12.054167              0.000000
# max     1151.000000          30.100000             18.700000
# std      269.003983           7.553631              0.482393
#
#        ray_visp_Lag_24h  forecast_prec_bruchji  forecast_temp_binn
# count      46032.000000           46032.000000        46032.000000
# mean         172.556378               0.147692            6.821311
# min            0.000000               0.000000          -13.701889
# 25%            4.000000               0.000000            1.307417
# 50%           10.000000               0.000000            6.343628
# 75%          252.000000               0.017188           12.038260
# max         1151.000000              28.178909           28.756269
# std          268.905649               0.537265            7.282035

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    # by default we assume that you have at least one cuda-capable nvidia gpu or macos with metal support
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        start_run(config_file=Path(configPath))
    # fall back to cpu-only mode
    else:
        print("Using CPU")
        start_run(config_file=Path(configPath), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-10-15 09:25:45,048: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_predict_last24h_of_Seq\M_0\runs\M_0_1510_092545\output.log initialized.
# 2025-10-15 09:25:45,049: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_predict_last24h_of_Seq\M_0\runs\M_0_1510_092545
# 2025-10-15 09:25:45,049: ### Run configurations for M_0
# 2025-10-15 09:25:45,049: experiment_name: M_0
# 2025-10-15 09:25:45,050: base_run_dir: runs
# 2025-10-15 09:25:45,050: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_predict_last24h_of_Seq\M_0\runs\M_0_1510_092545\train_data
# 2025-10-15 09:25:45,051: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_predict_last24h_of_Seq\M_0\runs\M_0_1510_092545\img_log
# 2025-10-15 09:25:45,051: seed: 42
# 2025-10-15 09:25:45,051: device: cuda:0
# 2025-10-15 09:25:45,052: num_workers: 16
# 2025-10-15 09:25:45,052: data_dir: ..\..\data
# 2025-10-15 09:25:45,053: dataset: swisshourly
# 2025-10-15 09:25:45,053: train_basin_file: ..\..\data\basins_basic_lstm.txt
# 2025-10-15 09:25:45,053: validation_basin_file: ..\..\data\basins_basic_lstm.txt
# 2025-10-15 09:25:45,054: test_basin_file: ..\..\data\basins_basic_lstm.txt
# 2025-10-15 09:25:45,055: train_start_date: 2020-01-03 00:00:00
# 2025-10-15 09:25:45,055: train_end_date: 2023-02-28 00:00:00
# 2025-10-15 09:25:45,055: validation_start_date: 2023-03-01 00:00:00
# 2025-10-15 09:25:45,056: validation_end_date: 2024-03-31 00:00:00
# 2025-10-15 09:25:45,056: test_start_date: 2024-04-01 00:00:00
# 2025-10-15 09:25:45,057: test_end_date: 2025-05-31 00:00:00
# 2025-10-15 09:25:45,057: dynamic_inputs: ['temp_binn', 'prec_bruchji', 'ray_visp']
# 2025-10-15 09:25:45,057: SH_addRollingFeatures: False
# 2025-10-15 09:25:45,058: target_variables: ['streamflow']
# 2025-10-15 09:25:45,058: clip_targets_to_zero: ['streamflow']
# 2025-10-15 09:25:45,059: target_normalization: {'streamflow': {'transform': 'log', 'log_offset': 0.01, 'center': 'mean', 'scale': 'std'}}
# 2025-10-15 09:25:45,059: save_transformed_targets: False
# 2025-10-15 09:25:45,059: model: customlstm
# 2025-10-15 09:25:45,060: head: regression
# 2025-10-15 09:25:45,060: hidden_size: 128
# 2025-10-15 09:25:45,060: output_activation: linear
# 2025-10-15 09:25:45,061: output_dropout: 0.1
# 2025-10-15 09:25:45,061: initial_forget_bias: 2
# 2025-10-15 09:25:45,062: dynamics_embedding: None
# 2025-10-15 09:25:45,062: statics_embedding: None
# 2025-10-15 09:25:45,062: epochs: 100
# 2025-10-15 09:25:45,063: max_updates_per_epoch: None
# 2025-10-15 09:25:45,063: batch_size: 64
# 2025-10-15 09:25:45,063: optimizer: AdamW
# 2025-10-15 09:25:45,064: loss: MSE
# 2025-10-15 09:25:45,064: learning_rate: 0.001
# 2025-10-15 09:25:45,064: clip_gradient_norm: 5.0
# 2025-10-15 09:25:45,065: seq_length: 360
# 2025-10-15 09:25:45,065: predict_last_n: 24
# 2025-10-15 09:25:45,065: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-10-15 09:25:45,066: validate_every: 1
# 2025-10-15 09:25:45,066: validate_n_random_basins: 1
# 2025-10-15 09:25:45,067: early_stopping: True
# 2025-10-15 09:25:45,067: patience_early_stopping: 5
# 2025-10-15 09:25:45,067: minimum_epochs_before_early_stopping: 50
# 2025-10-15 09:25:45,068: min_delta_early_stopping: 5e-05
# 2025-10-15 09:25:45,068: dynamic_learning_rate: True
# 2025-10-15 09:25:45,068: patience_dynamic_learning_rate: 5
# 2025-10-15 09:25:45,069: factor_dynamic_learning_rate: 0.4
# 2025-10-15 09:25:45,069: log_interval: 10
# 2025-10-15 09:25:45,069: log_n_figures: 1
# 2025-10-15 09:25:45,070: log_tensorboard: True
# 2025-10-15 09:25:45,070: save_train_data: False
# 2025-10-15 09:25:45,070: save_validation_results: False
# 2025-10-15 09:25:45,071: save_all_output: False
# 2025-10-15 09:25:45,071: save_weights_every: 10
# 2025-10-15 09:25:45,072: save_git_diff: False
# 2025-10-15 09:25:45,072: verbose: 1
# 2025-10-15 09:25:45,072: nan_handling_method: masked_mean
# 2025-10-15 09:25:45,072: nan_step_probability: 0.0
# 2025-10-15 09:25:45,073: nan_sequence_probability: 0.0
# 2025-10-15 09:25:45,073: nan_handling_pos_encoding_size: 0
# 2025-10-15 09:25:45,074: number_of_basins: 1
# 2025-10-15 09:25:45,074: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_predict_last24h_of_Seq\M_0\runs\M_0_1510_092545
# 2025-10-15 09:25:45,079: ### Device cuda:0 will be used for training
# 2025-10-15 09:25:45,080: Loading basin data into xarray data set.
# 2025-10-15 09:25:45,209: Create lookup table and convert to pytorch tensor
# 2025-10-15 09:28:26,542: Epoch 1 average loss: avg_loss: 0.06065, avg_total_loss: 0.06065
# Metrics for 1h are calculated over last 1 elements only. Ignoring 23 predictions per sequence.
# 2025-10-15 09:28:41,808: Epoch 1 average validation loss: 0.02549 -- Median validation metrics: avg_loss: 0.02549, MAPE: 27.43706, NSE: 0.79921, MSE: 111.20332, RMSE: 10.54530
# 2025-10-15 09:31:00,871: Epoch 2 average loss: avg_loss: 0.02597, avg_total_loss: 0.02597
# Metrics for 1h are calculated over last 1 elements only. Ignoring 23 predictions per sequence.
# 2025-10-15 09:31:18,235: Epoch 2 average validation loss: 0.06278 -- Median validation metrics: avg_loss: 0.06278, MAPE: 36.96637, NSE: 0.90987, MSE: 49.91690, RMSE: 7.06519
# 2025-10-15 09:33:38,243: Epoch 3 average loss: avg_loss: 0.02174, avg_total_loss: 0.02174
# Metrics for 1h are calculated over last 1 elements only. Ignoring 23 predictions per sequence.
# 2025-10-15 09:33:57,831: Epoch 3 average validation loss: 0.05230 -- Median validation metrics: avg_loss: 0.05230, MAPE: 35.03780, NSE: 0.85176, MSE: 82.09872, RMSE: 9.06083
# 2025-10-15 09:36:18,895: Epoch 4 average loss: avg_loss: 0.01758, avg_total_loss: 0.01758
# Metrics for 1h are calculated over last 1 elements only. Ignoring 23 predictions per sequence.
# 2025-10-15 09:36:38,660: Epoch 4 average validation loss: 0.03425 -- Median validation metrics: avg_loss: 0.03425, MAPE: 28.37783, NSE: 0.94609, MSE: 29.85924, RMSE: 5.46436
# 2025-10-15 09:39:14,703: Epoch 5 average loss: avg_loss: 0.01580, avg_total_loss: 0.01580
# Metrics for 1h are calculated over last 1 elements only. Ignoring 23 predictions per sequence.
# 2025-10-15 09:39:37,137: Epoch 5 average validation loss: 0.06181 -- Median validation metrics: avg_loss: 0.06181, MAPE: 31.72020, NSE: 0.76134, MSE: 132.17293, RMSE: 11.49665
# 2025-10-15 09:42:16,836: Epoch 6 average loss: avg_loss: 0.01804, avg_total_loss: 0.01804
# Metrics for 1h are calculated over last 1 elements only. Ignoring 23 predictions per sequence.
# 2025-10-15 09:42:37,710: Epoch 6 average validation loss: 0.03970 -- Median validation metrics: avg_loss: 0.03970, MAPE: 27.70118, NSE: 0.94281, MSE: 31.67458, RMSE: 5.62802
# 2025-10-15 09:45:24,820: Epoch 7 average loss: avg_loss: 0.01933, avg_total_loss: 0.01933
# Metrics for 1h are calculated over last 1 elements only. Ignoring 23 predictions per sequence.
# 2025-10-15 09:45:41,314: Epoch 7 average validation loss: 0.01876 -- Median validation metrics: avg_loss: 0.01876, MAPE: 23.55450, NSE: 0.95229, MSE: 26.42217, RMSE: 5.14025
# 2025-10-15 09:48:30,754: Epoch 8 average loss: avg_loss: 0.02361, avg_total_loss: 0.02361
# Metrics for 1h are calculated over last 1 elements only. Ignoring 23 predictions per sequence.
# 2025-10-15 09:48:49,140: Epoch 8 average validation loss: 0.03100 -- Median validation metrics: avg_loss: 0.03100, MAPE: 28.09623, NSE: 0.87463, MSE: 69.43253, RMSE: 8.33262
# # Epoch 9:  83%|████████▎ | 336/406 [02:11<00:45,  1.55it/s, Loss: 0.0133]

# %% [markdown]
# ### Plot of the Loss and Metrics

# %%
# Path to your output.log file
log_path = Path(f"{cfg.base_run_dir}/{runFile}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path)

print("Plotting the losses and metrics throughout the training process: ")
plot_training_curves(train_df, val_df)
plot_validation_metrics(val_df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Path to your output.log file
#       2 log_path = Path(f"{cfg.base_run_dir}/{runFile}/output.log")
# ----> 3 train_df, val_df = parse_neuralhydrology_log(log_path)
#       5 print("Plotting the losses and metrics throughout the training process: ")
#       6 plot_training_curves(train_df, val_df)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\custom\functions\utils_fla.py:8, in parse_neuralhydrology_log(log_path)
#       6 """Parse output.log from NeuralHydrology training run."""
#       7 log_path = Path(log_path)
# ----> 8 text = log_path.read_text(encoding="utf-8")
#      10 # Regex patterns
#      11 train_pattern = r"Epoch (\d+) average loss: avg_loss: ([\d\.]+), avg_total_loss: ([\d\.]+)"
#
# File C:\Python313\Lib\pathlib\_local.py:546, in Path.read_text(self, encoding, errors, newline)
#     543 # Call io.text_encoding() here to ensure any warning is raised at an
#     544 # appropriate stack level.
#     545 encoding = io.text_encoding(encoding)
# --> 546 return PathBase.read_text(self, encoding, errors, newline)
#
# File C:\Python313\Lib\pathlib\_abc.py:632, in PathBase.read_text(self, encoding, errors, newline)
#     628 def read_text(self, encoding=None, errors=None, newline=None):
#     629     """
#     630     Open the file in text mode, read it, and close the file.
#     631     """
# --> 632     with self.open(mode='r', encoding=encoding, errors=errors, newline=newline) as f:
#     633         return f.read()
#
# File C:\Python313\Lib\pathlib\_local.py:537, in Path.open(self, mode, buffering, encoding, errors, newline)
#     535 if "b" not in mode:
#     536     encoding = io.text_encoding(encoding)
# --> 537 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'runs\\M_0\\output.log'

# %% [markdown]
# ---

# %% [markdown]
# ## Evaluation on the **TEST** Dataset
# The run directory that needs to be specified for evaluation is printed in the output log above. Since the folder name is created dynamically (including the date and time of the start of the run) you will need to change the `run_dir` argument according to your local directory name. By default, it will use the same device as during the training process.

# %%
run_dir = Path(f"{cfg.base_run_dir}/{runFile}")

if Evaluation_TEST:
    print(" Starting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test")
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")

# %% [markdown]
# ---

# %% [markdown]
# ### Load and inspect model predictions
# Next, we load the results file and compare the model predictions with observations. The results file is always a pickled dictionary with one key per basin (even for a single basin). The next-lower dictionary level is the temporal resolution of the predictions.
#
# In this case, we trained a model only on daily data ('1D'). Within the temporal resolution, the next-lower dictionary level are `xr`(an xarray Dataset that contains observations and predictions), as well as one key for each metric that was specified in the config file.
#
# NOTE: The data variables in the xarray Dataset are named according to the name of the target variables, with suffix `_obs` for the observations and suffix `_sim` for the simulations.

# %%
model_str = f"model_epoch{str(cfg.epochs).zfill(3)}"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)

# results.keys()
results['massa']['1h']

# %% [markdown]
# ### Plotting model predictions vs observations

# %% [markdown]
# Code for 1h prediction:

# %%
# qobs=results['massa']['1h']['xr']['streamflow_obs']
# qsim=results['massa']['1h']['xr']['streamflow_sim']
# plot_hydrograph(
#     qobs=qobs,
#     qsim=qsim,
#     results=results,
#     basin='massa',
#     freq='1h',
#     plot_peaks=False  # turn on high-flow markers
# )

# %% [markdown]
# Code for 24h predictions:

# %%
from custom.functions.Plot import plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series

xr_ds = results['massa']["1h"]["xr"]
title24 = f"Massa – {cfg.predict_last_n}h | MAPE {results['massa']['1h']['MAPE']:.3f}, NSE {results['massa']['1h']['NSE']:.3f}, RMSE {results['massa']['1h']['MSE']:.3f}"

# last forecast of the horizon vs obs
plot_forecast_24h(xr_ds, title=title24).show()
# All spaghetti forecasts
# plot_forecast_24h(xr_ds, mode="spaghetti").show()

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
plot_forecast_horizon_24h(
    xr_ds,
    issue_date="2024-08-10 00:00:00"
).show()
plot_forecast_horizon_24h(
    xr_ds,
    issue_date="2024-08-10 01:00:00"
).show()

# %%
plot_forecast_horizon_series(
    xr_ds,
    issue_date="2024-06-10 00:00:00",
    n_forecasts=5
).show()

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores
# Next, we are going to compute all metrics that are implemented in the NeuralHydrology package. You will find additional hydrological signatures implemented in `neuralhydrology.evaluation.signatures`.

# %%
qobs=results['massa']['1h']['xr']['streamflow_obs']
qsim=results['massa']['1h']['xr']['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
