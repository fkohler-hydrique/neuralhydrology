# %% [markdown]
# #  Run of Model **$X$** on the App **MASSA**
#
# **Paramaters**
# The parameters of all models should be available in the parent folder, in an EXCEL file.

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
import torch

from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run
from neuralhydrology.datasetzoo import register_dataset

# %% [markdown]
# ### Adding our Dataset | Metrics | Models

# %%
from custom.dataset.swisshourly import SwissHourly
register_dataset("swisshourly", SwissHourly)
from neuralhydrology.utils.config import Config

# Custom functions plot_training_curves
from custom.functions.Plot import plot_hydrograph, plot_training_curves, plot_validation_metrics
from custom.functions.utils_fla import parse_neuralhydrology_log

# %% [markdown]
# ---

# %% [markdown]
# ### Run parameters

# %%
configPath = Path("explo.yml")

runFile = "RS_0_3110_093258"
# RS_0_2910_142521
cfg = Config(configPath)
TRAIN = True
Evaluation_TEST =  True

# %% [markdown]
# ---
# ## **Training**

# %%
import pandas as pd
csv_path = r"..\data\massa_with_RS.csv"
data = pd.read_csv(csv_path)

# %%
if TRAIN:
    print("--- Starting the training of the model ---")
    # by default we assume that you have at least one cuda-capable nvidia gpu or macos with metal support
    if torch.cuda.is_available() or torch.backends.mps.is_available():
        print("Using GPU")
        start_run(config_file=Path(configPath))
    # fall back to cpu-only mode
    else:
        print("Using CPU")
        start_run(config_file=Path(configPath), gpu=-1)
    print("==================================")
    print("  Training ended successfully !   ")
    print("==================================")
else: print(" Training step skipped !")
# Out:
# --- Starting the training of the model ---
# Using GPU
# 2025-10-31 16:31:31: Logging to c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hindFore_RS\runs\RS_0_3110_163131\output.log initialized.
# 2025-10-31 16:31:31: ### Folder structure created at c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hindFore_RS\runs\RS_0_3110_163131
# 2025-10-31 16:31:31: ### Run configurations for RS_0
# 2025-10-31 16:31:31: experiment_name: RS_0
# 2025-10-31 16:31:31: base_run_dir: runs
# 2025-10-31 16:31:31: train_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hindFore_RS\runs\RS_0_3110_163131\train_data
# 2025-10-31 16:31:31: img_log_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hindFore_RS\runs\RS_0_3110_163131\img_log
# 2025-10-31 16:31:31: seed: 42
# 2025-10-31 16:31:31: device: cuda:0
# 2025-10-31 16:31:31: num_workers: 16
# 2025-10-31 16:31:31: data_dir: ..\data
# 2025-10-31 16:31:31: dataset: swisshourly
# 2025-10-31 16:31:31: train_basin_file: ..\data\Data_RS.txt
# 2025-10-31 16:31:31: validation_basin_file: ..\data\Data_RS.txt
# 2025-10-31 16:31:31: test_basin_file: ..\data\Data_RS.txt
# 2025-10-31 16:31:31: train_start_date: 1983-03-04 00:00:00
# 2025-10-31 16:31:31: train_end_date: 2021-04-30 00:00:00
# 2025-10-31 16:31:31: validation_start_date: 2021-03-01 00:00:00
# 2025-10-31 16:31:31: validation_end_date: 2023-02-02 00:00:00
# 2025-10-31 16:31:31: test_start_date: 2023-02-03 00:00:00
# 2025-10-31 16:31:31: test_end_date: 2024-02-04 00:00:00
# 2025-10-31 16:31:31: dynamic_inputs: ['streamflow_hindcast', 'null_values', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus']
# 2025-10-31 16:31:31: hindcast_inputs: ['streamflow_hindcast', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus']
# 2025-10-31 16:31:31: forecast_inputs: ['null_values', 'Massa|22_Q simule', 'Massa|69_i', 'Massa|69_T', 'Massa|70_h', 'Massa|71_h', 'Massa|71_A', 'Massa|73_H', 'Massa|73_A', 'HourOfDaySinus', 'DayOfYearSinus']
# 2025-10-31 16:31:31: forecast_seq_length: 96
# 2025-10-31 16:31:31: forecast_overlap: None
# 2025-10-31 16:31:31: timestep_counter: True
# 2025-10-31 16:31:31: target_variables: ['streamflow']
# 2025-10-31 16:31:31: clip_targets_to_zero: ['streamflow']
# 2025-10-31 16:31:31: model: sequential_forecast_lstm
# 2025-10-31 16:31:31: head: regression
# 2025-10-31 16:31:31: hidden_size: 128
# 2025-10-31 16:31:31: num_layers: 2
# 2025-10-31 16:31:31: seq_length: 150
# 2025-10-31 16:31:31: predict_last_n: 96
# 2025-10-31 16:31:31: output_activation: linear
# 2025-10-31 16:31:31: output_dropout: 0.05
# 2025-10-31 16:31:31: initial_forget_bias: 2
# 2025-10-31 16:31:31: epochs: 1000
# 2025-10-31 16:31:31: learning_rate: 0.001
# 2025-10-31 16:31:31: batch_size: 128
# 2025-10-31 16:31:31: optimizer: AdamW
# 2025-10-31 16:31:31: custom_loss: {'losses': ['smape', 'mse', 'nse'], 'weights': [0.8, 0.1, 0.1]}
# 2025-10-31 16:31:31: loss: custom_loss
# 2025-10-31 16:31:31: clip_gradient_norm: 3.0
# 2025-10-31 16:31:31: metrics: ['MAPE', 'NSE', 'MSE', 'RMSE']
# 2025-10-31 16:31:31: validate_every: 1
# 2025-10-31 16:31:31: validate_n_random_basins: 1
# 2025-10-31 16:31:31: early_stopping: True
# 2025-10-31 16:31:31: patience_early_stopping: 20
# 2025-10-31 16:31:31: minimum_epochs_before_early_stopping: 20
# 2025-10-31 16:31:31: min_delta_early_stopping: 5e-07
# 2025-10-31 16:31:31: dynamic_learning_rate: True
# 2025-10-31 16:31:31: patience_dynamic_learning_rate: 5
# 2025-10-31 16:31:31: factor_dynamic_learning_rate: 0.4
# 2025-10-31 16:31:31: save_best_enabled: True
# 2025-10-31 16:31:31: save_best_criterion: val_loss
# 2025-10-31 16:31:31: log_interval: 10
# 2025-10-31 16:31:31: log_n_figures: 1
# 2025-10-31 16:31:31: log_tensorboard: True
# 2025-10-31 16:31:31: save_train_data: False
# 2025-10-31 16:31:31: save_validation_results: False
# 2025-10-31 16:31:31: save_all_output: False
# 2025-10-31 16:31:31: save_weights_every: 5
# 2025-10-31 16:31:31: verbose: 1
# 2025-10-31 16:31:31: nan_handling_method: masked_mean
# 2025-10-31 16:31:31: nan_step_probability: 0.0
# 2025-10-31 16:31:31: nan_sequence_probability: 0.0
# 2025-10-31 16:31:31: nan_handling_pos_encoding_size: 0
# 2025-10-31 16:31:31: number_of_basins: 1
# 2025-10-31 16:31:31: run_dir: c:\Users\Kohler\Documents\NeuralHydrology_FK\neuralhydrology\test_Fla\Massa\LSTM_hindFore_RS\runs\RS_0_3110_163131
# 2025-10-31 16:31:31: ### Device cuda:0 will be used for training
# 2025-10-31 16:31:31: Loading basin data into xarray data set.
# 2025-10-31 16:31:32: Calculating target variable stds per basin
# 2025-10-31 16:31:32: Create lookup table and convert to pytorch tensor
# 2025-10-31 16:33:29: Epoch 1 average loss: avg_loss: 15.78169, avg_total_loss: 15.78169
# 2025-10-31 16:33:35: Epoch 1 average validation loss: 15.71952 -- Median validation metrics: avg_loss: 15.71952, MAPE: 56.06325, NSE: 0.90159, MSE: 51.29005, RMSE: 7.16171
# 2025-10-31 16:33:35: [saveBest] New best model found at epoch 1: 15.719518 (prev inf)
# 2025-10-31 16:34:43: Epoch 2 average loss: avg_loss: 12.16373, avg_total_loss: 12.16373
# 2025-10-31 16:34:48: Epoch 2 average validation loss: 11.20199 -- Median validation metrics: avg_loss: 11.20199, MAPE: 24.93592, NSE: 0.96836, MSE: 16.49077, RMSE: 4.06088
# 2025-10-31 16:34:48: [saveBest] New best model found at epoch 2: 11.201991 (prev 15.719518)
# 2025-10-31 16:35:59: Epoch 3 average loss: avg_loss: 10.90932, avg_total_loss: 10.90932
# 2025-10-31 16:36:04: Epoch 3 average validation loss: 10.89127 -- Median validation metrics: avg_loss: 10.89127, MAPE: 17.30973, NSE: 0.96790, MSE: 16.72950, RMSE: 4.09017
# 2025-10-31 16:36:04: [saveBest] New best model found at epoch 3: 10.891275 (prev 11.201991)
# 2025-10-31 16:37:15: Epoch 4 average loss: avg_loss: 9.97549, avg_total_loss: 9.97549
# 2025-10-31 16:37:20: Epoch 4 average validation loss: 10.91472 -- Median validation metrics: avg_loss: 10.91472, MAPE: 25.23726, NSE: 0.96366, MSE: 18.94021, RMSE: 4.35203
# 2025-10-31 16:38:29: Epoch 5 average loss: avg_loss: 9.12749, avg_total_loss: 9.12749
# 2025-10-31 16:38:34: Epoch 5 average validation loss: 10.88630 -- Median validation metrics: avg_loss: 10.88630, MAPE: 16.02951, NSE: 0.96376, MSE: 18.88499, RMSE: 4.34569
# 2025-10-31 16:38:34: [saveBest] New best model found at epoch 5: 10.886301 (prev 10.891275)
# 2025-10-31 16:39:46: Epoch 6 average loss: avg_loss: 8.35581, avg_total_loss: 8.35581
# 2025-10-31 16:39:51: Epoch 6 average validation loss: 11.09112 -- Median validation metrics: avg_loss: 11.09112, MAPE: 17.24146, NSE: 0.95980, MSE: 20.94857, RMSE: 4.57696
# 2025-10-31 16:41:02: Epoch 7 average loss: avg_loss: 7.73424, avg_total_loss: 7.73424
# 2025-10-31 16:41:06: Epoch 7 average validation loss: 11.39483 -- Median validation metrics: avg_loss: 11.39483, MAPE: 19.13358, NSE: 0.95255, MSE: 24.72927, RMSE: 4.97285
# 2025-10-31 16:42:15: Epoch 8 average loss: avg_loss: 7.17911, avg_total_loss: 7.17911
# 2025-10-31 16:42:20: Epoch 8 average validation loss: 11.57712 -- Median validation metrics: avg_loss: 11.57712, MAPE: 19.91031, NSE: 0.95381, MSE: 24.07336, RMSE: 4.90646
# 2025-10-31 16:42:20: [Scheduler] - Learning rate changed from 1.0e-03 to 4.0e-04
# 2025-10-31 16:43:31: Epoch 9 average loss: avg_loss: 5.99279, avg_total_loss: 5.99279
# 2025-10-31 16:43:35: Epoch 9 average validation loss: 10.90518 -- Median validation metrics: avg_loss: 10.90518, MAPE: 14.73944, NSE: 0.96004, MSE: 20.82559, RMSE: 4.56351
# 2025-10-31 16:44:45: Epoch 10 average loss: avg_loss: 5.63720, avg_total_loss: 5.63720
# 2025-10-31 16:44:49: Epoch 10 average validation loss: 11.16959 -- Median validation metrics: avg_loss: 11.16959, MAPE: 15.58568, NSE: 0.95737, MSE: 22.21642, RMSE: 4.71343
# 2025-10-31 16:45:57: Epoch 11 average loss: avg_loss: 5.42024, avg_total_loss: 5.42024
# 2025-10-31 16:46:02: Epoch 11 average validation loss: 10.87585 -- Median validation metrics: avg_loss: 10.87585, MAPE: 14.83507, NSE: 0.96105, MSE: 20.30163, RMSE: 4.50573
# 2025-10-31 16:46:02: [saveBest] New best model found at epoch 11: 10.875846 (prev 10.886301)
# 2025-10-31 16:47:13: Epoch 12 average loss: avg_loss: 5.24629, avg_total_loss: 5.24629
# 2025-10-31 16:47:18: Epoch 12 average validation loss: 10.99291 -- Median validation metrics: avg_loss: 10.99291, MAPE: 16.36433, NSE: 0.95970, MSE: 21.00147, RMSE: 4.58274
# 2025-10-31 16:48:30: Epoch 13 average loss: avg_loss: 5.09174, avg_total_loss: 5.09174
# 2025-10-31 16:48:35: Epoch 13 average validation loss: 10.97902 -- Median validation metrics: avg_loss: 10.97902, MAPE: 15.49704, NSE: 0.96173, MSE: 19.94543, RMSE: 4.46603
# 2025-10-31 16:49:45: Epoch 14 average loss: avg_loss: 4.94995, avg_total_loss: 4.94995
# 2025-10-31 16:49:51: Epoch 14 average validation loss: 11.11907 -- Median validation metrics: avg_loss: 11.11907, MAPE: 14.73177, NSE: 0.96049, MSE: 20.59272, RMSE: 4.53792
# 2025-10-31 16:51:02: Epoch 15 average loss: avg_loss: 4.83840, avg_total_loss: 4.83840
# 2025-10-31 16:51:07: Epoch 15 average validation loss: 10.94699 -- Median validation metrics: avg_loss: 10.94699, MAPE: 15.55760, NSE: 0.96138, MSE: 20.12902, RMSE: 4.48654
# 2025-10-31 16:52:28: Epoch 16 average loss: avg_loss: 4.71426, avg_total_loss: 4.71426
# 2025-10-31 16:52:33: Epoch 16 average validation loss: 10.93358 -- Median validation metrics: avg_loss: 10.93358, MAPE: 14.35608, NSE: 0.96212, MSE: 19.74196, RMSE: 4.44319
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       4 if torch.cuda.is_available() or torch.backends.mps.is_available():
#       5     print("Using GPU")
# ----> 6     start_run(config_file=Path(configPath))
#       7 # fall back to cpu-only mode
#       8 else:
#       9     print("Using CPU")
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\nh_run.py:77, in start_run(config_file, gpu)
#      74 if gpu is not None and gpu < 0:
#      75     config.device = "cpu"
# ---> 77 start_training(config)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\train.py:20, in start_training(cfg)
#      18     raise ValueError(f"Unknown head {cfg.head}.")
#      19 trainer.initialize_training()
# ---> 20 trainer.train_and_validate()
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\basetrainer.py:258, in BaseTrainer.train_and_validate(self)
#     255         for param_group in self.optimizer.param_groups:
#     256             param_group["lr"] = self.cfg.learning_rate[epoch]
# --> 258 self._train_epoch(epoch=epoch)
#     259 avg_losses = self.experiment_logger.summarise()
#     260 loss_str = ", ".join(f"{k}: {v:.5f}" for k, v in avg_losses.items())
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\neuralhydrology\training\basetrainer.py:444, in BaseTrainer._train_epoch(self, epoch)
#     441 nan_count = 0
#     443 # get gradients
# --> 444 loss.backward()
#     446 if self.cfg.clip_gradient_norm is not None:
#     447     torch.nn.utils.clip_grad_norm_(self.model.parameters(), self.cfg.clip_gradient_norm)
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)    645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File c:\Users\Kohler\Documents\NeuralHydrology_FK\NH_venv\Lib\site-packages\torch\autograd\graph.py:829, in _engine_run_backward(t_outputs, *args, **kwargs)
#     827     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828 try:
# --> 829     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830         t_outputs, *args, **kwargs
#     831     )  # Calls into the C++ engine to run the backward pass
#     832 finally:
#     833     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Plot of the Loss and Metrics

# %%
# Path to your output.log file
log_path = Path(f"{cfg.base_run_dir}/{runFile}/output.log")
train_df, val_df = parse_neuralhydrology_log(log_path)

print("Plotting the losses and metrics throughout the training process: ")
plot_training_curves(train_df, val_df)
plot_validation_metrics(val_df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Path to your output.log file
#       2 log_path = Path(f"{cfg.base_run_dir}/{runFile}/output.log")
# ----> 3 train_df, val_df = parse_neuralhydrology_log(log_path)
#       5 print("Plotting the losses and metrics throughout the training process: ")
#       6 plot_training_curves(train_df, val_df)
#
# File ~\Documents\NeuralHydrology_FK\neuralhydrology\custom\functions\utils_fla.py:9, in parse_neuralhydrology_log(log_path)
#       7 """Parse output.log from NeuralHydrology training run."""
#       8 log_path = Path(log_path)
# ----> 9 text = log_path.read_text(encoding="utf-8")
#      11 # Regex patterns
#      12 train_pattern = r"Epoch (\d+) average loss: avg_loss: ([\d\.]+), avg_total_loss: ([\d\.]+)"
#
# File C:\Python313\Lib\pathlib\_local.py:546, in Path.read_text(self, encoding, errors, newline)
#     543 # Call io.text_encoding() here to ensure any warning is raised at an
#     544 # appropriate stack level.
#     545 encoding = io.text_encoding(encoding)
# --> 546 return PathBase.read_text(self, encoding, errors, newline)
#
# File C:\Python313\Lib\pathlib\_abc.py:632, in PathBase.read_text(self, encoding, errors, newline)
#     628 def read_text(self, encoding=None, errors=None, newline=None):
#     629     """
#     630     Open the file in text mode, read it, and close the file.
#     631     """
# --> 632     with self.open(mode='r', encoding=encoding, errors=errors, newline=newline) as f:
#     633         return f.read()
#
# File C:\Python313\Lib\pathlib\_local.py:537, in Path.open(self, mode, buffering, encoding, errors, newline)
#     535 if "b" not in mode:
#     536     encoding = io.text_encoding(encoding)
# --> 537 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'runs\\RS_0_3010_144031\\output.log'

# %% [markdown]
# ---

# %% [markdown]
# ## Evaluation on the **TEST** Dataset
# The run directory that needs to be specified for evaluation is printed in the output log above. Since the folder name is created dynamically (including the date and time of the start of the run) you will need to change the `run_dir` argument according to your local directory name. By default, it will use the same device as during the training process.

# %%
run_dir = Path(f"{cfg.base_run_dir}/{runFile}")

if Evaluation_TEST:
    print(" Starting the EVALUATION on the test period:  ")
    eval_run(run_dir=run_dir, period="test", from_best=True)
    print("==================================")
    print("  TEST ended successfully !   ")
    print("==================================")
else: print(" Testing process skipped !")
# Out:
#  Starting the EVALUATION on the test period:
# ==================================
#   TEST ended successfully !
# ==================================

# %% [markdown]
# ---

# %% [markdown]
# ### Load and inspect model predictions
# Next, we load the results file and compare the model predictions with observations. The results file is always a pickled dictionary with one key per basin (even for a single basin). The next-lower dictionary level is the temporal resolution of the predictions.
#
# In this case, we trained a model only on daily data ('1D'). Within the temporal resolution, the next-lower dictionary level are `xr`(an xarray Dataset that contains observations and predictions), as well as one key for each metric that was specified in the config file.
#
# NOTE: The data variables in the xarray Dataset are named according to the name of the target variables, with suffix `_obs` for the observations and suffix `_sim` for the simulations.

# %%
# model_str = f"model_epoch{str(cfg.epochs).zfill(3)}"
model_str = f"model_epoch015"
testPath = Path(run_dir / "test" / f"{model_str}" / "test_results.p")
with open(testPath, "rb") as fp:
    results = pickle.load(fp)
basin = "massa_with_RS"
# results.keys()
results[basin]['1h']
# Out:
# {'xr': <xarray.Dataset> Size: 7MB
#  Dimensions:         (date: 8713, time_step: 96)
#  Coordinates:
#    * date            (date) datetime64[ns] 70kB 2023-02-06T23:00:00 ... 2024-0...
#    * time_step       (time_step) int64 768B -95 -94 -93 -92 -91 ... -4 -3 -2 -1 0
#  Data variables:
#      streamflow_obs  (date, time_step) float32 3MB 0.403 0.403 ... 0.603 0.601
#      streamflow_sim  (date, time_step) float32 3MB 0.5089 0.4568 ... 0.5798,
#  'MAPE': 16.859264373779297,
#  'NSE': 0.9640237092971802,
#  'MSE': 20.765647888183594,
#  'RMSE': 4.556934044748025}

# %% [markdown]
# ### Plotting model predictions vs observations

# %% [markdown]
# Code for 1h prediction:

# %%
# qobs=results['massa']['1h']['xr']['streamflow_obs']
# qsim=results['massa']['1h']['xr']['streamflow_sim']
# plot_hydrograph(
#     qobs=qobs,
#     qsim=qsim,
#     results=results,
#     basin='massa',
#     freq='1h',
#     plot_peaks=False  # turn on high-flow markers
# )

# %% [markdown]
# Code for 24h predictions:

# %%
from custom.functions.Plot import plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series
from custom.functions.utils_fla import info_results, mape_array, dict_without_xr_key
from custom.functions.Plot import plot_mape_horizon

results_ = results[basin]["1h"]["xr"]
scores = dict_without_xr_key(results[basin]['1h'])

# store only the values in numpy arrays from xarray DataArrays
y_true = results_['streamflow_obs']#.values
y_pred = results_['streamflow_sim']#.values

verb = False
if verb: 
    print("\n-- Calculating MAPE values for each horizon: --\n")
    mapes = mape_array(y_true, y_pred, verbose=verb)
    print("\n-- MAPE calculation per horizon completed. --\n")
else:
    mapes = mape_array(y_true, y_pred, verbose=verb)

# %%
# Example usage (variables `mapes`, `horizons`, and `basin` exist in the notebook):
plot_mape_horizon(
    mapes,
    color="#e76f51",
    title=f"MAPE vs Forecast Horizon for basin {basin}"
)

# %%
from custom.functions.Plot import plot_forecast_24h, plot_forecast_horizon_24h,plot_forecast_horizon_series

scores_str = str.join(', ', [f"{key} : {scores[key]:.2f}" for key in scores])
title24 = f"Massa – {cfg.predict_last_n}h | " + scores_str
plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[1, 6, cfg.predict_last_n])
plot_forecast_24h(measured=y_true, predicted=y_pred, title=title24, mode="list", horizons=[cfg.predict_last_n])

# %%
# Example: visualize forecast issued on April 10, 2024, at midnight
plot_forecast_horizon_24h(
    issue_date="2023-08-10 00:00:00",
    xr_ds=results_
).show()
plot_forecast_horizon_24h(
    issue_date="2023-08-10 01:00:00",
    xr_ds=results_
).show()

# %%
plot_forecast_horizon_series(
    issue_date="2023-06-10 00:00:00",
    xr_ds=results_,
    n_forecasts=6
).show()
# 2024-02-04

# %% [markdown]
# ---

# %% [markdown]
# ## Computation of all metric scores
# Next, we are going to compute all metrics that are implemented in the NeuralHydrology package. You will find additional hydrological signatures implemented in `neuralhydrology.evaluation.signatures`.

# %%
qobs=results_['streamflow_obs']
qsim=results_['streamflow_sim']
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))

for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.964
# MSE: 20.766
# RMSE: 4.557
# KGE: 0.955
# Alpha-NSE: 0.969
# Beta-KGE: 0.973
# Beta-NSE: -0.021
# Pearson-r: 0.982
# FHV: -9.731
# FMS: 4.050
# FLV: 9.407
# Peak-Timing: nan
# Peak-MAPE: 21.692
# MAPE: 16.859

# %%
values = metrics.calculate_all_metrics(qobs.isel(time_step=23), qsim.isel(time_step=23))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.970
# MSE: 17.202
# RMSE: 4.147
# KGE: 0.981
# Alpha-NSE: 0.990
# Beta-KGE: 0.996
# Beta-NSE: -0.004
# Pearson-r: 0.985
# FHV: -7.192
# FMS: 2.209
# FLV: 6.706
# Peak-Timing: nan
# Peak-MAPE: 16.196
# MAPE: 11.992
